# %% [markdown]
# <a href="https://colab.research.google.com/github/naga-dheeraj-p/Assignments/blob/main/stocks_intraday_backtesting_11th_july.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Packages

# %%
pip install fyers_apiv3
# Out:
# Collecting fyers_apiv3
#   Downloading fyers_apiv3-3.1.7-py3-none-any.whl.metadata (19 kB)
# Collecting requests==2.31.0 (from fyers_apiv3)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting asyncio==3.4.3 (from fyers_apiv3)
#   Downloading asyncio-3.4.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting aiohttp==3.9.3 (from fyers_apiv3)
#   Downloading aiohttp-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting aws_lambda_powertools==1.25.5 (from fyers_apiv3)
#   Downloading aws_lambda_powertools-1.25.5-py3-none-any.whl.metadata (6.8 kB)
# Collecting websocket-client==1.6.1 (from fyers_apiv3)
#   Downloading websocket_client-1.6.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting protobuf==5.29.3 (from fyers_apiv3)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (6.6.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.9.3->fyers_apiv3) (1.20.1)
# Collecting aws-xray-sdk<3.0.0,>=2.8.0 (from aws_lambda_powertools==1.25.5->fyers_apiv3)
#   Downloading aws_xray_sdk-2.14.0-py2.py3-none-any.whl.metadata (22 kB)
# Collecting boto3<2.0,>=1.18 (from aws_lambda_powertools==1.25.5->fyers_apiv3)
#   Downloading boto3-1.39.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.14.5 in /usr/local/lib/python3.11/dist-packages (from aws_lambda_powertools==1.25.5->fyers_apiv3) (2.21.1)
# Collecting jmespath<0.11.0,>=0.10.0 (from aws_lambda_powertools==1.25.5->fyers_apiv3)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0->fyers_apiv3) (2025.6.15)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.1.2->aiohttp==3.9.3->fyers_apiv3) (4.14.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers_apiv3) (1.17.2)
# Collecting botocore>=1.11.3 (from aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers_apiv3)
#   Downloading botocore-1.39.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3<2.0,>=1.18->aws_lambda_powertools==1.25.5->fyers_apiv3)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->fyers_apiv3) (0.3.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore>=1.11.3->aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers_apiv3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.11.3->aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers_apiv3) (1.17.0)
# Downloading fyers_apiv3-3.1.7-py3-none-any.whl (37 kB)
# Downloading aiohttp-3.9.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.7 MB/s eta 0:00:00
# Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 7.8 MB/s eta 0:00:00
# Downloading aws_lambda_powertools-1.25.5-py3-none-any.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 12.1 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 19.9 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 4.0 MB/s eta 0:00:00
# Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.7 MB/s eta 0:00:00
# Downloading aws_xray_sdk-2.14.0-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 7.6 MB/s eta 0:00:00
# Downloading boto3-1.39.4-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 10.5 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading botocore-1.39.4-py3-none-any.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.9 MB/s eta 0:00:00
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: asyncio, websocket-client, requests, protobuf, jmespath, botocore, aiohttp, s3transfer, aws-xray-sdk, boto3, aws_lambda_powertools, fyers_apiv3
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.8.0
#     Uninstalling websocket-client-1.8.0:
#       Successfully uninstalled websocket-client-1.8.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# Successfully installed aiohttp-3.9.3 asyncio-3.4.3 aws-xray-sdk-2.14.0 aws_lambda_powertools-1.25.5 boto3-1.39.4 botocore-1.39.4 fyers_apiv3-3.1.7 jmespath-0.10.0 protobuf-5.29.3 requests-2.31.0 s3transfer-0.13.0 websocket-client-1.6.1

# %%
pip install pyotp
# Out:
# Collecting pyotp
#   Downloading pyotp-2.9.0-py3-none-any.whl.metadata (9.8 kB)
# Downloading pyotp-2.9.0-py3-none-any.whl (13 kB)
# Installing collected packages: pyotp
# Successfully installed pyotp-2.9.0

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.6.15)

# %%
pip install parse
# Out:
# Collecting parse
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: parse
# Successfully installed parse-1.20.2

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
df = pd.read_csv("/content/2000_STOCKS_list.csv")
df = df[df[" SERIES"].str.strip() == "EQ"]
symbols = df["SYMBOL"].str.strip().tolist()
df = pd.read_csv("/content/stocks_above_6kcr.csv")
df = df[df[" SERIES"].str.strip() == "EQ"]
symbols = df["SYMBOL"].str.strip().tolist()
symbols
fyers_symbols_filtered = [f"NSE:{sym}-EQ" for sym in symbols]
print(fyers_symbols_filtered[:10])
# Out:
# ['20MICRONS',
#  '21STCENMGM',
#  '360ONE',
#  '3IINFOLTD',
#  '3MINDIA',
#  '3PLAND',
#  '5PAISA',
#  '63MOONS',
#  'AAATECH',
#  'AADHARHFC',
#  'AARON',
#  'AARTECH',
#  'AARTIDRUGS',
#  'AARTIIND',
#  'AARTIPHARM',
#  'AARVI',
#  'AAVAS',
#  'ABAN',
#  'ABB',
#  'ABBOTINDIA',
#  'ABCAPITAL',
#  'ABDL',
#  'ABFRL',
#  'ABMINTLLTD',
#  'ABREL',
#  'ABSLAMC',
#  'ACC',
#  'ACCELYA',
#  'ACCURACY',
#  'ACE',
#  'ACEINTEG',
#  'ACI',
#  'ACL',
#  'ACLGATI',
#  'ACMESOLAR',
#  'ACUTAAS',
#  'ADANIENSOL',
#  'ADANIENT',
#  'ADANIGREEN',
#  'ADANIPORTS',
#  'ADANIPOWER',
#  'ADFFOODS',
#  'ADOR',
#  'ADROITINFO',
#  'ADSL',
#  'ADVANIHOTR',
#  'ADVENZYMES',
#  'AEGISLOG',
#  'AEGISVOPAK',
#  'AEROENTER',
#  'AEROFLEX',
#  'AETHER',
#  'AFCONS',
#  'AFFLE',
#  'AFFORDABLE',
#  'AFIL',
#  'AFSL',
#  'AGARIND',
#  'AGARWALEYE',
#  'AGI',
#  'AGIIL',
#  'AGRITECH',
#  'AGROPHOS',
#  'AHLADA',
#  'AHLEAST',
#  'AHLUCONT',
#  'AIAENG',
#  'AIIL',
#  'AIRAN',
#  'AIROLAM',
#  'AJANTPHARM',
#  'AJAXENGG',
#  'AJMERA',
#  'AJOONI',
#  'AKASH',
#  'AKG',
#  'AKSHARCHEM',
#  'AKSHOPTFBR',
#  'AKUMS',
#  'AKZOINDIA',
#  'ALANKIT',
#  'ALBERTDAVD',
#  'ALEMBICLTD',
#  'ALICON',
#  'ALIVUS',
#  'ALKALI',
#  'ALKEM',
#  'ALKYLAMINE',
#  'ALLCARGO',
#  'ALLDIGI',
#  'ALMONDZ',
#  'ALOKINDS',
#  'ALPA',
#  'ALPHAGEO',
#  'AMBER',
#  'AMBICAAGAR',
#  'AMBIKCO',
#  'AMBUJACEM',
#  'AMDIND',
#  'AMJLAND',
#  'AMNPLST',
#  'AMRUTANJAN',
#  'ANANDRATHI',
#  'ANANTRAJ',
#  'ANDHRAPAP',
#  'ANDHRSUGAR',
#  'ANGELONE',
#  'ANIKINDS',
#  'ANMOL',
#  'ANTGRAPHIC',
#  'ANUHPHR',
#  'ANUP',
#  'ANURAS',
#  'APARINDS',
#  'APCL',
#  'APCOTEXIND',
#  'APEX',
#  'APLAPOLLO',
#  'APLLTD',
#  'APOLLO',
#  'APOLLOHOSP',
#  'APOLLOPIPE',
#  'APOLLOTYRE',
#  'APOLSINHOT',
#  'APTUS',
#  'ARCHIDPLY',
#  'ARE&M',
#  'ARENTERP',
#  'ARIES',
#  'ARIHANTCAP',
#  'ARIHANTSUP',
#  'ARISINFRA',
#  'ARKADE',
#  'ARMANFIN',
#  'AROGRANITE',
#  'ARTEMISMED',
#  'ARVEE',
#  'ARVIND',
#  'ARVINDFASN',
#  'ARVSMART',
#  'ASAHIINDIA',
#  'ASAL',
#  'ASALCBR',
#  'ASHAPURMIN',
#  'ASHIANA',
#  'ASHOKA',
#  'ASHOKAMET',
#  'ASHOKLEY',
#  'ASIANENE',
#  'ASIANPAINT',
#  'ASKAUTOLTD',
#  'ASMS',
#  'ASPINWALL',
#  'ASTEC',
#  'ASTERDM',
#  'ASTRAL',
#  'ASTRAMICRO',
#  'ASTRAZEN',
#  'ATAM',
#  'ATGL',
#  'ATHERENERG',
#  'ATL',
#  'ATLANTAA',
#  'ATUL',
#  'ATULAUTO',
#  'AUBANK',
#  'AURIONPRO',
#  'AUROPHARMA',
#  'AURUM',
#  'AUTOAXLES',
#  'AUTOIND',
#  'AVADHSUGAR',
#  'AVALON',
#  'AVANTEL',
#  'AVANTIFEED',
#  'AVG',
#  'AVL',
#  'AVROIND',
#  'AVTNPL',
#  'AWFIS',
#  'AWHCL',
#  'AWL',
#  'AXISBANK',
#  'AXITA',
#  'AYMSYNTEX',
#  'AZAD',
#  'BAGFILMS',
#  'BAIDFIN',
#  'BAJAJ-AUTO',
#  'BAJAJCON',
#  'BAJAJELEC',
#  'BAJAJFINSV',
#  'BAJAJHCARE',
#  'BAJAJHFL',
#  'BAJAJHIND',
#  'BAJAJHLDNG',
#  'BAJAJINDEF',
#  'BAJFINANCE',
#  'BALAJEE',
#  'BALAMINES',
#  'BALAXI',
#  'BALKRISHNA',
#  'BALKRISIND',
#  'BALMLAWRIE',
#  'BALPHARMA',
#  'BALRAMCHIN',
#  'BANARBEADS',
#  'BANARISUG',
#  'BANCOINDIA',
#  'BANDHANBNK',
#  'BANG',
#  'BANKA',
#  'BANKBARODA',
#  'BANKINDIA',
#  'BANSALWIRE',
#  'BANSWRAS',
#  'BARBEQUE',
#  'BASF',
#  'BASML',
#  'BATAINDIA',
#  'BAYERCROP',
#  'BBL',
#  'BBTC',
#  'BBTCL',
#  'BCLIND',
#  'BCONCEPTS',
#  'BDL',
#  'BEARDSELL',
#  'BECTORFOOD',
#  'BEDMUTHA',
#  'BEL',
#  'BELRISE',
#  'BEML',
#  'BEPL',
#  'BERGEPAINT',
#  'BESTAGRO',
#  'BFINVEST',
#  'BFUTILITIE',
#  'BHAGCHEM',
#  'BHAGERIA',
#  'BHAGYANGR',
#  'BHANDARI',
#  'BHARATFORG',
#  'BHARATGEAR',
#  'BHARATRAS',
#  'BHARATWIRE',
#  'BHARTIARTL',
#  'BHARTIHEXA',
#  'BHEL',
#  'BIGBLOC',
#  'BIKAJI',
#  'BIL',
#  'BIOCON',
#  'BIRLACORPN',
#  'BIRLAMONEY',
#  'BIRLANU',
#  'BLACKBUCK',
#  'BLAL',
#  'BLBLIMITED',
#  'BLISSGVS',
#  'BLKASHYAP',
#  'BLS',
#  'BLUEDART',
#  'BLUEJET',
#  'BLUESTARCO',
#  'BLUSPRING',
#  'BODALCHEM',
#  'BOMDYEING',
#  'BORANA',
#  'BOROLTD',
#  'BORORENEW',
#  'BOROSCI',
#  'BOSCHLTD',
#  'BPCL',
#  'BPL',
#  'BRIGADE',
#  'BRITANNIA',
#  'BSE',
#  'BSHSL',
#  'BSOFT',
#  'BTML',
#  'BUTTERFLY',
#  'BVCL',
#  'CALSOFT',
#  'CAMPUS',
#  'CAMS',
#  'CANBK',
#  'CANFINHOME',
#  'CANTABIL',
#  'CAPACITE',
#  'CAPITALSFB',
#  'CAPLIPOINT',
#  'CARBORUNIV',
#  'CARERATING',
#  'CARRARO',
#  'CARTRADE',
#  'CARYSIL',
#  'CASTROLIND',
#  'CCCL',
#  'CCHHL',
#  'CCL',
#  'CDSL',
#  'CEATLTD',
#  'CEIGALL',
#  'CELEBRITY',
#  'CELLO',
#  'CENTENKA',
#  'CENTEXT',
#  'CENTRALBK',
#  'CENTUM',
#  'CENTURYPLY',
#  'CERA',
#  'CESC',
#  'CEWATER',
#  'CGCL',
#  'CGPOWER',
#  'CHALET',
#  'CHAMBLFERT',
#  'CHEMCON',
#  'CHEMFAB',
#  'CHEMPLASTS',
#  'CHENNPETRO',
#  'CHEVIOT',
#  'CHOICEIN',
#  'CHOLAFIN',
#  'CHOLAHLDNG',
#  'CIEINDIA',
#  'CIFL',
#  'CIGNITITEC',
#  'CINELINE',
#  'CIPLA',
#  'CLEAN',
#  'CLEDUCATE',
#  'CLSEL',
#  'CMSINFO',
#  'COALINDIA',
#  'COASTCORP',
#  'COCHINSHIP',
#  'COFFEEDAY',
#  'COFORGE',
#  'COHANCE',
#  'COLPAL',
#  'COMPUSOFT',
#  'COMSYN',
#  'CONCOR',
#  'CONCORDBIO',
#  'CONFIPET',
#  'CONSOFINVT',
#  'CONTROLPR',
#  'CORALFINAC',
#  'CORDSCABLE',
#  'COROMANDEL',
#  'COSMOFIRST',
#  'CPCAP',
#  'CRAFTSMAN',
#  'CREATIVE',
#  'CREDITACC',
#  'CREST',
#  'CRISIL',
#  'CROMPTON',
#  'CROWN',
#  'CSBBANK',
#  'CSLFINANCE',
#  'CUB',
#  'CUBEXTUB',
#  'CUMMINSIND',
#  'CUPID',
#  'CYBERMEDIA',
#  'CYIENT',
#  'CYIENTDLM',
#  'DABUR',
#  'DALBHARAT',
#  'DALMIASUG',
#  'DAMCAPITAL',
#  'DAMODARIND',
#  'DATAMATICS',
#  'DATAPATTNS',
#  'DAVANGERE',
#  'DBCORP',
#  'DBEIL',
#  'DBL',
#  'DBREALTY',
#  'DBSTOCKBRO',
#  'DCBBANK',
#  'DCI',
#  'DCM',
#  'DCMNVL',
#  'DCMSHRIRAM',
#  'DCMSRIND',
#  'DCW',
#  'DCXINDIA',
#  'DDEVPLSTIK',
#  'DECCANCE',
#  'DEEDEV',
#  'DEEPAKFERT',
#  'DEEPAKNTR',
#  'DEEPINDS',
#  'DELHIVERY',
#  'DELPHIFX',
#  'DELTACORP',
#  'DEN',
#  'DENORA',
#  'DENTA',
#  'DEVIT',
#  'DEVYANI',
#  'DGCONTENT',
#  'DHAMPURSUG',
#  'DHANBANK',
#  'DHANI',
#  'DHANUKA',
#  'DHUNINV',
#  'DIACABS',
#  'DIAMINESQ',
#  'DIAMONDYD',
#  'DICIND',
#  'DIFFNKG',
#  'DIGIDRIVE',
#  'DIGISPICE',
#  'DIGITIDE',
#  'DIVGIITTS',
#  'DIVISLAB',
#  'DIXON',
#  'DJML',
#  'DLF',
#  'DLINKINDIA',
#  'DMART',
#  'DMCC',
#  'DNAMEDIA',
#  'DODLA',
#  'DOLATALGO',
#  'DOLLAR',
#  'DOLPHIN',
#  'DOMS',
#  'DONEAR',
#  'DPABHUSHAN',
#  'DPSCLTD',
#  'DPWIRES',
#  'DREAMFOLKS',
#  'DREDGECORP',
#  'DRREDDY',
#  'DSSL',
#  'DTIL',
#  'DUCON',
#  'DVL',
#  'DWARKESH',
#  'DYCL',
#  'DYNAMATECH',
#  'DYNPRO',
#  'E2E',
#  'EASEMYTRIP',
#  'ECLERX',
#  'ECOSMOBLTY',
#  'EDELWEISS',
#  'EICHERMOT',
#  'EIDPARRY',
#  'EIEL',
#  'EIFFL',
#  'EIHAHOTELS',
#  'EIHOTEL',
#  'EIMCOELECO',
#  'EKC',
#  'ELDEHSG',
#  'ELECON',
#  'ELECTCAST',
#  'ELECTHERM',
#  'ELGIEQUIP',
#  'EMAMILTD',
#  'EMAMIPAP',
#  'EMBDL',
#  'EMCURE',
#  'EMIL',
#  'EMMBI',
#  'EMSLIMITED',
#  'EMUDHRA',
#  'ENDURANCE',
#  'ENGINERSIN',
#  'ENIL',
#  'ENTERO',
#  'EPACK',
#  'EPIGRAL',
#  'EPL',
#  'EQUITASBNK',
#  'ERIS',
#  'ESABINDIA',
#  'ESAFSFB',
#  'ESCORTS',
#  'ESSENTIA',
#  'ESTER',
#  'ETERNAL',
#  'ETHOSLTD',
#  'EUREKAFORB',
#  'EUROTEXIND',
#  'EVEREADY',
#  'EXCEL',
#  'EXCELINDUS',
#  'EXICOM',
#  'EXIDEIND',
#  'EXPLEOSOL',
#  'FACT',
#  'FAIRCHEMOR',
#  'FAZE3Q',
#  'FCL',
#  'FCSSOFT',
#  'FDC',
#  'FEDERALBNK',
#  'FEDFINA',
#  'FIBERWEB',
#  'FIEMIND',
#  'FILATEX',
#  'FINCABLES',
#  'FINEORG',
#  'FINOPB',
#  'FINPIPE',
#  'FIRSTCRY',
#  'FIVESTAR',
#  'FLAIR',
#  'FLUOROCHEM',
#  'FMGOETZE',
#  'FOODSIN',
#  'FORCEMOT',
#  'FORTIS',
#  'FOSECOIND',
#  'FSL',
#  'FUSION',
#  'GABRIEL',
#  'GAEL',
#  'GAIL',
#  'GALAPREC',
#  'GALAXYSURF',
#  'GALLANTT',
#  'GANDHAR',
#  'GANDHITUBE',
#  'GANECOS',
#  'GANESHBE',
#  'GANESHHOUC',
#  'GANGAFORGE',
#  'GANGESSECU',
#  'GARFIBRES',
#  'GARUDA',
#  'GATECHDVR',
#  'GATEWAY',
#  'GEECEE',
#  'GEEKAYWIRE',
#  'GENESYS',
#  'GENUSPAPER',
#  'GENUSPOWER',
#  'GEOJITFSL',
#  'GEPIL',
#  'GESHIP',
#  'GFLLIMITED',
#  'GHCL',
#  'GHCLTEXTIL',
#  'GICHSGFIN',
#  'GICRE',
#  'GILLANDERS',
#  'GILLETTE',
#  'GIPCL',
#  'GKWLIMITED',
#  'GLAND',
#  'GLAXO',
#  'GLENMARK',
#  'GLOBAL',
#  'GLOBALVECT',
#  'GLOBUSSPR',
#  'GLOSTERLTD',
#  'GMBREW',
#  'GMDCLTD',
#  'GMMPFAUDLR',
#  'GMRAIRPORT',
#  'GMRP&UI',
#  'GNA',
#  'GNFC',
#  'GOACARBON',
#  'GOCLCORP',
#  'GOCOLORS',
#  'GODFRYPHLP',
#  'GODHA',
#  'GODIGIT',
#  'GODREJAGRO',
#  'GODREJCP',
#  'GODREJIND',
#  'GODREJPROP',
#  'GOKEX',
#  'GOKUL',
#  'GOKULAGRO',
#  'GOLDIAM',
#  'GOLDTECH',
#  'GOODLUCK',
#  'GOPAL',
#  'GOYALALUM',
#  'GPIL',
#  'GPPL',
#  'GPTHEALTH',
#  'GPTINFRA',
#  'GRANULES',
#  'GRAPHITE',
#  'GRASIM',
#  'GRAVITA',
#  'GREAVESCOT',
#  'GREENLAM',
#  'GREENPANEL',
#  'GREENPLY',
#  'GREENPOWER',
#  'GRINDWELL',
#  'GRINFRA',
#  'GRMOVER',
#  'GRPLTD',
#  'GRSE',
#  'GRWRHITECH',
#  'GSFC',
#  'GSLSU',
#  'GSPL',
#  'GSS',
#  'GTL',
#  'GTLINFRA',
#  'GTPL',
#  'GUFICBIO',
#  'GUJALKALI',
#  'GUJAPOLLO',
#  'GUJGASLTD',
#  'GUJTHEM',
#  'GULFOILLUB',
#  'GULFPETRO',
#  'GULPOLY',
#  'GVPTECH',
#  'GVT&D',
#  'HAL',
#  'HAPPSTMNDS',
#  'HAPPYFORGE',
#  'HARIOMPIPE',
#  'HARRMALAYA',
#  'HARSHA',
#  'HATHWAY',
#  'HATSUN',
#  'HAVELLS',
#  'HAVISHA',
#  'HBLENGINE',
#  'HBSL',
#  'HCG',
#  'HCLTECH',
#  'HDFCAMC',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEADSUP',
#  'HEG',
#  'HEIDELBERG',
#  'HEMIPROP',
#  'HERITGFOOD',
#  'HEROMOTOCO',
#  'HESTERBIO',
#  'HEUBACHIND',
#  'HEXATRADEX',
#  'HEXT',
#  'HFCL',
#  'HGINFRA',
#  'HGS',
#  'HIKAL',
#  'HIMATSEIDE',
#  'HINDALCO',
#  'HINDCOMPOS',
#  'HINDCON',
#  'HINDCOPPER',
#  'HINDOILEXP',
#  'HINDPETRO',
#  'HINDUNILVR',
#  'HINDWAREAP',
#  'HINDZINC',
#  'HIRECT',
#  'HISARMETAL',
#  'HITECH',
#  'HITECHCORP',
#  'HLEGLAS',
#  'HLVLTD',
#  'HMAAGRO',
#  'HMVL',
#  'HNDFDS',
#  'HOMEFIRST',
#  'HONASA',
#  'HONAUT',
#  'HONDAPOWER',
#  'HPAL',
#  'HPIL',
#  'HPL',
#  'HSCL',
#  'HUBTOWN',
#  'HUDCO',
#  'HUHTAMAKI',
#  'HYUNDAI',
#  'ICEMAKE',
#  'ICICIBANK',
#  'ICICIGI',
#  'ICICIPRULI',
#  'ICIL',
#  'ICRA',
#  'IDBI',
#  'IDEA',
#  'IDEAFORGE',
#  'IDFCFIRSTB',
#  'IEX',
#  'IFBIND',
#  'IFCI',
#  'IFGLEXPOR',
#  'IGARASHI',
#  'IGIL',
#  'IGL',
#  'IGPL',
#  'IIFL',
#  'IIFLCAPS',
#  'IKIO',
#  'IKS',
#  'IMAGICAA',
#  'IMFA',
#  'IMPAL',
#  'INDBANK',
#  'INDGN',
#  'INDHOTEL',
#  'INDIACEM',
#  'INDIAGLYCO',
#  'INDIAMART',
#  'INDIANB',
#  'INDIANCARD',
#  'INDIANHUME',
#  'INDIASHLTR',
#  'INDIGO',
#  'INDIGOPNTS',
#  'INDNIPPON',
#  'INDOAMIN',
#  'INDOBORAX',
#  'INDOCO',
#  'INDOSTAR',
#  'INDOTECH',
#  'INDOUS',
#  'INDOWIND',
#  'INDRAMEDCO',
#  'INDSWFTLAB',
#  'INDSWFTLTD',
#  'INDTERRAIN',
#  'INDUSINDBK',
#  'INDUSTOWER',
#  'INFIBEAM',
#  'INFOBEAN',
#  'INFY',
#  'INGERRAND',
#  'INNOVACAP',
#  'INNOVANA',
#  'INOXINDIA',
#  'INOXWIND',
#  'INSECTICID',
#  'INSPIRISYS',
#  'INTELLECT',
#  'INTENTECH',
#  'INTLCONV',
#  'INVENTURE',
#  'IOB',
#  'IOC',
#  'IOLCP',
#  'IONEXCHANG',
#  'IPCALAB',
#  'IPL',
#  'IRB',
#  'IRCON',
#  'IRCTC',
#  'IREDA',
#  'IRFC',
#  'IRIS',
#  'IRISDOREME',
#  'IRMENERGY',
#  'ISFT',
#  'ISGEC',
#  'ISHANCH',
#  'ITC',
#  'ITCHOTELS',
#  'ITDC',
#  'ITDCEM',
#  'ITI',
#  'IVC',
#  'IVP',
#  'IXIGO',
#  'J&KBANK',
#  'JAGRAN',
#  'JAGSNPHARM',
#  'JAIBALAJI',
#  'JAICORPLTD',
#  'JAIPURKURT',
#  'JAMNAAUTO',
#  'JASH',
#  'JAYAGROGN',
#  'JAYBARMARU',
#  'JAYNECOIND',
#  'JAYSREETEA',
#  'JBCHEPHARM',
#  'JBMA',
#  'JCHAC',
#  'JETFREIGHT',
#  'JGCHEM',
#  'JHS',
#  'JINDALPOLY',
#  'JINDALSAW',
#  'JINDALSTEL',
#  'JINDRILL',
#  'JINDWORLD',
#  'JIOFIN',
#  'JISLDVREQS',
#  'JISLJALEQS',
#  'JKCEMENT',
#  'JKIL',
#  'JKLAKSHMI',
#  'JKPAPER',
#  'JKTYRE',
#  'JLHL',
#  'JMA',
#  'JMFINANCIL',
#  'JNKINDIA',
#  'JOCIL',
#  'JPOLYINVST',
#  'JPPOWER',
#  'JSFB',
#  'JSL',
#  'JSWENERGY',
#  'JSWINFRA',
#  'JSWSTEEL',
#  'JTEKTINDIA',
#  'JTLIND',
#  'JUBLCPL',
#  'JUBLFOOD',
#  'JUBLINGREA',
#  'JUBLPHARMA',
#  'JUNIPER',
#  'JUSTDIAL',
#  'JWL',
#  'JYOTHYLAB',
#  'JYOTICNC',
#  'JYOTISTRUC',
#  'KAJARIACER',
#  'KAKATCEM',
#  'KALAMANDIR',
#  'KALYANIFRG',
#  'KALYANKJIL',
#  'KAMATHOTEL',
#  'KAMDHENU',
#  'KANANIIND',
#  'KANORICHEM',
#  'KANSAINER',
#  'KAPSTON',
#  'KARURVYSYA',
#  'KAUSHALYA',
#  'KAYNES',
#  'KCP',
#  'KCPSUGIND',
#  'KDDL',
#  'KEC',
#  'KECL',
#  'KEI',
#  'KELLTONTEC',
#  'KFINTECH',
#  'KHADIM',
#  'KHANDSE',
#  'KICL',
#  'KIMS',
#  'KINGFA',
#  'KIOCL',
#  'KIRIINDUS',
#  'KIRLOSBROS',
#  'KIRLOSENG',
#  'KIRLOSIND',
#  'KIRLPNU',
#  'KITEX',
#  'KKCL',
#  'KMEW',
#  'KMSUGAR',
#  'KNRCON',
#  'KOHINOOR',
#  'KOKUYOCMLN',
#  'KOLTEPATIL',
#  'KOPRAN',
#  'KOTAKBANK',
#  'KOTARISUG',
#  'KOTHARIPET',
#  'KOTHARIPRO',
#  'KPEL',
#  'KPIGREEN',
#  'KPIL',
#  'KPITTECH',
#  'KPRMILL',
#  'KRBL',
#  'KRIDHANINF',
#  'KRISHANA',
#  'KRITIKA',
#  'KRITINUT',
#  'KRN',
#  'KRONOX',
#  'KROSS',
#  'KRSNAA',
#  'KSB',
#  'KSCL',
#  'KSHITIJPOL',
#  'KSL',
#  'KSOLVES',
#  'KTKBANK',
#  'KUANTUM',
#  'LAGNAM',
#  'LALPATHLAB',
#  'LAMBODHARA',
#  'LANCORHOL',
#  'LANDMARK',
#  'LAOPALA',
#  'LATENTVIEW',
#  'LATTEYS',
#  'LAURUSLABS',
#  'LAXMICOT',
#  'LAXMIDENTL',
#  'LEMONTREE',
#  'LEXUS',
#  'LFIC',
#  'LGBBROSLTD',
#  'LGHL',
#  'LIBAS',
#  'LICHSGFIN',
#  'LICI',
#  'LIKHITHA',
#  'LINC',
#  'LINCOLN',
#  'LINDEINDIA',
#  'LLOYDSENGG',
#  'LLOYDSENT',
#  'LLOYDSME',
#  'LMW',
#  'LODHA',
#  'LORDSCHLO',
#  'LOTUSEYE',
#  'LOVABLE',
#  'LOYALTEX',
#  'LPDC',
#  'LT',
#  'LTF',
#  'LTFOODS',
#  'LTIM',
#  'LTTS',
#  'LUMAXIND',
#  'LUMAXTECH',
#  'LUPIN',
#  'LUXIND',
#  'LXCHEM',
#  'LYKALABS',
#  'M&M',
#  'M&MFIN',
#  'MADHAV',
#  'MADRASFERT',
#  'MAGADSUGAR',
#  'MAGNUM',
#  'MAHABANK',
#  'MAHAPEXLTD',
#  'MAHEPC',
#  'MAHESHWARI',
#  'MAHLIFE',
#  'MAHLOG',
#  'MAHSCOOTER',
#  'MAHSEAMLES',
#  'MAITHANALL',
#  'MALLCOM',
#  'MALUPAPER',
#  'MAMATA',
#  'MANAKALUCO',
#  'MANAKCOAT',
#  'MANAKSIA',
#  'MANAKSTEEL',
#  'MANALIPETC',
#  'MANAPPURAM',
#  'MANBA',
#  'MANCREDIT',
#  'MANGALAM',
#  'MANGCHEFER',
#  'MANGLMCEM',
#  'MANINDS',
#  'MANINFRA',
#  'MANKIND',
#  'MANOMAY',
#  'MANORAMA',
#  'MANYAVAR',
#  'MAPMYINDIA',
#  'MARALOVER',
#  'MARATHON',
#  'MARICO',
#  'MARKSANS',
#  'MARUTI',
#  'MASFIN',
#  'MASTEK',
#  'MASTERTR',
#  'MATRIMONY',
#  'MAWANASUG',
#  'MAXESTATES',
#  'MAXHEALTH',
#  'MAXIND',
#  'MAYURUNIQ',
#  'MAZDA',
#  'MAZDOCK',
#  'MBAPL',
#  'MBLINFRA',
#  'MCL',
#  'MCLEODRUSS',
#  ...]

# %%
df = pd.read_csv("/content/stocks_above_6kcr.csv")
df = df[df[" SERIES"].str.strip() == "EQ"]
symbols = df["SYMBOL"].str.strip().tolist()
symbols
fyers_symbols_filtered = [f"NSE:{sym}-EQ" for sym in symbols]
print(fyers_symbols_filtered[:10])
# Out:
# ['NSE:TVSSCS-EQ', 'NSE:BANSALWIRE-EQ', 'NSE:PILANIINVS-EQ', 'NSE:GULFOILLUB-EQ', 'NSE:GREENLAM-EQ', 'NSE:SUBROS-EQ', 'NSE:EMUDHRA-EQ', 'NSE:JKPAPER-EQ', 'NSE:KNRCON-EQ', 'NSE:RESPONIND-EQ']

# %%
fyers_symbols = [f"NSE:{sym}-EQ" for sym in symbols]
print(fyers_symbols[:10])  # Preview the first 10
pd.Series(fyers_symbols).to_csv("fyers_symbols_list.csv", index=False, header=False)

# %%
import yfinance as yf
import pandas as pd
import time

# Load your CSV file
df = pd.read_csv("/content/2000_STOCKS_list.csv")
symbols = df['SYMBOL'].tolist()

# Append '.NS' to all symbols (assuming NSE)
symbols_ns = [sym + ".NS" for sym in symbols]

market_caps = []

for sym in symbols_ns:
    try:
        ticker = yf.Ticker(sym)
        info = ticker.info
        mc = info.get('marketCap', None)
        market_caps.append(mc)
    except:
        market_caps.append(None)
    time.sleep(0.5)  # polite scraping

# Add market cap column to original dataframe
df['MARKET_CAP'] = market_caps

# Convert to crores and filter
df['MARKET_CAP_CR'] = df['MARKET_CAP'] / 1e7  # ₹10 million = ₹1 crore
filtered_df_yahoo = df[df['MARKET_CAP_CR'] > 2000]
filtered_df_yahoo
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1-168753962.py in <cell line: 0>()
#      20     except:
#      21         market_caps.append(None)
# ---> 22     time.sleep(0.5)  # polite scraping
#      23
#      24 # Add market cap column to original dataframe
#
# KeyboardInterrupt:

# %%
filtered_df.to_csv("stocks_above_2kcr.csv", index=False)

print("✅ Done! Filtered stocks saved to 'stocks_above_2kcr.csv'")

# %% [markdown]
# # Backtesting

# %%
import pandas as pd
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dVRkQKGhrninZO8WxjXO4wC_ZKiruGxNrtcGwHS7FsE"

# Replace this with your list of symbols
fyers_symbols = fyers_symbols_filtered

#dates_to_backtest = ["2025-06-26", "2025-06-27", "2025-06-30", "2025-07-01"]
#dates_to_backtest = ["2025-06-30"]
dates_to_backtest = ["2025-06-27", "2025-06-30", "2025-07-01"]

# Initialize Fyers API
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# Store all trades
all_trades = []

for date in dates_to_backtest:
    print(f"\n📅 Backtesting for date: {date}")

    for symbol in fyers_symbols:
        print(f"🔍 Checking: {symbol}")

        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                print(f"❌ Failed to fetch {symbol}: {data}")
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df.dropna(inplace=True)

            trade_entered = False

            for i in range(len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("11:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume, ema_9 = row["open"], row["close"], row["volume"], row["ema_9"]
                move_pct = (close - open_) / open_

                # Turnover check
                turnover = close * volume
                if turnover < 1e7:
                    continue

                # New condition: Bullish + SL (open) must be above EMA
                if move_pct >= 0.01 and open_ > ema_9:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break

                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

            time.sleep(0.1)

        except Exception as e:
            print(f"⚠️ Error in {symbol}: {e}")
            continue

# Save results to CSV
results_df = pd.DataFrame(all_trades)
#results_df.to_csv("filtered_bullish_strategy_results.csv", index=False)
print("\n✅ Backtest Complete. Total trades:", len(results_df))
# Out:
# 📅 Backtesting for date: 2025-06-27
#
# 📅 Backtesting for date: 2025-06-30
#
# 📅 Backtesting for date: 2025-07-01
#
# ✅ Backtest Complete. Total trades: 0

# %%
results_df.to_csv("3_days_after_changes.csv", index=False)

# %%
import pandas as pd
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dU0oRZk2iGQD3GjRTQOZG6uFW0f6Yv3_2I1xYog--A4"

fyers_symbols = fyers_symbols_filtered
#dates_to_backtest = ["2025-06-26", "2025-06-27", "2025-06-30", "2025-07-01"]
dates_to_backtest = ["2025-06-24"]


fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)
all_trades = []

for date in dates_to_backtest:
    print(f"\n📅 Backtesting for date: {date}")

    for symbol in fyers_symbols:
        print(f"🔍 Checking: {symbol}")

        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                print(f"❌ Failed to fetch {symbol}: {data}")
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)

            # Calculate EMA
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            trade_entered = False

            for i in range(len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("11:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                # Avg volume liquidity check
                if i < 5:
                    continue
                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 5e6:
                    continue

                # Trade condition: bullish move + open > EMA 9 and EMA 20
                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    # Trailing SL
                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break

                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

            time.sleep(0)

        except Exception as e:
            print(f"⚠️ Error in {symbol}: {e}")
            continue

# Final output
results_df = pd.DataFrame(all_trades)
#results_df.to_csv("liquidity_filtered_bullish_strategy.csv", index=False)

# ✅ Total net return
total_return = results_df["pnl_%"].sum()
print("\n✅ Backtest Complete. Total trades:", len(results_df))
print("📈 Net % Return from strategy:", round(total_return, 2), "%")
print(results_df)
# Out:
# 📅 Backtesting for date: 2025-06-24
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-8-2885121649.py in <cell line: 0>()
#     123
#     124 # ✅ Total net return
# --> 125 total_return = results_df["pnl_%"].sum()
#     126 print("\n✅ Backtest Complete. Total trades:", len(results_df))
#     127 print("📈 Net % Return from strategy:", round(total_return, 2), "%")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'pnl_%'

# %%
results_df
# Out:
#          date             symbol              trigger_time  \
# 0  2025-06-24  NSE:CARBORUNIV-EQ 2025-06-24 11:45:00+05:30
# 1  2025-06-24   NSE:GEOJITFSL-EQ 2025-06-24 11:45:00+05:30
# 2  2025-06-24     NSE:J&KBANK-EQ 2025-06-24 11:30:00+05:30
# 3  2025-06-24   NSE:LLOYDSENT-EQ 2025-06-24 11:05:00+05:30
# 4  2025-06-24     NSE:LTFOODS-EQ 2025-06-24 11:25:00+05:30
# 5  2025-06-24   NSE:MUKANDLTD-EQ 2025-06-24 12:55:00+05:30
# 6  2025-06-24    NSE:NORTHARC-EQ 2025-06-24 12:50:00+05:30
# 7  2025-06-24     NSE:PVRINOX-EQ 2025-06-24 11:00:00+05:30
# 8  2025-06-24   NSE:SERVOTECH-EQ 2025-06-24 12:20:00+05:30
#
#                  entry_time  entry_price                 exit_time  \
# 0 2025-06-24 11:50:00+05:30       959.15 2025-06-24 12:40:00+05:30
# 1 2025-06-24 11:50:00+05:30        84.01 2025-06-24 12:40:00+05:30
# 2 2025-06-24 11:35:00+05:30       109.60 2025-06-24 12:20:00+05:30
# 3 2025-06-24 11:10:00+05:30        76.76 2025-06-24 11:40:00+05:30
# 4 2025-06-24 11:30:00+05:30       423.85 2025-06-24 12:25:00+05:30
# 5 2025-06-24 13:00:00+05:30       136.87 2025-06-24 13:05:00+05:30
# 6 2025-06-24 12:55:00+05:30       238.25 2025-06-24 13:20:00+05:30
# 7 2025-06-24 11:05:00+05:30       979.10 2025-06-24 12:55:00+05:30
# 8 2025-06-24 12:25:00+05:30       152.86 2025-06-24 12:40:00+05:30
#
#    exit_price  pnl_%
# 0    949.3000  -1.03
# 1     83.4966  -0.61
# 2    108.5040  -1.00
# 3     75.5500  -1.58
# 4    443.2725   4.58
# 5    135.5013  -1.00
# 6    236.1744  -0.87
# 7    965.4500  -1.39
# 8    151.3908  -0.96

# %%
results_df
# Out:
#           date             symbol              trigger_time  \
# 0   2025-06-25       NSE:AKUMS-EQ 2025-06-25 14:10:00+05:30
# 1   2025-06-25    NSE:BAJAJCON-EQ 2025-06-25 13:15:00+05:30
# 2   2025-06-25         NSE:BBL-EQ 2025-06-25 11:25:00+05:30
# 3   2025-06-25    NSE:EIDPARRY-EQ 2025-06-25 13:50:00+05:30
# 4   2025-06-25       NSE:EMBDL-EQ 2025-06-25 11:30:00+05:30
# 5   2025-06-25      NSE:EXICOM-EQ 2025-06-25 14:00:00+05:30
# 6   2025-06-25      NSE:FINOPB-EQ 2025-06-25 13:50:00+05:30
# 19 2025-07-01 13:05:00+05:30      1441.90 2025-07-01 13:15:00+05:30
# 20 2025-07-01 12:35:00+05:30        32.80 2025-07-01 09:15:00+05:30
# 21 2025-07-01 12:50:00+05:30      1085.75 2025-07-01 13:05:00+05:30
#
#     exit_price  pnl_%
# 0     819.0765   1.84
# 1     543.5100   0.01
# 2     666.4500  -1.24
# 3    6791.4000   0.46
# 4     225.7500  -1.01
# 5     240.6100  -0.98
# 6      70.0425   0.28
# 7      61.2810   5.78
# 8     613.7010   2.82
# 9     422.8290   0.02
# 10    282.5460  -0.23
# 11    273.3390  -0.51
# 12    237.6594   1.18
# 13     12.9393   1.01
# 14    803.9295  -0.95
# 15    131.7900  -1.35
# 16    224.0000  -1.03
# 17     27.0864   0.66
# 18    583.2500  -1.34
# 19   1425.8000  -1.12
# 20     32.6799  -0.37
# 21   1078.8525  -0.64

# %%
import pandas as pd
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dVRkQKGhrninZO8WxjXO4wC_ZKiruGxNrtcGwHS7FsE"
fyers_symbols = fyers_symbols_filtered  # Make sure this variable is defined
dates_to_backtest = ["2025-06-26", "2025-06-27", "2025-06-30", "2025-07-01","2025-07-02"]

fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)
all_trades = []

for date in dates_to_backtest:
    print(f"\n📅 Backtesting for date: {date}")
    daily_pnl = 0
    trade_details = []

    for symbol in fyers_symbols:
        print(f"🔍 Checking: {symbol}")

        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                print(f"❌ Failed to fetch {symbol}: {data}")
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("12:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                # 🛑 Skip if already moved >6% from 9:15 avg
                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.06:
                    continue

                # 🛑 Turnover filter for illiquid stocks
                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 5e6:
                    continue

                # ✅ Entry conditions
                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            trade_details.append(pnl)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

            time.sleep(0)

        except Exception as e:
            print(f"⚠️ Error in {symbol}: {e}")
            continue

    # Summary for the day
    bins = [float('-inf'), -1, 0, 1, 2, 3, 4, float('inf')]
    labels = ["<-1%", "-1 to 0%", "0 to 1%", "1 to 2%", "2 to 3%", "3 to 4%", ">4%"]
    bin_counts = pd.cut(trade_details, bins=bins, labels=labels).value_counts().sort_index()

    total_trades = len(trade_details)
    profit_trades = sum(p > 0 for p in trade_details)
    loss_trades = total_trades - profit_trades

    print(f"\n📊 {date} → Net Return: {round(daily_pnl, 2)}%")
    print(f"   📈 Trades Taken: {total_trades} | ✅ Profitable: {profit_trades} | ❌ Loss: {loss_trades}")
    print("   🔍 Return Distribution:")
    for label in labels:
        print(f"      {label}: {bin_counts.get(label, 0)}")

# Final Output
results_df = pd.DataFrame(all_trades)
print("\n📋 Detailed Trades:")
print(results_df)
# Optionally save
# results_df.to_csv("backtest_results.csv", index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# 🔍 Checking: NSE:CDSL-EQ
# 🔍 Checking: NSE:CEATLTD-EQ
# 🔍 Checking: NSE:CEIGALL-EQ
# 🔍 Checking: NSE:CELLO-EQ
# 🔍 Checking: NSE:CENTENKA-EQ
# 🔍 Checking: NSE:CENTRALBK-EQ
# 🔍 Checking: NSE:CENTUM-EQ
# 🔍 Checking: NSE:CENTURYPLY-EQ
# 🔍 Checking: NSE:CERA-EQ
# 🔍 Checking: NSE:CESC-EQ
# 🔍 Checking: NSE:CEWATER-EQ
# 🔍 Checking: NSE:CGCL-EQ
# 32 2025-07-02 12:25:00+05:30      1271.10 2025-07-02 15:25:00+05:30
# 33 2025-07-02 14:20:00+05:30       655.80 2025-07-02 14:30:00+05:30
# 34 2025-07-02 13:40:00+05:30       157.96 2025-07-02 13:55:00+05:30
# 35 2025-07-02 13:50:00+05:30       429.00 2025-07-02 14:40:00+05:30
# 36 2025-07-02 12:35:00+05:30       157.29 2025-07-02 12:50:00+05:30
# 37 2025-07-02 14:20:00+05:30       907.55 2025-07-02 14:25:00+05:30
# 38 2025-07-02 13:15:00+05:30       966.00 2025-07-02 13:25:00+05:30
# 39 2025-07-02 13:10:00+05:30      1472.10 2025-07-02 13:20:00+05:30
#
#     exit_price  pnl_%
# 0     157.3605  -0.90
# 1      64.4094   3.42
# 2     243.4400  -1.45
# 3     346.3000  -0.73
# 4     211.1373   0.07
# 5      26.1459   0.72
# 6     338.2500  -1.08
# 7      64.3800  -0.36
# 8    2418.1740  10.07
# 9      71.2107   3.84
# 10    887.8320  -0.94
# 11   4833.6750  -0.49
# 12     41.4000  -1.05
# 13    623.8000  -1.38
# 14    328.5500  -1.19
# 15    110.2365   1.49
# 16   2495.9000   2.12
# 17    137.6298   0.86
# 18    702.9990   7.99
# 19   2091.5730  -0.64
# 20   9199.5000   3.03
# 21    819.0765   1.84
# 22    543.3500  -0.77
# 23    666.4500  -1.24
# 24    225.7500  -1.01
# 25    282.9000  -0.11
# 26    237.6594   1.18
# 27    133.0200  -0.43
# 28    586.1000  -0.85
# 29     32.9000   0.30
# 30    205.6000  -1.15
# 31    826.8975   2.69
# 32   1259.6760  -0.90
# 33    656.2215   0.06
# 34    168.1812   6.47
# 35    427.6800  -0.31
# 36    158.2020   0.58
# 37    896.5500  -1.21
# 38    972.1305   0.63
# 39   1457.0000  -1.03

# %%
import pandas as pd
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dVRkQKGhrninZO8WxjXO4wC_ZKiruGxNrtcGwHS7FsE"
fyers_symbols = fyers_symbols_filtered  # Make sure this variable is defined
dates_to_backtest = ["2025-07-02"]

fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)
all_trades = []

for date in dates_to_backtest:
    print(f"\n📅 Backtesting for date: {date}")
    daily_pnl = 0
    trade_details = []

    for symbol in fyers_symbols:
        print(f"🔍 Checking: {symbol}")

        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                print(f"❌ Failed to fetch {symbol}: {data}")
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("11:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                # 🛑 Skip if already moved >6% from 9:15 avg
                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.06:
                    continue

                # 🛑 Turnover filter for illiquid stocks
                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 5e6:
                    continue

                # ✅ Entry conditions
                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            trade_details.append(pnl)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

            time.sleep(0)

        except Exception as e:
            print(f"⚠️ Error in {symbol}: {e}")
            continue

    # Summary for the day
    bins = [float('-inf'), -1, 0, 1, 2, 3, 4, float('inf')]
    labels = ["<-1%", "-1 to 0%", "0 to 1%", "1 to 2%", "2 to 3%", "3 to 4%", ">4%"]
    bin_counts = pd.cut(trade_details, bins=bins, labels=labels).value_counts().sort_index()

    total_trades = len(trade_details)
    profit_trades = sum(p > 0 for p in trade_details)
    loss_trades = total_trades - profit_trades

    print(f"\n📊 {date} → Net Return: {round(daily_pnl, 2)}%")
    print(f"   📈 Trades Taken: {total_trades} | ✅ Profitable: {profit_trades} | ❌ Loss: {loss_trades}")
    for symbol in fyers_symbols:
        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("12:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.06:
                    continue

                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 5e6:
                    continue

                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            trade_details.append(pnl)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

        except Exception as e:
            continue

    capital *= (1 + daily_pnl / 100)
    capital_curve.append(round(capital, 2))
    daily_returns.append(round(daily_pnl, 2))

# Plotting the equity curve
plt.figure(figsize=(12, 6))
plt.plot([initial_capital] + daily_returns, label="Daily Returns (%)", color="gray", linestyle="--", alpha=0.4)
plt.plot(capital_curve, label="Capital Over Time (₹)", color="blue", linewidth=2)
plt.title("Portfolio Growth (Starting with ₹1,00,000 in June 2025)")
plt.xlabel("Trading Days")
plt.ylabel("Portfolio Value (₹)")
plt.xticks(range(len(dates_to_backtest)+1), ["Start"] + dates_to_backtest, rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print final summary
print(f"\n💼 Final Portfolio Value: ₹{round(capital, 2)}")
print("📊 Daily Returns (%):", daily_returns)

# Optional: Save trades
results_df = pd.DataFrame(all_trades)
# results_df.to_csv("june_backtest_trades.csv", index=False)
# Out:
# 💼 Final Portfolio Value: ₹96011.96
# 📊 Daily Returns (%): [np.float64(1.19), np.float64(-3.97), np.float64(5.95), np.float64(-3.05), np.float64(6.28), np.float64(-5.83), np.float64(-9.61), np.float64(-2.86), np.float64(-5.28), np.float64(0.9), np.float64(-0.57), np.float64(0.72), np.float64(-2.03), np.float64(-1.9), np.float64(-3.15), np.float64(-1.43), np.float64(-0.87), np.float64(0.77), np.float64(0.34), np.float64(9.7), np.float64(13.36)]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dYXtFS4S_dcSxuwsZNneAfltKzuKeG2BI43ALsAFheQ"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# Define trading days in June 2025
'''dates_to_backtest = [
    "2025-05-02", "2025-05-05", "2025-05-06", "2025-05-07", "2025-05-08",
    "2025-05-09", "2025-05-12", "2025-05-13", "2025-05-14", "2025-05-15",
    "2025-05-16", "2025-05-19", "2025-05-20", "2025-05-21", "2025-05-22",
    "2025-05-23", "2025-05-26", "2025-05-27", "2025-05-28", "2025-05-29",
    "2025-05-30"
]'''

dates_to_backtest = ["2025-07-03"]
# List of symbols you want to test
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined in your code

initial_capital = 100000
capital = initial_capital
capital_curve = [capital]
daily_returns = []

all_trades = []

for date in dates_to_backtest:
    daily_pnl = 0
    trade_details = []

    for symbol in fyers_symbols:
        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("12:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.06:
                    continue

                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 5e6:
                    continue

                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            trade_details.append(pnl)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

        except Exception as e:
            continue

    capital *= (1 + daily_pnl / 100)
    capital_curve.append(round(capital, 2))
    daily_returns.append(round(daily_pnl, 2))

# Plotting the equity curve
plt.figure(figsize=(12, 6))
plt.plot([initial_capital] + daily_returns, label="Daily Returns (%)", color="gray", linestyle="--", alpha=0.4)
plt.plot(capital_curve, label="Capital Over Time (₹)", color="blue", linewidth=2)
plt.title("Portfolio Growth (Starting with ₹1,00,000 in June 2025)")
plt.xlabel("Trading Days")
plt.ylabel("Portfolio Value (₹)")
plt.xticks(range(len(dates_to_backtest)+1), ["Start"] + dates_to_backtest, rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print final summary
print(f"\n💼 Final Portfolio Value: ₹{round(capital, 2)}")
print("📊 Daily Returns (%):", daily_returns)

# Optional: Save trades
results_df = pd.DataFrame(all_trades)
results_df
# Out:
# 💼 Final Portfolio Value: ₹96210.0
# 📊 Daily Returns (%): [np.float64(-3.79)]
#           date             symbol              trigger_time  \
# 0   2025-07-03      NSE:ARKADE-EQ 2025-07-03 13:10:00+05:30
# 1   2025-07-03     NSE:GABRIEL-EQ 2025-07-03 13:05:00+05:30
# 2   2025-07-03     NSE:HUBTOWN-EQ 2025-07-03 12:40:00+05:30
# 3   2025-07-03  NSE:KIRLOSBROS-EQ 2025-07-03 14:10:00+05:30
# 4   2025-07-03     NSE:KPRMILL-EQ 2025-07-03 12:05:00+05:30
# 5   2025-07-03   NSE:LLOYDSENT-EQ 2025-07-03 13:30:00+05:30
# 6   2025-07-03    NSE:RATEGAIN-EQ 2025-07-03 12:35:00+05:30
# 7   2025-07-03  NSE:SCODATUBES-EQ 2025-07-03 12:30:00+05:30
# 8   2025-07-03  NSE:SHARDACROP-EQ 2025-07-03 13:00:00+05:30
# 9   2025-07-03    NSE:SMLISUZU-EQ 2025-07-03 12:25:00+05:30
# 10  2025-07-03  NSE:TRANSRAILL-EQ 2025-07-03 12:35:00+05:30
# 11  2025-07-03  NSE:WOCKPHARMA-EQ 2025-07-03 12:10:00+05:30
#
#                   entry_time  entry_price                 exit_time  \
# 0  2025-07-03 13:15:00+05:30       198.63 2025-07-03 13:50:00+05:30
# 1  2025-07-03 13:10:00+05:30       952.30 2025-07-03 13:15:00+05:30
# 2  2025-07-03 12:45:00+05:30       269.00 2025-07-03 12:50:00+05:30
# 3  2025-07-03 14:15:00+05:30      2274.00 2025-07-03 14:30:00+05:30
# 4  2025-07-03 12:10:00+05:30      1169.00 2025-07-03 12:20:00+05:30
# 5  2025-07-03 13:35:00+05:30        88.34 2025-07-03 14:20:00+05:30
# 6  2025-07-03 12:40:00+05:30       471.25 2025-07-03 13:00:00+05:30
# 7  2025-07-03 12:35:00+05:30       203.00 2025-07-03 13:10:00+05:30
# 8  2025-07-03 13:05:00+05:30       896.60 2025-07-03 14:00:00+05:30
# 9  2025-07-03 12:30:00+05:30      2419.60 2025-07-03 13:20:00+05:30
# 10 2025-07-03 12:40:00+05:30       726.40 2025-07-03 13:05:00+05:30
# 11 2025-07-03 12:15:00+05:30      1725.30 2025-07-03 14:30:00+05:30
#
#     exit_price  pnl_%
# 0     195.4000  -1.63
# 1     942.7770  -1.00
# 2     265.6500  -1.25
# 3    2256.1110  -0.79
# 4    1157.0000  -1.03
# 5      88.9020   0.64
# 6     468.2205  -0.64
# 7     202.5243  -0.23
# 8     911.6910   1.68
# 9    2407.5810  -0.50
# 10    727.4025   0.14
# 11   1739.4300   0.82

# %%
import pandas as pd
import matplotlib.pyplot as plt
from fyers_apiv3 import fyersModel
import time

# Fyers credentials
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dYXtFS4S_dcSxuwsZNneAfltKzuKeG2BI43ALsAFheQ"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# Dates to backtest
dates_to_backtest = [
    "2025-05-02", "2025-05-05", "2025-05-06", "2025-05-07", "2025-05-08",
    "2025-05-09", "2025-05-12", "2025-05-13", "2025-05-14", "2025-05-15",
    "2025-05-16", "2025-05-19", "2025-05-20", "2025-05-21", "2025-05-22",
    "2025-05-23", "2025-05-26", "2025-05-27", "2025-05-28", "2025-05-29",
    "2025-05-30"
]

# List of symbols to backtest
fyers_symbols = fyers_symbols_filtered  # You must define this list before running

# Initial portfolio setup
initial_capital = 100000
capital = initial_capital
capital_curve = [capital]
daily_returns = []
all_trades = []

# Main backtest loop
for date in dates_to_backtest:
    daily_pnl = 0
    trade_details = []

    print(f"\n🔄 Processing date: {date}")

    for symbol in fyers_symbols:
        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("12:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.06:
                    continue

                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 5e6:
                    continue

                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            trade_details.append(pnl)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])

                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

        except Exception as e:
            continue

    # Update capital
    capital *= (1 + daily_pnl / 100)
    capital_curve.append(round(capital, 2))
    daily_returns.append(round(daily_pnl, 2))

    # Show daily summary
    print(f"✅ Finished: {date}")
    print(f"📈 Daily Return (%): {round(daily_pnl, 2)}")
    print(f"📝 Trades Taken: {len(trade_details)}")

    if trade_details:
        daily_trades_df = pd.DataFrame([trade for trade in all_trades if trade["date"] == date])
        display(daily_trades_df)

    # Save backups after each day
    '''pd.DataFrame(all_trades).to_csv("trades_backup.csv", index=False)
    pd.DataFrame({
        "Date": ["Start"] + dates_to_backtest[:len(daily_returns)],
        "Capital": capital_curve
    }).to_csv("capital_curve_backup.csv", index=False)'''

# Plot the capital growth
plt.figure(figsize=(12, 6))
plt.plot([initial_capital] + daily_returns, label="Daily Returns (%)", color="gray", linestyle="--", alpha=0.4)
plt.plot(capital_curve, label="Capital Over Time (₹)", color="blue", linewidth=2)
plt.title("Portfolio Growth (Starting with ₹1,00,000 in June 2025)")
plt.xlabel("Trading Days")
plt.ylabel("Portfolio Value (₹)")
plt.xticks(range(len(dates_to_backtest)+1), ["Start"] + dates_to_backtest, rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Final results
print(f"\n💼 Final Portfolio Value: ₹{round(capital, 2)}")
print("📊 Daily Returns (%):", daily_returns)

# Output all trades as final result
results_df = pd.DataFrame(all_trades)
results_df
# Out:
# 🔄 Processing date: 2025-05-02
# ✅ Finished: 2025-05-02
# 📈 Daily Return (%): -2.46
# 📝 Trades Taken: 3
#          date             symbol              trigger_time  \
# 0  2025-05-02     NSE:GRAVITA-EQ 2025-05-02 13:50:00+05:30
# 1  2025-05-02  NSE:SHAKTIPUMP-EQ 2025-05-02 13:20:00+05:30
# 2  2025-05-02      NSE:TIMKEN-EQ 2025-05-02 13:00:00+05:30
#
#                  entry_time  entry_price                 exit_time  \
# 0 2025-05-02 13:55:00+05:30       1828.3 2025-05-02 14:25:00+05:30
# 1 2025-05-02 13:25:00+05:30        865.7 2025-05-02 13:35:00+05:30
# 2 2025-05-02 13:05:00+05:30       2588.0 2025-05-02 13:20:00+05:30
#
#    exit_price  pnl_%
# 0     1804.90  -1.28
# 1      856.50  -1.06
# 2     2584.89  -0.12
# 🔄 Processing date: 2025-05-05
# ✅ Finished: 2025-05-05
# 📈 Daily Return (%): -2.21
# 📝 Trades Taken: 6
#          date             symbol              trigger_time  \
# 0  2025-05-05    NSE:CARTRADE-EQ 2025-05-05 12:10:00+05:30
# 1  2025-05-05  NSE:DATAPATTNS-EQ 2025-05-05 13:00:00+05:30
# 2  2025-05-05  NSE:MOTILALOFS-EQ 2025-05-05 12:50:00+05:30
# 3  2025-05-05  NSE:POONAWALLA-EQ 2025-05-05 13:40:00+05:30
# 4  2025-05-05  NSE:QUADFUTURE-EQ 2025-05-05 14:30:00+05:30
# 5  2025-05-05      NSE:TIMKEN-EQ 2025-05-05 14:25:00+05:30
#
#                  entry_time  entry_price                 exit_time  \
# 0 2025-05-05 12:15:00+05:30      1831.70 2025-05-05 13:10:00+05:30
# 1 2025-05-05 13:05:00+05:30      2300.00 2025-05-05 13:10:00+05:30
# 2 2025-05-05 12:55:00+05:30       676.60 2025-05-05 13:55:00+05:30
# 3 2025-05-05 13:45:00+05:30       393.95 2025-05-05 13:55:00+05:30
# 4 2025-05-05 14:35:00+05:30       477.95 2025-05-05 14:40:00+05:30
# 5 2025-05-05 14:30:00+05:30      2675.60 2025-05-05 15:10:00+05:30
#
#    exit_price  pnl_%
# 5 2025-05-19 12:10:00+05:30        63.70 2025-05-19 12:45:00+05:30
# 6 2025-05-19 12:25:00+05:30       185.52 2025-05-19 12:30:00+05:30
# 7 2025-05-19 12:20:00+05:30      1135.80 2025-05-19 12:30:00+05:30
# 8 2025-05-19 12:15:00+05:30        32.66 2025-05-19 13:05:00+05:30
#
#    exit_price  pnl_%
# 0    995.6925   1.55
# 1    661.8150  -0.93
# 2    113.0778  -0.49
# 3     39.9564  -0.98
# 4     60.4692  -1.00
# 5     64.7361   1.63
# 6    183.6648  -1.00
# 7   1122.8000  -1.14
# 8     32.6007  -0.18
# 🔄 Processing date: 2025-05-20
# ✅ Finished: 2025-05-20
# 📈 Daily Return (%): 1.69
# 📝 Trades Taken: 1
#          date        symbol              trigger_time  \
# 0  2025-05-20  NSE:DODLA-EQ 2025-05-20 12:25:00+05:30
#
#                  entry_time  entry_price                 exit_time  \
# 0 2025-05-20 12:30:00+05:30       1197.8 2025-05-20 12:50:00+05:30
#
#    exit_price  pnl_%
# 0    1218.096   1.69
# 🔄 Processing date: 2025-05-21
# ✅ Finished: 2025-05-21
# 📈 Daily Return (%): 0.79
# 📝 Trades Taken: 3
#          date         symbol              trigger_time  \
# 0  2025-05-21     NSE:PFC-EQ 2025-05-21 13:15:00+05:30
# 1  2025-05-21   NSE:TATVA-EQ 2025-05-21 13:45:00+05:30
# 2  2025-05-21  NSE:ZENTEC-EQ 2025-05-21 12:55:00+05:30
#
#                  entry_time  entry_price                 exit_time  \
# 0 2025-05-21 13:20:00+05:30        415.5 2025-05-21 13:40:00+05:30
# 1 2025-05-21 13:50:00+05:30        941.0 2025-05-21 15:10:00+05:30
# 2 2025-05-21 13:00:00+05:30       1913.0 2025-05-21 13:05:00+05:30
#
#    exit_price  pnl_%
# 0     414.711  -0.19
# 1     959.607   1.98
# 2    1893.870  -1.00
# 🔄 Processing date: 2025-05-22
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-12-44195052.py in <cell line: 0>()
#      45                 "cont_flag": "1"
#      46             }
# ---> 47             data = fyers.history(payload)
#      48             if data["s"] != "ok":
#      49                 continue
#
# /usr/local/lib/python3.11/dist-packages/fyers_apiv3/fyersModel.py in history(self, data)
#    1061
#    1062         else:
# -> 1063             response = self.service.get_call(
#    1064                 Config.history, self.header, data, data_flag=True
#    1065             )
#
# /usr/local/lib/python3.11/dist-packages/fyers_apiv3/fyersModel.py in get_call(self, api, header, data, data_flag)
#     130                 url_params = urllib.parse.urlencode(data)
#     131                 URL = URL + "?" + url_params
# --> 132             response = requests.get(
#     133                 url=URL,
#     134                 headers={
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     462             # Trigger any extra validation we need to do.
#     463             try:
# --> 464                 self._validate_conn(conn)
#     465             except (SocketTimeout, BaseSSLError) as e:
#     466                 self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1091         # Force connect early to allow us to validate the connection.
#    1092         if conn.is_closed:
# -> 1093             conn.connect()
#    1094
#    1095         # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in connect(self)
#     739             server_hostname_rm_dot = server_hostname.rstrip(".")
#     740
# --> 741             sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     742                 sock=sock,
#     743                 cert_reqs=self.cert_reqs,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     918             server_hostname = normalized
#     919
# --> 920     ssl_sock = ssl_wrap_socket(
#     921         sock=sock,
#     922         keyfile=key_file,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     478     context.set_alpn_protocols(ALPN_PROTOCOLS)
#     479
# --> 480     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     481     return ssl_sock
#     482
#
# /usr/local/lib/python3.11/dist-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     522         return SSLTransport(sock, ssl_context, server_hostname)
#     523
# --> 524     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# /usr/lib/python3.11/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     515         # SSLSocket class handles server_hostname encoding before it calls
#     516         # ctx._wrap_socket()
# --> 517         return self.sslsocket_class._create(
#     518             sock=sock,
#     519             server_side=server_side,
#
# /usr/lib/python3.11/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1102                         # non-blocking
#    1103                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104                     self.do_handshake()
#    1105         except:
#    1106             try:
#
# /usr/lib/python3.11/ssl.py in do_handshake(self, block)
#    1380             if timeout == 0.0 and block:
#    1381                 self.settimeout(None)
# -> 1382             self._sslobj.do_handshake()
#    1383         finally:
#    1384             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
#JUNE AFTER CHANGES
import pandas as pd
import matplotlib.pyplot as plt
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....cO6-U96MD0KpHMDZW5lGoKQpTEpLG6d3-VyR3-PaqsU"  # Replace with valid access token
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# Define trading days in June 2025
dates_to_backtest = [
    "2025-06-02", "2025-06-03", "2025-06-04", "2025-06-05", "2025-06-06",
    "2025-06-09", "2025-06-10", "2025-06-11", "2025-06-12", "2025-06-13",
    "2025-06-16", "2025-06-17", "2025-06-18", "2025-06-19", "2025-06-20",
    "2025-06-23", "2025-06-24", "2025-06-25", "2025-06-26", "2025-06-27",
    "2025-06-30"
]

fyers_symbols = fyers_symbols_filtered  # Define this before running

initial_capital = 100000
capital = initial_capital
capital_curve = [capital]
daily_returns = []
all_trades = []

for date in dates_to_backtest:
    daily_pnl = 0
    trade_details = []

    for symbol in fyers_symbols:
        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok":
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("12:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close = row["open"], row["close"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_

                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.05:
                    continue

                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est
                if liquidity_turnover < 3e6:
                    continue

                # 🛑 Top Wick Filter
                if (row["high"] - row["close"]) >= 0.5 * abs(row["close"] - row["open"]):
                    continue

                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]

                    # 🛑 Inverted Red Candle Exit Check
                    if entry_candle["open"] > entry_candle["close"] and \
                       (entry_candle["open"] - entry_candle["close"]) < 0.3 * (entry_candle["high"] - entry_candle["low"]):
                        exit_price = df.iloc[i + 2]["open"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": df.iloc[i + 2].name,
                            "exit_price": exit_price,
                            "pnl_%": pnl,
                            "reason": "Inverted Red Candle"
                        })
                        trade_entered = True
                        break

                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            trade_details.append(pnl)
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl,
                                "reason": "SL Hit"
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])
                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        trade_details.append(pnl)
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl,
                            "reason": "End of Day Exit"
                        })
                        trade_entered = True

        except Exception as e:
            continue

    capital *= (1 + daily_pnl / 100)
    capital_curve.append(round(capital, 2))
    daily_returns.append(round(daily_pnl, 2))

    # ✅ Print daily summary
    print(f"\n📅 {date} Summary:")
    print(f"   📈 Trades Taken: {len(trade_details)}")
    print(f"   💰 Day's Return: {round(daily_pnl, 2)}%")
    if trade_details:
        print(f"   📋 Trades PnL: {trade_details}")

# 📈 Plot capital growth curve
plt.figure(figsize=(12, 6))
plt.plot([initial_capital] + daily_returns, label="Daily Returns (%)", color="gray", linestyle="--", alpha=0.4)
plt.plot(capital_curve, label="Capital Over Time (₹)", color="blue", linewidth=2)
plt.title("Portfolio Growth (Starting with ₹1,00,000 in June 2025)")
plt.xlabel("Trading Days")
plt.ylabel("Portfolio Value (₹)")
plt.xticks(range(len(dates_to_backtest)+1), ["Start"] + dates_to_backtest, rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# 📋 Print Final Summary
print(f"\n💼 Final Portfolio Value: ₹{round(capital, 2)}")
print("📊 Daily Returns (%):", daily_returns)

# 📁 Save all trade details if needed
results_df = pd.DataFrame(all_trades)

# results_df.to_csv("june_backtest_trades_with_filters.csv", index=False)
print("\n🔍 Exit Reason Summary:")
if not results_df.empty:
    reason_counts = results_df["reason"].value_counts()
    for reason, count in reason_counts.items():
        sub_df = results_df[results_df["reason"] == reason]
        wins = sub_df[sub_df["pnl_%"] > 0].shape[0]
        losses = sub_df[sub_df["pnl_%"] <= 0].shape[0]
        win_rate = round((wins / (wins + losses)) * 100, 2) if (wins + losses) > 0 else 0
        print(f"▶️ {reason}: {count} trades → ✅ Wins: {wins} | ❌ Losses: {losses} | 🏆 Win%: {win_rate}%")
else:
    print("No trades recorded.")

results_df
# Out:
# 📅 2025-06-02 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: -0.6%
#    📋 Trades PnL: [np.float64(2.39), np.float64(-1.52), np.float64(-0.31), np.float64(-1.16)]
#
# 📅 2025-06-03 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: 0.34%
#    📋 Trades PnL: [np.float64(0.56), np.float64(-0.22)]
#
# 📅 2025-06-04 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: 3.88%
#    📋 Trades PnL: [np.float64(-0.55), np.float64(-0.34), np.float64(-0.05), np.float64(-1.66), np.float64(6.41), np.float64(0.07)]
#
# 📅 2025-06-05 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: -0.6%
#    📋 Trades PnL: [np.float64(-0.98), np.float64(-0.15), np.float64(-1.18), np.float64(0.29), np.float64(1.34), np.float64(0.08)]
#
# 📅 2025-06-06 Summary:
#    📈 Trades Taken: 10
#    💰 Day's Return: 0.42%
#    📋 Trades PnL: [np.float64(-0.04), np.float64(0.87), np.float64(-0.36), np.float64(0.23), np.float64(-0.18), np.float64(-0.27), np.float64(-0.02), np.float64(-1.95), np.float64(1.4), np.float64(0.74)]
#
# 📅 2025-06-09 Summary:
#    📈 Trades Taken: 8
#    💰 Day's Return: -1.77%
#    📋 Trades PnL: [np.float64(-1.57), np.float64(-0.09), np.float64(0.73), np.float64(-1.8), np.float64(-0.01), np.float64(-0.86), np.float64(-0.43), np.float64(2.26)]
#
# 📅 2025-06-10 Summary:
#    📈 Trades Taken: 10
#    💰 Day's Return: -9.01%
#    📋 Trades PnL: [np.float64(-1.09), np.float64(-1.57), np.float64(-1.19), np.float64(-1.15), np.float64(-1.14), np.float64(-1.0), np.float64(-1.43), np.float64(0.69), np.float64(-1.06), np.float64(-0.07)]
#
# 📅 2025-06-11 Summary:
#    📈 Trades Taken: 10
#    💰 Day's Return: -0.1%
#    📋 Trades PnL: [np.float64(-0.1), np.float64(-0.02), np.float64(-0.66), np.float64(1.09), np.float64(0.25), np.float64(-0.19), np.float64(-0.77), np.float64(-0.14), np.float64(1.49), np.float64(-1.05)]
#
# 📅 2025-06-12 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: -3.59%
#    📋 Trades PnL: [np.float64(-0.98), np.float64(-0.03), np.float64(-1.0), np.float64(-0.56), np.float64(-0.27), np.float64(-0.65), np.float64(-0.1)]
#
# 📅 2025-06-13 Summary:
#    📈 Trades Taken: 5
#    💰 Day's Return: 3.56%
#    📋 Trades PnL: [np.float64(1.1), np.float64(-0.09), np.float64(1.28), np.float64(-0.13), np.float64(1.4)]
#
# 📅 2025-06-16 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: 2.84%
#    📋 Trades PnL: [np.float64(0.04), np.float64(2.8)]
#
# 📅 2025-06-17 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: 0.72%
#    📋 Trades PnL: [np.float64(0.72)]
#
# 📅 2025-06-18 Summary:
#    📈 Trades Taken: 3
#    💰 Day's Return: -2.79%
#    📋 Trades PnL: [np.float64(-1.12), np.float64(-0.23), np.float64(-1.44)]
#
# 📅 2025-06-19 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: -1.04%
#    📋 Trades PnL: [np.float64(0.69), np.float64(0.17), np.float64(-0.9), np.float64(-1.0)]
#
# 📅 2025-06-20 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: -1.88%
#    📋 Trades PnL: [np.float64(-1.05), np.float64(-0.83)]
#
# 📅 2025-06-23 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: -0.52%
#    📋 Trades PnL: [np.float64(-0.52), np.float64(0.0)]
#
# 📅 2025-06-24 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: -0.87%
#    📋 Trades PnL: [np.float64(-0.87)]
#
# 📅 2025-06-25 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: 1.72%
#    📋 Trades PnL: [np.float64(-1.46), np.float64(2.45), np.float64(0.9), np.float64(-0.17)]
#
# 📅 2025-06-26 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: 2.64%
#    📋 Trades PnL: [np.float64(2.35), np.float64(-0.07), np.float64(3.42), np.float64(-1.45), np.float64(-0.81), np.float64(-0.07), np.float64(-0.73)]
#
# 📅 2025-06-27 Summary:
#    📈 Trades Taken: 5
#    💰 Day's Return: 6.52%
#    📋 Trades PnL: [np.float64(0.07), np.float64(10.07), np.float64(-1.05), np.float64(-1.38), np.float64(-1.19)]
#
# 📅 2025-06-30 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: 9.41%
#    📋 Trades PnL: [np.float64(-0.42), np.float64(7.99), np.float64(-1.19), np.float64(3.03)]
# 💼 Final Portfolio Value: ₹108161.94
# 📊 Daily Returns (%): [np.float64(-0.6), np.float64(0.34), np.float64(3.88), np.float64(-0.6), np.float64(0.42), np.float64(-1.77), np.float64(-9.01), np.float64(-0.1), np.float64(-3.59), np.float64(3.56), np.float64(2.84), np.float64(0.72), np.float64(-2.79), np.float64(-1.04), np.float64(-1.88), np.float64(-0.52), np.float64(-0.87), np.float64(1.72), np.float64(2.64), np.float64(6.52), np.float64(9.41)]
#
# 🔍 Exit Reason Summary:
# ▶️ SL Hit: 72 trades → ✅ Wins: 25 | ❌ Losses: 47 | 🏆 Win%: 34.72%
# ▶️ Inverted Red Candle: 22 trades → ✅ Wins: 1 | ❌ Losses: 21 | 🏆 Win%: 4.55%
# ▶️ End of Day Exit: 9 trades → ✅ Wins: 7 | ❌ Losses: 2 | 🏆 Win%: 77.78%
#            date             symbol              trigger_time  \
# 0    2025-06-02    NSE:DBREALTY-EQ 2025-06-02 13:20:00+05:30
# 1    2025-06-02        NSE:IFCI-EQ 2025-06-02 13:15:00+05:30
# 2    2025-06-02        NSE:MTNL-EQ 2025-06-02 12:30:00+05:30
# 3    2025-06-02     NSE:POKARNA-EQ 2025-06-02 14:15:00+05:30
# 4    2025-06-03       NSE:NOCIL-EQ 2025-06-03 12:05:00+05:30
# ..          ...                ...                       ...
# 98   2025-06-27     NSE:SKYGOLD-EQ 2025-06-27 12:10:00+05:30
# 99   2025-06-30      NSE:PFOCUS-EQ 2025-06-30 13:35:00+05:30
# 100  2025-06-30     NSE:RAYMOND-EQ 2025-06-30 12:45:00+05:30
# 101  2025-06-30  NSE:STYLEBAAZA-EQ 2025-06-30 14:30:00+05:30
# 102  2025-06-30       NSE:WENDT-EQ 2025-06-30 12:45:00+05:30
#
#                    entry_time  entry_price                 exit_time  \
# 0   2025-06-02 13:25:00+05:30       197.24 2025-06-02 13:45:00+05:30
# 1   2025-06-02 13:20:00+05:30        68.95 2025-06-02 13:55:00+05:30
# 2   2025-06-02 12:35:00+05:30        50.41 2025-06-02 13:05:00+05:30
# 3   2025-06-02 14:20:00+05:30      1050.00 2025-06-02 15:00:00+05:30
# 4   2025-06-03 12:10:00+05:30       194.05 2025-06-03 12:50:00+05:30
# ..                        ...          ...                       ...
# 98  2025-06-27 12:15:00+05:30       332.50 2025-06-27 12:40:00+05:30
# 99  2025-06-30 13:40:00+05:30       136.45 2025-06-30 13:45:00+05:30
# 100 2025-06-30 12:50:00+05:30       651.00 2025-06-30 13:35:00+05:30
# 101 2025-06-30 14:35:00+05:30       314.00 2025-06-30 15:00:00+05:30
# 102 2025-06-30 12:50:00+05:30      8929.00 2025-06-30 15:25:00+05:30
#
#      exit_price  pnl_%               reason
# 0      201.9501   2.39               SL Hit
# 1       67.9000  -1.52               SL Hit
# 2       50.2524  -0.31               SL Hit
# 3     1037.8000  -1.16               SL Hit
# 4      195.1290   0.56               SL Hit
# ..          ...    ...                  ...
# 98     328.5500  -1.19               SL Hit
# 99     135.8800  -0.42  Inverted Red Candle
# 100    702.9990   7.99               SL Hit
# 101    310.2500  -1.19               SL Hit
# 102   9199.5000   3.03      End of Day Exit
#
# [103 rows x 9 columns]

# %% [markdown]
# # data fetching

# %%
'''import pandas as pd

# Load the CSV
df = pd.read_csv('/content/stocks_above_1kcr.csv')

# Convert MARKET_CAP_CR to numeric if it's not already
df['MARKET_CAP_CR'] = pd.to_numeric(df['MARKET_CAP_CR'], errors='coerce')

# Filter above 2000 Cr
above_3k = df[df['MARKET_CAP_CR'] > 3000]

# Filter above 5000 Cr
above_4k = df[df['MARKET_CAP_CR'] > 4000]

# Save to new CSV files
above_3k.to_csv('/content/stocks_above_3kcr.csv', index=False)
above_4k.to_csv('/content/stocks_above_4kcr.csv', index=False)

print("CSV files saved for >3k Cr and >4k Cr market cap.")'''

# %%
import pandas as pd
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....dYXtFS4S_dcSxuwsZNneAfltKzuKeG2BI43ALsAFheQ"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

dates_to_check =[
    "2025-06-02", "2025-06-03", "2025-06-04", "2025-06-05", "2025-06-06",
    "2025-06-09", "2025-06-10", "2025-06-11", "2025-06-12", "2025-06-13",
    "2025-06-16", "2025-06-17", "2025-06-18", "2025-06-19", "2025-06-20",
    "2025-06-23", "2025-06-24", "2025-06-25", "2025-06-26", "2025-06-27",
    "2025-06-30"
]
fyers_symbols = fyers_symbols_filtered  # Make sure this is defined

for date in dates_to_check:
    print(f"\n📅 {date} → Stocks with >1% move from 11:00AM to Close:\n")

    for symbol in fyers_symbols:
        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok" or len(data["candles"]) < 2:
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)

            # Get first candle after 11:00
            df_after_11 = df[df.index.time >= pd.to_datetime("11:00").time()]
            if df_after_11.empty:
                continue

            open_11am = df_after_11.iloc[0]["open"]
            close_last = df.iloc[-1]["close"]
            move_pct = ((close_last - open_11am) / open_11am) * 100

            if (move_pct) > 4:  # Use 1% for debug, increase to 4 or 5% later
                direction = "🔺" if move_pct > 0 else "🔻"
                print(f"{direction} {symbol} → {round(move_pct, 2)}%")

            time.sleep(0.01)  # Light delay for rate limits

        except Exception as e:
            # Uncomment for debugging
            # print(f"Error in {symbol}: {e}")
            continue
# Out:
# 📅 2025-06-02 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:APCOTEXIND-EQ → 4.8%
# 🔺 NSE:ASTRAZEN-EQ → 4.45%
# 🔺 NSE:AVANTEL-EQ → 6.66%
# 🔺 NSE:BRIGADE-EQ → 4.26%
# 🔺 NSE:CDSL-EQ → 6.59%
# 🔺 NSE:DBREALTY-EQ → 6.55%
# 🔺 NSE:FIEMIND-EQ → 4.68%
# 🔺 NSE:KRISHANA-EQ → 4.73%
# 🔺 NSE:MARATHON-EQ → 6.78%
# 🔺 NSE:MOL-EQ → 5.97%
# 🔺 NSE:NITINSPIN-EQ → 4.31%
# 🔺 NSE:OLAELEC-EQ → 5.85%
# 🔺 NSE:OMAXE-EQ → 5.19%
# 🔺 NSE:ORIENTHOT-EQ → 5.35%
# 🔺 NSE:PRECAM-EQ → 6.65%
# 🔺 NSE:REFEX-EQ → 4.73%
# 🔺 NSE:SANOFICONR-EQ → 5.63%
# 🔺 NSE:SINDHUTRAD-EQ → 9.26%
# 🔺 NSE:TCIEXP-EQ → 7.62%
#
# 📅 2025-06-03 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AEGISVOPAK-EQ → 4.95%
# 🔺 NSE:FACT-EQ → 4.16%
# 🔺 NSE:GKWLIMITED-EQ → 5.82%
# 🔺 NSE:JISLDVREQS-EQ → 4.26%
# 🔺 NSE:NITCO-EQ → 4.91%
# 🔺 NSE:SERVOTECH-EQ → 4.14%
# 🔺 NSE:SHREEPUSHK-EQ → 8.74%
# 🔺 NSE:STERTOOLS-EQ → 7.49%
# 🔺 NSE:VOLTAMP-EQ → 5.22%
#
# 📅 2025-06-04 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AETHER-EQ → 4.08%
# 🔺 NSE:ALLCARGO-EQ → 4.59%
# 🔺 NSE:CANTABIL-EQ → 4.83%
# 🔺 NSE:GLAXO-EQ → 4.84%
# 🔺 NSE:GOKULAGRO-EQ → 8.1%
# 🔺 NSE:HERITGFOOD-EQ → 4.2%
# 🔺 NSE:HINDWAREAP-EQ → 4.95%
# 🔺 NSE:INDOTECH-EQ → 5.21%
# 🔺 NSE:IRCON-EQ → 11.5%
# 🔺 NSE:IRMENERGY-EQ → 4.58%
# 🔺 NSE:JAICORPLTD-EQ → 4.35%
# 🔺 NSE:KRISHANA-EQ → 4.56%
# 🔺 NSE:LUMAXTECH-EQ → 5.05%
# 🔺 NSE:MARATHON-EQ → 4.17%
# 🔺 NSE:MMTC-EQ → 5.1%
# 🔺 NSE:MTNL-EQ → 4.64%
# 🔺 NSE:MVGJL-EQ → 10.91%
# 🔺 NSE:PURVA-EQ → 8.41%
# 🔺 NSE:QUICKHEAL-EQ → 12.1%
# 🔺 NSE:RAILTEL-EQ → 8.34%
# 🔺 NSE:RITES-EQ → 4.28%
# 🔺 NSE:RVNL-EQ → 4.03%
# 🔺 NSE:SMCGLOBAL-EQ → 5.6%
# 🔺 NSE:STEELCAS-EQ → 6.21%
# 🔺 NSE:STOVEKRAFT-EQ → 4.11%
# 🔺 NSE:SURYODAY-EQ → 4.11%
# 🔺 NSE:SWANENERGY-EQ → 7.72%
# 🔺 NSE:SWIGGY-EQ → 4.9%
# 🔺 NSE:TECHNOE-EQ → 4.93%
# 🔺 NSE:TEXINFRA-EQ → 4.46%
# 🔺 NSE:TEXRAIL-EQ → 4.26%
# 🔺 NSE:WAAREERTL-EQ → 4.85%
#
# 📅 2025-06-05 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:360ONE-EQ → 4.49%
# 🔺 NSE:ABDL-EQ → 4.79%
# 🔺 NSE:AGIIL-EQ → 4.66%
# 🔺 NSE:AVANTEL-EQ → 8.23%
# 🔺 NSE:BLISSGVS-EQ → 4.29%
# 🔺 NSE:COCHINSHIP-EQ → 14.19%
# 🔺 NSE:CREST-EQ → 4.57%
# 🔺 NSE:DCXINDIA-EQ → 4.93%
# 🔺 NSE:EIMCOELECO-EQ → 8.13%
# 🔺 NSE:GARUDA-EQ → 7.45%
# 🔺 NSE:HARIOMPIPE-EQ → 9.78%
# 🔺 NSE:HINDZINC-EQ → 5.24%
# 🔺 NSE:IMFA-EQ → 4.96%
# 🔺 NSE:MCLOUD-EQ → 4.64%
# 🔺 NSE:PARAS-EQ → 6.19%
# 🔺 NSE:POKARNA-EQ → 4.62%
# 🔺 NSE:PRECAM-EQ → 4.68%
# 🔺 NSE:SDBL-EQ → 4.44%
# 🔺 NSE:SRHHYPOLTD-EQ → 8.01%
# 🔺 NSE:SUPRAJIT-EQ → 5.84%
# 🔺 NSE:SURAJEST-EQ → 7.41%
# 🔺 NSE:TIPSMUSIC-EQ → 4.68%
# 🔺 NSE:UNIECOM-EQ → 4.27%
#
# 📅 2025-06-06 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AAVAS-EQ → 5.08%
# 🔺 NSE:ARKADE-EQ → 5.98%
# 🔺 NSE:ASTEC-EQ → 4.62%
# 🔺 NSE:BLKASHYAP-EQ → 4.55%
# 🔺 NSE:CHOLAHLDNG-EQ → 4.9%
# 🔺 NSE:DOLPHIN-EQ → 4.15%
# 🔺 NSE:GODIGIT-EQ → 6.43%
# 🔺 NSE:GODREJIND-EQ → 6.91%
# 🔺 NSE:HUBTOWN-EQ → 6.1%
# 🔺 NSE:ICICIGI-EQ → 5.16%
# 🔺 NSE:KIRIINDUS-EQ → 4.31%
# 🔺 NSE:KKCL-EQ → 5.08%
# 🔺 NSE:LLOYDSENT-EQ → 4.35%
# 🔺 NSE:MAHSCOOTER-EQ → 4.22%
# 🔺 NSE:MUFIN-EQ → 5.0%
# 🔺 NSE:MUFTI-EQ → 4.11%
# 🔺 NSE:MUTHOOTFIN-EQ → 5.25%
# 🔺 NSE:PRAKASH-EQ → 4.78%
# 🔺 NSE:QUICKHEAL-EQ → 5.58%
# 🔺 NSE:SELAN-EQ → 7.55%
# 🔺 NSE:STERTOOLS-EQ → 8.68%
# 🔺 NSE:TARC-EQ → 5.39%
# 🔺 NSE:WEALTH-EQ → 5.43%
# 🔺 NSE:WENDT-EQ → 4.06%
# 🔺 NSE:YATHARTH-EQ → 5.11%
#
# 📅 2025-06-09 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:ADFFOODS-EQ → 7.53%
# 🔺 NSE:AMBER-EQ → 4.41%
# 🔺 NSE:CANTABIL-EQ → 5.27%
# 🔺 NSE:CERA-EQ → 6.12%
# 🔺 NSE:CGCL-EQ → 4.66%
# 🔺 NSE:DAMCAPITAL-EQ → 4.09%
# 🔺 NSE:DLINKINDIA-EQ → 4.91%
# 🔺 NSE:GOCLCORP-EQ → 6.38%
# 🔺 NSE:GREENPOWER-EQ → 7.12%
# 🔺 NSE:GRINFRA-EQ → 4.57%
# 🔺 NSE:JISLJALEQS-EQ → 4.92%
# 🔺 NSE:JMFINANCIL-EQ → 4.26%
# 🔺 NSE:JPPOWER-EQ → 5.74%
# 🔺 NSE:JTLIND-EQ → 7.62%
# 🔺 NSE:KALAMANDIR-EQ → 4.62%
# 🔺 NSE:KKCL-EQ → 5.03%
# 🔺 NSE:KOKUYOCMLN-EQ → 7.19%
# 🔺 NSE:KRISHANA-EQ → 4.92%
# 🔺 NSE:MAITHANALL-EQ → 5.29%
# 🔺 NSE:MANAPPURAM-EQ → 4.04%
# 🔺 NSE:MOSCHIP-EQ → 4.14%
# 🔺 NSE:PREMEXPLN-EQ → 4.43%
# 🔺 NSE:QUADFUTURE-EQ → 4.02%
# 🔺 NSE:REFEX-EQ → 4.17%
# 🔺 NSE:RTNPOWER-EQ → 4.43%
# 🔺 NSE:SCODATUBES-EQ → 6.48%
# 🔺 NSE:SELAN-EQ → 7.34%
# 🔺 NSE:SKIPPER-EQ → 6.0%
# 🔺 NSE:SMCGLOBAL-EQ → 4.52%
# 🔺 NSE:SOMANYCERA-EQ → 11.8%
# 🔺 NSE:SPMLINFRA-EQ → 4.35%
# 🔺 NSE:SRM-EQ → 4.59%
# 🔺 NSE:TATVA-EQ → 4.08%
# 🔺 NSE:WEALTH-EQ → 4.91%
# 🔺 NSE:WESTLIFE-EQ → 9.2%
# 🔺 NSE:WINDMACHIN-EQ → 7.0%
# 🔺 NSE:ZAGGLE-EQ → 5.74%
#
# 📅 2025-06-10 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:ADANIPOWER-EQ → 5.01%
# 🔺 NSE:ADVENZYMES-EQ → 4.73%
# 🔺 NSE:ALOKINDS-EQ → 7.06%
# 🔺 NSE:BAJAJINDEF-EQ → 7.24%
# 🔺 NSE:BANCOINDIA-EQ → 8.28%
# 🔺 NSE:DBREALTY-EQ → 5.32%
# 🔺 NSE:DDEVPLSTIK-EQ → 4.19%
# 🔺 NSE:DPSCLTD-EQ → 4.38%
# 🔺 NSE:ECOSMOBLTY-EQ → 7.39%
# 🔺 NSE:ELECTCAST-EQ → 4.53%
# 🔺 NSE:FSL-EQ → 4.36%
# 🔺 NSE:GALLANTT-EQ → 4.12%
# 🔺 NSE:GEPIL-EQ → 12.31%
# 🔺 NSE:GREENPOWER-EQ → 5.81%
# 🔺 NSE:GTPL-EQ → 4.69%
# 🔺 NSE:INNOVANA-EQ → 4.8%
# 🔺 NSE:KMEW-EQ → 5.26%
# 🔺 NSE:NAVKARCORP-EQ → 5.03%
# 🔺 NSE:NELCO-EQ → 8.62%
# 🔺 NSE:RTNINDIA-EQ → 18.43%
# 🔺 NSE:RTNPOWER-EQ → 15.39%
# 🔺 NSE:SINDHUTRAD-EQ → 6.77%
# 🔺 NSE:SMCGLOBAL-EQ → 5.65%
# 🔺 NSE:TATAINVEST-EQ → 4.49%
#
# 📅 2025-06-11 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:ADFFOODS-EQ → 4.65%
# 🔺 NSE:ARMANFIN-EQ → 4.91%
# 🔺 NSE:BLISSGVS-EQ → 6.1%
# 🔺 NSE:COSMOFIRST-EQ → 4.4%
# 🔺 NSE:DHANI-EQ → 4.45%
# 🔺 NSE:ELECTCAST-EQ → 4.1%
# 🔺 NSE:GARUDA-EQ → 5.29%
# 🔺 NSE:GREENPANEL-EQ → 4.29%
# 🔺 NSE:GTLINFRA-EQ → 8.38%
# 🔺 NSE:HLEGLAS-EQ → 10.13%
# 🔺 NSE:INDGN-EQ → 4.93%
# 🔺 NSE:IXIGO-EQ → 4.2%
# 🔺 NSE:JISLDVREQS-EQ → 5.41%
# 🔺 NSE:LANDMARK-EQ → 6.61%
# 🔺 NSE:NATCOPHARM-EQ → 5.89%
# 🔺 NSE:NEULANDLAB-EQ → 5.55%
# 🔺 NSE:PFOCUS-EQ → 4.6%
# 🔺 NSE:PRABHA-EQ → 8.02%
# 🔺 NSE:SOLARA-EQ → 5.48%
# 🔺 NSE:WOCKPHARMA-EQ → 16.28%
#
# 📅 2025-06-12 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AMNPLST-EQ → 4.25%
# 🔺 NSE:HUBTOWN-EQ → 19.65%
# 🔺 NSE:INNOVACAP-EQ → 6.7%
# 🔺 NSE:MANALIPETC-EQ → 4.42%
# 🔺 NSE:SUBROS-EQ → 5.85%
#
# 📅 2025-06-13 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:DHANI-EQ → 4.15%
# 🔺 NSE:GOODLUCK-EQ → 4.4%
# 🔺 NSE:NAZARA-EQ → 6.92%
# 🔺 NSE:PARKHOTELS-EQ → 8.0%
# 🔺 NSE:PRINCEPIPE-EQ → 4.25%
# 🔺 NSE:VINCOFE-EQ → 4.41%
#
# 📅 2025-06-16 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AWFIS-EQ → 5.3%
# 🔺 NSE:BHARATWIRE-EQ → 4.76%
# 🔺 NSE:DSSL-EQ → 9.92%
# 🔺 NSE:DYCL-EQ → 4.17%
# 🔺 NSE:GRMOVER-EQ → 6.16%
# 🔺 NSE:HAPPYFORGE-EQ → 8.74%
# 🔺 NSE:IFCI-EQ → 4.38%
# 🔺 NSE:INDOTECH-EQ → 4.2%
# 🔺 NSE:JAIBALAJI-EQ → 4.1%
# 🔺 NSE:JGCHEM-EQ → 6.7%
# 🔺 NSE:KDDL-EQ → 19.44%
# 🔺 NSE:KOKUYOCMLN-EQ → 7.52%
# 🔺 NSE:LGHL-EQ → 8.74%
# 🔺 NSE:MATRIMONY-EQ → 5.54%
# 🔺 NSE:MOSCHIP-EQ → 4.56%
# 🔺 NSE:NETWEB-EQ → 4.31%
# 🔺 NSE:NEWGEN-EQ → 5.58%
# 🔺 NSE:OMAXE-EQ → 12.98%
# 🔺 NSE:ONESOURCE-EQ → 5.33%
# 🔺 NSE:PARAGMILK-EQ → 6.73%
# 🔺 NSE:PRINCEPIPE-EQ → 6.37%
# 🔺 NSE:PRSMJOHNSN-EQ → 4.72%
# 🔺 NSE:QUICKHEAL-EQ → 8.19%
# 🔺 NSE:SAGILITY-EQ → 4.23%
# 🔺 NSE:SENCO-EQ → 4.06%
# 🔺 NSE:SFL-EQ → 5.22%
# 🔺 NSE:SHANKARA-EQ → 4.24%
# 🔺 NSE:SHRIRAMPPS-EQ → 4.55%
# 🔺 NSE:SJS-EQ → 4.61%
# 🔺 NSE:STLTECH-EQ → 8.2%
# 🔺 NSE:SUBROS-EQ → 18.63%
# 🔺 NSE:SUPREMEIND-EQ → 6.94%
# 🔺 NSE:TIRUMALCHM-EQ → 4.07%
# 🔺 NSE:TVSSCS-EQ → 6.47%
#
# 📅 2025-06-17 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:GOKULAGRO-EQ → 4.71%
# 🔺 NSE:HAPPSTMNDS-EQ → 4.5%
# 🔺 NSE:MANAKCOAT-EQ → 4.75%
# 🔺 NSE:RML-EQ → 8.57%
# 🔺 NSE:VMM-EQ → 7.85%
#
# 📅 2025-06-18 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AYMSYNTEX-EQ → 4.16%
# 🔺 NSE:EMIL-EQ → 5.42%
# 🔺 NSE:GALLANTT-EQ → 4.3%
# 🔺 NSE:INDIGOPNTS-EQ → 5.17%
# 🔺 NSE:JISLDVREQS-EQ → 4.25%
# 🔺 NSE:NDRAUTO-EQ → 9.36%
# 🔺 NSE:PFOCUS-EQ → 6.17%
# 🔺 NSE:PGIL-EQ → 4.22%
# 🔺 NSE:VERANDA-EQ → 4.91%
# 🔺 NSE:WEALTH-EQ → 4.13%
# 🔺 NSE:YUKEN-EQ → 5.7%
#
# 📅 2025-06-19 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:GALLANTT-EQ → 6.46%
# 🔺 NSE:PUNJABCHEM-EQ → 5.84%
# 🔺 NSE:RPGLIFE-EQ → 4.27%
#
# 📅 2025-06-20 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:ACUTAAS-EQ → 4.18%
# 🔺 NSE:AFCONS-EQ → 6.98%
# 🔺 NSE:APLLTD-EQ → 4.35%
# 🔺 NSE:BEML-EQ → 7.42%
# 🔺 NSE:COCHINSHIP-EQ → 5.65%
# 🔺 NSE:DEEDEV-EQ → 4.58%
# 🔺 NSE:GALLANTT-EQ → 4.39%
# 🔺 NSE:GODIGIT-EQ → 6.34%
# 🔺 NSE:MOL-EQ → 4.11%
# 🔺 NSE:RTNPOWER-EQ → 5.4%
# 🔺 NSE:SAILIFE-EQ → 6.25%
# 🔺 NSE:SESHAPAPER-EQ → 6.46%
# 🔺 NSE:SHREDIGCEM-EQ → 5.12%
# 🔺 NSE:WAAREEENER-EQ → 6.55%
#
# 📅 2025-06-23 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AFSL-EQ → 4.62%
# 🔺 NSE:AGIIL-EQ → 7.8%
# 🔺 NSE:AKZOINDIA-EQ → 4.84%
# 🔺 NSE:BOROSCI-EQ → 18.9%
# 🔺 NSE:CHENNPETRO-EQ → 7.15%
# 🔺 NSE:DIGITIDE-EQ → 5.47%
# 🔺 NSE:GRSE-EQ → 4.32%
# 🔺 NSE:INNOVANA-EQ → 12.07%
# 🔺 NSE:KIRLOSBROS-EQ → 4.25%
# 🔺 NSE:KOLTEPATIL-EQ → 4.38%
# 🔺 NSE:LINDEINDIA-EQ → 4.05%
# 🔺 NSE:LUMAXTECH-EQ → 5.12%
# 🔺 NSE:POONAWALLA-EQ → 5.05%
# 🔺 NSE:SCODATUBES-EQ → 5.2%
# 🔺 NSE:SMCGLOBAL-EQ → 7.93%
# 🔺 NSE:SPLPETRO-EQ → 8.0%
#
# 📅 2025-06-24 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:ANDHRAPAP-EQ → 4.89%
# 🔺 NSE:ASTEC-EQ → 5.26%
# 🔺 NSE:AVL-EQ → 4.75%
# 🔺 NSE:BUTTERFLY-EQ → 4.51%
# 🔺 NSE:COROMANDEL-EQ → 4.25%
# 🔺 NSE:FILATEX-EQ → 4.49%
# 🔺 NSE:FUSION-EQ → 4.42%
# 🔺 NSE:KAJARIACER-EQ → 4.28%
# 🔺 NSE:KOKUYOCMLN-EQ → 6.31%
# 🔺 NSE:LTFOODS-EQ → 5.52%
# 🔺 NSE:MOL-EQ → 4.97%
# 🔺 NSE:MPSLTD-EQ → 4.37%
# 🔺 NSE:MUKANDLTD-EQ → 10.0%
# 🔺 NSE:PENIND-EQ → 5.16%
# 🔺 NSE:TNPL-EQ → 4.07%
#
# 📅 2025-06-25 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:AFSL-EQ → 6.56%
# 🔺 NSE:ANANTRAJ-EQ → 4.95%
# 🔺 NSE:ANDHRSUGAR-EQ → 5.6%
# 🔺 NSE:AURIONPRO-EQ → 4.61%
# 🔺 NSE:BBL-EQ → 6.7%
# 🔺 NSE:CRAFTSMAN-EQ → 4.07%
# 🔺 NSE:EIDPARRY-EQ → 5.33%
# 🔺 NSE:EMBDL-EQ → 7.26%
# 🔺 NSE:EXICOM-EQ → 9.02%
# 🔺 NSE:FINOPB-EQ → 5.57%
# 🔺 NSE:GIPCL-EQ → 4.34%
# 🔺 NSE:GOKULAGRO-EQ → 4.1%
# 🔺 NSE:HUBTOWN-EQ → 6.58%
# 🔺 NSE:JAIBALAJI-EQ → 11.25%
# 🔺 NSE:JYOTHYLAB-EQ → 4.63%
# 🔺 NSE:KIRLOSBROS-EQ → 8.87%
# 🔺 NSE:KIRLOSIND-EQ → 6.05%
# 🔺 NSE:KIRLPNU-EQ → 4.26%
# 🔺 NSE:KNRCON-EQ → 7.68%
# 🔺 NSE:MANINDS-EQ → 4.87%
# 🔺 NSE:NH-EQ → 4.57%
# 🔺 NSE:PRABHA-EQ → 8.42%
# 🔺 NSE:SAMMAANCAP-EQ → 11.82%
# 🔺 NSE:SOLARA-EQ → 9.0%
# 🔺 NSE:STYLEBAAZA-EQ → 5.82%
# 🔺 NSE:VSSL-EQ → 10.82%
#
# 📅 2025-06-26 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:ASTEC-EQ → 6.89%
# 🔺 NSE:AURIONPRO-EQ → 6.01%
# 🔺 NSE:BIKAJI-EQ → 4.86%
# 🔺 NSE:CENTUM-EQ → 4.75%
# 🔺 NSE:FIRSTCRY-EQ → 9.44%
# 🔺 NSE:HINDCOPPER-EQ → 4.75%
# 🔺 NSE:HUBTOWN-EQ → 5.15%
# 🔺 NSE:JAIBALAJI-EQ → 9.15%
# 🔺 NSE:LANDMARK-EQ → 6.15%
# 🔺 NSE:LLOYDSENGG-EQ → 7.53%
# 🔺 NSE:MAHSEAMLES-EQ → 4.31%
# 🔺 NSE:MUTHOOTMF-EQ → 4.44%
# 🔺 NSE:NPST-EQ → 4.01%

# %%
import pandas as pd
from fyers_apiv3 import fyersModel
import time

client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....cO6-U96MD0KpHMDZW5lGoKQpTEpLG6d3-VyR3-PaqsU"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

dates_to_check =[
    "2025-06-02", "2025-06-03", "2025-06-04", "2025-06-05", "2025-06-06",
    "2025-06-09", "2025-06-10", "2025-06-11", "2025-06-12", "2025-06-13",
    "2025-06-16", "2025-06-17", "2025-06-18", "2025-06-19", "2025-06-20",
    "2025-06-23", "2025-06-24", "2025-06-25", "2025-06-26", "2025-06-27",
    "2025-06-30"
]
fyers_symbols = fyers_symbols_filtered  # Make sure this is defined

for date in dates_to_check:
    print(f"\n📅 {date} → Stocks with >1% move from 11:00AM to Close:\n")

    for symbol in fyers_symbols:
        try:
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }
            data = fyers.history(payload)
            if data["s"] != "ok" or len(data["candles"]) < 2:
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)

            # Get first candle after 11:00
            df_after_11 = df[df.index.time >= pd.to_datetime("11:00").time()]
            if df_after_11.empty:
                continue

            open_11am = df_after_11.iloc[0]["open"]
            close_last = df.iloc[-1]["close"]
            move_pct = ((close_last - open_11am) / open_11am) * 100

            if (move_pct) > 4:  # Use 1% for debug, increase to 4 or 5% later
                direction = "🔺" if move_pct > 0 else "🔻"
                print(f"{direction} {symbol} → {round(move_pct, 2)}%")

            time.sleep(0.01)  # Light delay for rate limits

        except Exception as e:
            # Uncomment for debugging
            # print(f"Error in {symbol}: {e}")
            continue
# Out:
# 📅 2025-06-02 → Stocks with >1% move from 11:00AM to Close:
#
# 🔺 NSE:APCOTEXIND-EQ → 4.8%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-5-4207338419.py in <cell line: 0>()
#      29                 "cont_flag": "1"
#      30             }
# ---> 31             data = fyers.history(payload)
#      32             if data["s"] != "ok" or len(data["candles"]) < 2:
#      33                 continue
#
# /usr/local/lib/python3.11/dist-packages/fyers_apiv3/fyersModel.py in history(self, data)
#    1061
#    1062         else:
# -> 1063             response = self.service.get_call(
#    1064                 Config.history, self.header, data, data_flag=True
#    1065             )
#
# /usr/local/lib/python3.11/dist-packages/fyers_apiv3/fyersModel.py in get_call(self, api, header, data, data_flag)
#     130                 url_params = urllib.parse.urlencode(data)
#     131                 URL = URL + "?" + url_params
# --> 132             response = requests.get(
#     133                 url=URL,
#     134                 headers={
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#VARIABLE TURNOVER
'''
import pandas as pd
import matplotlib.pyplot as plt
from fyers_apiv3 import fyersModel
import time

# Load market cap data and clean it
marketcap_df = pd.read_csv("/content/stocks_above_1kcr.csv")
marketcap_df["SYMBOL"] = marketcap_df["SYMBOL"].astype(str).str.strip().str.upper()
marketcap_df["fyers_symbol"] = "NSE:" + marketcap_df["SYMBOL"]

# Create dictionary for quick market cap lookup
symbol_to_mcap = dict(zip(marketcap_df["fyers_symbol"], marketcap_df["MARKET_CAP"]))

# Example list: you can replace this with your full list from another source
# For demo, let's use the ones directly from market cap file and append "-EQ"
fyers_symbols = ["NSE:" + sym + "-EQ" for sym in marketcap_df["SYMBOL"]]

# FYERS credentials
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....ryLoHhjyQCbIcxGfBXos08RrP9M2-yDko8wZm8pfOP8"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# Dates to backtest
dates_to_backtest = ["2025-06-09"]  # add more if needed

initial_capital = 100000
capital = initial_capital
capital_curve = [capital]
daily_returns = []
all_trades = []

print(f"🧠 Running backtest for {len(fyers_symbols)} symbols...\n")

for date in dates_to_backtest:
    print(f"📅 Backtesting for {date}")
    daily_pnl = 0

    for symbol in fyers_symbols:
        try:
            print(f"🔍 Checking {symbol}")
            payload = {
                "symbol": symbol,
                "resolution": "5",
                "date_format": "1",
                "range_from": date,
                "range_to": date,
                "cont_flag": "1"
            }

            data = fyers.history(payload)
            if data["s"] != "ok" or not data.get("candles"):
                print(f"⚠️ No data for {symbol} on {date}")
                continue

            df = pd.DataFrame(data["candles"], columns=["timestamp", "open", "high", "low", "close", "volume"])
            df["time"] = pd.to_datetime(df["timestamp"], unit="s").dt.tz_localize("UTC").dt.tz_convert("Asia/Kolkata")
            df.set_index("time", inplace=True)
            df["ema_9"] = df["close"].ewm(span=9, adjust=False).mean()
            df["ema_20"] = df["close"].ewm(span=20, adjust=False).mean()
            df.dropna(inplace=True)

            if len(df) < 10:
                continue

            # Prepare symbol without "-EQ" to match market cap map
            symbol_base = symbol.replace("-EQ", "")
            if symbol_base not in symbol_to_mcap:
                print(f"❌ {symbol_base} not in market cap CSV. Skipping.")
                continue

            market_cap = symbol_to_mcap[symbol_base]
            min_turnover = market_cap * 0.0005  # 0.05% of market cap

            trade_entered = False
            open_915 = df.iloc[0]["open"]
            close_915 = df.iloc[0]["close"]
            avg_915 = (open_915 + close_915) / 2

            for i in range(5, len(df) - 2):
                if trade_entered:
                    break

                row = df.iloc[i]
                time_only = row.name.time()
                if not (pd.to_datetime("12:00").time() <= time_only <= pd.to_datetime("14:30").time()):
                    continue

                open_, close, volume = row["open"], row["close"], row["volume"]
                ema_9, ema_20 = row["ema_9"], row["ema_20"]
                move_pct = (close - open_) / open_
                from_open_915_pct = (close - avg_915) / avg_915
                if from_open_915_pct > 0.06:
                    continue

                avg_vol = df.iloc[:i]["volume"].mean()
                price_est = (row["high"] + row["low"]) / 2
                liquidity_turnover = avg_vol * price_est

                if liquidity_turnover < min_turnover:
                    continue

                if move_pct >= 0.01 and open_ > ema_9 and open_ > ema_20:
                    entry_candle = df.iloc[i + 1]
                    entry_price = entry_candle["open"]
                    sl = entry_price - 0.01 * entry_price if move_pct > 0.02 else open_

                    for j in range(i + 2, len(df)):
                        next_candle = df.iloc[j]

                        if next_candle["low"] <= sl:
                            exit_price = sl
                            pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                            daily_pnl += pnl
                            all_trades.append({
                                "date": date,
                                "symbol": symbol,
                                "trigger_time": row.name,
                                "entry_time": entry_candle.name,
                                "entry_price": entry_price,
                                "exit_time": next_candle.name,
                                "exit_price": exit_price,
                                "pnl_%": pnl
                            })
                            trade_entered = True
                            break
                        elif next_candle["close"] > entry_price:
                            sl = max(sl, next_candle["close"] - 0.01 * next_candle["close"])
                    else:
                        final_exit = df.iloc[-1]
                        exit_price = final_exit["close"]
                        pnl = round((exit_price - entry_price) / entry_price * 100, 2)
                        daily_pnl += pnl
                        all_trades.append({
                            "date": date,
                            "symbol": symbol,
                            "trigger_time": row.name,
                            "entry_time": entry_candle.name,
                            "entry_price": entry_price,
                            "exit_time": final_exit.name,
                            "exit_price": exit_price,
                            "pnl_%": pnl
                        })
                        trade_entered = True

        except Exception as e:
            print(f"🚫 Error for {symbol}: {str(e)}")
            continue

    capital *= (1 + daily_pnl / 100)
    capital_curve.append(round(capital, 2))
    daily_returns.append(round(daily_pnl, 2))
    print(f"✅ {date} done. Daily PnL: {daily_pnl:.2f}%\n")

# Plotting
plt.figure(figsize=(12, 6))
plt.plot([initial_capital] + daily_returns, label="Daily Returns (%)", color="gray", linestyle="--", alpha=0.4)
plt.plot(capital_curve, label="Capital Over Time (₹)", color="blue", linewidth=2)
plt.title("Portfolio Growth (Starting with ₹1,00,000)")
plt.xlabel("Trading Days")
plt.ylabel("Portfolio Value (₹)")
plt.xticks(range(len(dates_to_backtest)+1), ["Start"] + dates_to_backtest, rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Summary
print(f"\n💼 Final Portfolio Value: ₹{round(capital, 2)}")
print("📊 Daily Returns (%):", daily_returns)

# Save trade results
results_df = pd.DataFrame(all_trades)
results_df.to_csv("backtest_trades.csv", index=False)
results_df'''
# Out:
# 🧠 Running backtest for 1306 symbols...
#
# 📅 Backtesting for 2025-06-09
# 🔍 Checking NSE:360ONE-EQ
# 🔍 Checking NSE:3MINDIA-EQ
# 🔍 Checking NSE:5PAISA-EQ
# 🔍 Checking NSE:63MOONS-EQ
# 🔍 Checking NSE:AADHARHFC-EQ
# 🔍 Checking NSE:AARTIDRUGS-EQ
# 🔍 Checking NSE:AARTIIND-EQ
# 🔍 Checking NSE:AARTIPHARM-EQ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-5-140668667.py in <cell line: 0>()
#      48             }
#      49
# ---> 50             data = fyers.history(payload)
#      51             if data["s"] != "ok" or not data.get("candles"):
#      52                 print(f"⚠️ No data for {symbol} on {date}")
#
# /usr/local/lib/python3.11/dist-packages/fyers_apiv3/fyersModel.py in history(self, data)
#    1061
#    1062         else:
# -> 1063             response = self.service.get_call(
#    1064                 Config.history, self.header, data, data_flag=True
#    1065             )
#
# /usr/local/lib/python3.11/dist-packages/fyers_apiv3/fyersModel.py in get_call(self, api, header, data, data_flag)
#     130                 url_params = urllib.parse.urlencode(data)
#     131                 URL = URL + "?" + url_params
# --> 132             response = requests.get(
#     133                 url=URL,
#     134                 headers={
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # BreakOut Strategy

# %%
import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....zl2V43LLPXHUFpitNdjYUhjqUUuqZhH1-zazGOzp_94"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Inputs ===
dates_to_check = ["2025-06-26"]
fyers_symbols = fyers_symbols_filtered  # Make sure this list is defined

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
entry_buffer_pct = 0.01
min_body_pct = 0.0075
confirmation_breakout_pct = 0.01  # 1% breakout

# === Fetch 5-min Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]
            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            # ❌ Skip trade if upper wick is large
            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]
                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99  # ✅ Fixed 1% SL
                        remaining_candles = candles_after.iloc[j + 1:]

                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
all_trades = []

for date in dates_to_check:
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        print(f"✅ Data fetched: {symbol} on {date}, {len(df)} candles")
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            print(f"🔍 Trades found: {len(trades)}")
            all_trades.extend(trades)
        time.sleep(0)  # Adjust if needed to handle rate limit

# === Results ===
trades_df = pd.DataFrame(all_trades)

if trades_df.empty:
    print("\n❌ No trades were generated.")
else:
    trades_df['date'] = pd.to_datetime(trades_df['date']).dt.date
    daily_returns = []
    portfolio_value = 100000

    for date, group in trades_df.groupby('date'):
        pnls = group['pnl_%'].values
        trades_taken = len(pnls)
        day_return = round(np.sum(pnls), 2)
        daily_returns.append(np.float64(day_return))

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {trades_taken}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[np.float64(round(p, 2)) for p in pnls]}")

    for ret in daily_returns:
        portfolio_value *= (1 + float(ret) / 100)

    print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
    print(f"📊 Daily Returns (%): {daily_returns}")

    print("\n🔍 Exit Reason Summary:")
    exit_summary = trades_df['reason'].value_counts().to_dict()
    for reason in exit_summary:
        total = exit_summary[reason]
        wins = sum((trades_df['reason'] == reason) & (trades_df['pnl_%'] > 0))
        losses = total - wins
        win_pct = round((wins / total) * 100, 2)
        print(f"▶️ {reason}: {total} trades → ✅ Wins: {wins} | ❌ Losses: {losses} | 🏆 Win%: {win_pct}%")

    print("\n📋 Trade Log:")
    print(trades_df[['date', 'symbol', 'trigger_time', 'entry_time', 'entry_price',
                     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
# Out:
# ✅ Data fetched: NSE:360ONE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:3MINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:63MOONS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AADHARHFC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIDRUGS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIIND-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIPHARM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AAVAS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABB-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABBOTINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABCAPITAL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABDL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABFRL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABREL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABSLAMC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACI-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACMESOLAR-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACUTAAS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIENSOL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIENT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIGREEN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIPORTS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIPOWER-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADFFOODS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADVENZYMES-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AEGISLOG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AEGISVOPAK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AETHER-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AFCONS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AFFLE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AGARWALEYE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AGI-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AHLUCONT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AIAENG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AIIL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJANTPHARM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJAXENGG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJMERA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AKUMS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AKZOINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALEMBICLTD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALIVUS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALKEM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALKYLAMINE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALLCARGO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALOKINDS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AMBER-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AMBUJACEM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANANDRATHI-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANANTRAJ-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANGELONE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANUP-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANURAS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APARINDS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APLAPOLLO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APLLTD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLOHOSP-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLOTYRE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APTUS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARE&M-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARKADE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVIND-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVINDFASN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVSMART-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASAHIINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHAPURMIN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHIANA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHOKA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHOKLEY-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASIANPAINT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASKAUTOLTD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTERDM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAMICRO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAZEN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATGL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATHERENERG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATUL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AUBANK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AURIONPRO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:AUROPHARMA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVALON-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVANTEL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVANTIFEED-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AWFIS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AWL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AXISBANK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AZAD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJ-AUTO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJELEC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJFINSV-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHFL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHIND-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHLDNG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJFINANCE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALAMINES-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALKRISIND-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALMLAWRIE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALRAMCHIN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANARISUG-EQ on 2025-06-26, 74 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANCOINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANDHANBNK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANKBARODA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANKINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANSALWIRE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BASF-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BATAINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAYERCROP-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BBL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BBTC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BDL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BECTORFOOD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BEL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BELRISE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BEML-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BERGEPAINT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHAGCHEM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARATFORG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARATRAS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARTIARTL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARTIHEXA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHEL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIKAJI-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BIOCON-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIRLACORPN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLACKBUCK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BLUEDART-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUEJET-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUESTARCO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOMDYEING-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOROLTD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BORORENEW-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOSCHLTD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BPCL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BRIGADE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BRITANNIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BSE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BSOFT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAMPUS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAMS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CANBK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:CANFINHOME-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAPLIPOINT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARBORUNIV-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARERATING-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARTRADE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CASTROLIND-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CCL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CDSL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEATLTD-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEIGALL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CELLO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CENTRALBK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CENTUM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CENTURYPLY-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CERA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CESC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CGCL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CGPOWER-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHALET-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHAMBLFERT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHEMPLASTS-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHENNPETRO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHOICEIN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHOLAFIN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHOLAHLDNG-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CIEINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CIGNITITEC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CIPLA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CLEAN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CMSINFO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COALINDIA-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COCHINSHIP-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COFORGE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COHANCE-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COLPAL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CONCOR-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CONCORDBIO-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COROMANDEL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COSMOFIRST-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CRAFTSMAN-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CREDITACC-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CRISIL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CROMPTON-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CSBBANK-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CUB-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CUMMINSIND-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CYIENT-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CYIENTDLM-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:
EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZYDUSWELL-EQ on 2025-06-26, 75 candles
# 🔍 Trades found: 0
#
# 📅 2025-06-26 Summary:
#    📈 Trades Taken: 40
#    💰 Day's Return: 14.4%
#    📋 Trades PnL: [np.float64(3.23), np.float64(-1.0), np.float64(3.34), np.float64(-0.6), np.float64(0.1), np.float64(-0.11), np.float64(0.88), np.float64(-1.0), np.float64(-1.0), np.float64(1.31), np.float64(-0.13), np.float64(0.24), np.float64(3.53), np.float64(-0.18), np.float64(-0.39), np.float64(2.5), np.float64(-0.24), np.float64(0.33), np.float64(0.87), np.float64(-0.22), np.float64(0.48), np.float64(-1.0), np.float64(-0.42), np.float64(0.14), np.float64(-1.0), np.float64(-0.09), np.float64(0.32), np.float64(-0.34), np.float64(1.19), np.float64(-0.77), np.float64(0.1), np.float64(-1.0), np.float64(-1.0), np.float64(0.4), np.float64(-0.02), np.float64(1.58), np.float64(-0.52), np.float64(0.33), np.float64(1.85), np.float64(2.71)]
#
# 💼 Final Portfolio Value: ₹114400.0
# 📊 Daily Returns (%): [np.float64(14.4)]
#
# 🔍 Exit Reason Summary:
# ▶️ End of Day Exit: 33 trades → ✅ Wins: 20 | ❌ Losses: 13 | 🏆 Win%: 60.61%
# ▶️ SL Hit: 7 trades → ✅ Wins: 0 | ❌ Losses: 7 | 🏆 Win%: 0.0%
#
# 📋 Trade Log:
#       date            symbol              trigger_time                entry_time  entry_price                 exit_time  exit_price  pnl_%          reason
# 2025-06-26  NSE:AURIONPRO-EQ 2025-06-26 14:05:00+05:30 2025-06-26 14:10:00+05:30      1361.58 2025-06-26 15:25:00+05:30     1405.50   3.23 End of Day Exit
# 2025-06-26  NSE:BAYERCROP-EQ 2025-06-26 14:30:00+05:30 2025-06-26 14:45:00+05:30      5942.34 2025-06-26 14:55:00+05:30     5882.91  -1.00          SL Hit
# 2025-06-26     NSE:BIKAJI-EQ 2025-06-26 12:35:00+05:30 2025-06-26 12:40:00+05:30       727.20 2025-06-26 15:25:00+05:30      751.50   3.34 End of Day Exit
# 2025-06-26        NSE:BLS-EQ 2025-06-26 14:20:00+05:30 2025-06-26 14:25:00+05:30       371.18 2025-06-26 15:25:00+05:30      368.95  -0.60 End of Day Exit
# 2025-06-26      NSE:CANBK-EQ 2025-06-26 12:00:00+05:30 2025-06-26 14:35:00+05:30       110.89 2025-06-26 15:25:00+05:30      111.00   0.10 End of Day Exit
# 2025-06-26 NSE:DATAMATICS-EQ 2025-06-26 14:30:00+05:30 2025-06-26 14:35:00+05:30       625.70 2025-06-26 15:25:00+05:30      625.00  -0.11 End of Day Exit
# 2025-06-26   NSE:DBREALTY-EQ 2025-06-26 14:15:00+05:30 2025-06-26 14:20:00+05:30       230.08 2025-06-26 15:25:00+05:30      232.10   0.88 End of Day Exit
# 2025-06-26   NSE:GALLANTT-EQ 2025-06-26 13:00:00+05:30 2025-06-26 13:05:00+05:30       547.87 2025-06-26 13:10:00+05:30      542.40  -1.00          SL Hit
# 2025-06-26    NSE:GMRP&UI-EQ 2025-06-26 12:50:00+05:30 2025-06-26 12:55:00+05:30       108.47 2025-06-26 13:30:00+05:30      107.39  -1.00          SL Hit
defined

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
entry_buffer_pct = 0.01
min_body_pct = 0.0075
confirmation_breakout_pct = 0.01  # 1% breakout

# === Fetch 5-min Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]
            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            # ❌ Skip trade if upper wick is large
            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]
                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99  # ✅ Fixed 1% SL
                        remaining_candles = candles_after.iloc[j + 1:]

                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
all_trades = []

for date in dates_to_check:
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        print(f"✅ Data fetched: {symbol} on {date}, {len(df)} candles")
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            print(f"🔍 Trades found: {len(trades)}")
            all_trades.extend(trades)
        time.sleep(0)  # Adjust if needed to handle rate limit

# === Results ===
trades_df = pd.DataFrame(all_trades)

if trades_df.empty:
    print("\n❌ No trades were generated.")
else:
    trades_df['date'] = pd.to_datetime(trades_df['date']).dt.date
    daily_returns = []
    portfolio_value = 100000

    for date, group in trades_df.groupby('date'):
        pnls = group['pnl_%'].values
        trades_taken = len(pnls)
        day_return = round(np.sum(pnls), 2)
        daily_returns.append(np.float64(day_return))

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {trades_taken}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[np.float64(round(p, 2)) for p in pnls]}")

    for ret in daily_returns:
        portfolio_value *= (1 + float(ret) / 100)

    print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
    print(f"📊 Daily Returns (%): {daily_returns}")

    print("\n🔍 Exit Reason Summary:")
    exit_summary = trades_df['reason'].value_counts().to_dict()
    for reason in exit_summary:
        total = exit_summary[reason]
        wins = sum((trades_df['reason'] == reason) & (trades_df['pnl_%'] > 0))
        losses = total - wins
        win_pct = round((wins / total) * 100, 2)
        print(f"▶️ {reason}: {total} trades → ✅ Wins: {wins} | ❌ Losses: {losses} | 🏆 Win%: {win_pct}%")

    print("\n📋 Trade Log:")
    print(trades_df[['date', 'symbol', 'trigger_time', 'entry_time', 'entry_price',
                     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
# Out:
# ✅ Data fetched: NSE:360ONE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:3MINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:63MOONS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AADHARHFC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:AARTIDRUGS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIPHARM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AAVAS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABBOTINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABCAPITAL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABDL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABFRL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABREL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABSLAMC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACMESOLAR-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACUTAAS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIENSOL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIENT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIGREEN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIPORTS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIPOWER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADFFOODS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADVENZYMES-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:AEGISLOG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AEGISVOPAK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AETHER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AFCONS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AFFLE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AGARWALEYE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AGI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AHLUCONT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AIAENG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AIIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJANTPHARM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJAXENGG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJMERA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AKUMS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AKZOINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALEMBICLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALIVUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALKEM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALKYLAMINE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALLCARGO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALOKINDS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AMBER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AMBUJACEM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANANDRATHI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANANTRAJ-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANGELONE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANUP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANURAS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APARINDS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APLAPOLLO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:APLLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLOHOSP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLOTYRE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APTUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARE&M-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARKADE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVINDFASN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVSMART-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASAHIINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:ASHAPURMIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHIANA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHOKA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHOKLEY-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASIANPAINT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASKAUTOLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTERDM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAMICRO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAZEN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATGL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATHERENERG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATUL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AUBANK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AURIONPRO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AUROPHARMA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVALON-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVANTEL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVANTIFEED-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AWFIS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AWL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AXISBANK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AZAD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJ-AUTO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJELEC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJFINSV-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHFL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHLDNG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJFINANCE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALAMINES-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALKRISIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALMLAWRIE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALRAMCHIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANARISUG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANCOINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANDHANBNK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANKBARODA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANKINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANSALWIRE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BASF-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BATAINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAYERCROP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BBL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BBTC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BDL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BECTORFOOD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BEL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BELRISE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BEML-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BERGEPAINT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BHAGCHEM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARATFORG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARATRAS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARTIARTL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARTIHEXA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHEL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIKAJI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIOCON-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIRLACORPN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BLACKBUCK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUEDART-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUEJET-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUESTARCO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOMDYEING-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOROLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BORORENEW-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOSCHLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BPCL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BRIGADE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BRITANNIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BSE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BSOFT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAMPUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAMS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CANBK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CANFINHOME-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAPLIPOINT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARBORUNIV-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARERATING-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARTRADE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CASTROLIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CCL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CDSL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEATLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEIGALL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:CELLO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEN
ND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JUBLFOOD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JUBLINGREA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JUBLPHARMA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JUNIPER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JUSTDIAL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JWL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JYOTHYLAB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:JYOTICNC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KAJARIACER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KALYANKJIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KANSAINER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KARURVYSYA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:KAYNES-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KDDL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KEC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KEI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KFINTECH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KIMS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KINGFA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KIOCL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KIRIINDUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KIRLOSBROS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:KIRLOSENG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KIRLOSIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:KIRLPNU-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:KITEX-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KKCL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KNRCON-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KOLTEPATIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:KOTAKBANK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KPEL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KPIGREEN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KPIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KPITTECH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KPRMILL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KRBL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KRISHANA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KRN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KSB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KSCL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KSL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:KTKBANK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LALPATHLAB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LATENTVIEW-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LAURUSLABS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LEMONTREE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LGBBROSLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LICHSGFIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LICI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LINDEINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LLOYDSENGG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LLOYDSENT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LLOYDSME-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LMW-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LODHA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LTF-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LTFOODS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LTIM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LTTS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LUMAXIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LUMAXTECH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:LUPIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LUXIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:LXCHEM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:M&M-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:M&MFIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAHABANK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAHLIFE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAHSCOOTER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAHSEAMLES-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAITHANALL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MANAPPURAM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MANGCHEFER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MANINFRA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MANKIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MANORAMA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MANYAVAR-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAPMYINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MARATHON-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MARICO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MARKSANS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MARUTI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MASFIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MASTEK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAXESTATES-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAXHEALTH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MAZDOCK-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MBAPL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MCLOUD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MCX-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MEDANTA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MEDIASSIST-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MEDPLUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:METROBRAND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:METROPOLIS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MFSL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MGL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MHRIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MIDHANI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MINDACORP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MMTC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MOIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MOREPENLAB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MOSCHIP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MOTHERSON-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MOTILALOFS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MPHASIS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MPSLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MRF-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MRPL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MSTCLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MSUMI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MTARTECH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MTNL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:MUTHOOTFIN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NAM-INDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NATCOPHARM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NATIONALUM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NAUKRI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NAVA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NAVINFLUOR-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NAVNETEDUL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NAZARA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NBCC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NCC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NEOGEN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NESCO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NESTLEIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NETWEB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NETWORK18-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NEULANDLAB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NEWGEN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NFL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NHPC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NIACL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NIITMTS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NITCO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NIVABUPA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NLCINDIA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NMDC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NOCIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NORTHARC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NPST-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NSIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NSLNISP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NTPC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NTPCGREEN-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NUCLEUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NUVAMA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NUVOCO-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:NYKAA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OBEROIRLTY-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OFSS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OLAELEC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OLECTRA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ONESOURCE-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ONGC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OPTIEMUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ORCHPHARMA-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ORIENTCEM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ORIENTELEC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:OSWALPUMPS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PAGEIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PARADEEP-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PARAS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PARKHOTELS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PATANJALI-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PATELENG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PAYTM-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PCBL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PCJEWELLER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:PDSL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PEL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PENIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PERSISTENT-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PETRONET-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PFC-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PFIZER-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PFOCUS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PGEL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PGHH-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PGHL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PGIL-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PHOENIXLTD-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PIDILITIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PIIND-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PILANIINVS-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PITTIENG-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PNB-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:PNBHOUSING-EQ on 2025-07-01, 75 candles
# 🔍 Trades found: 0
# ...
# ✅ Data fetched: NSE:YATHARTH-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:YESBANK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZAGGLE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZEEL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZENSARTECH-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZENTEC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZFCVINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZYDUSLIFE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZYDUSWELL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
#
# 📅 2025-07-01 Summary:
#    📈 Trades Taken: 39
#    💰 Day's Return: 10.91%
#    📋 Trades PnL: [np.float64(-0.19), np.float64(-1.0), np.float64(-1.0), np.float64(2.11), np.float64(-1.0), np.float64(-0.83), np.float64(-1.0), np.float64(1.33), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.04), np.float64(1.19), np.float64(-1.0), np.float64(1.32), np.float64(0.21), np.float64(-1.0), np.float64(-1.0), np.float64(0.6), np.float64(4.66), np.float64(-1.0), np.float64(4.73), np.float64(-1.0), np.float64(-0.45), np.float64(-1.0), np.float64(-0.29), np.float64(-1.0), np.float64(-0.12), np.float64(0.01), np.float64(0.65), np.float64(-1.0), np.float64(2.4), np.float64(1.22), np.float64(2.32), np.float64(2.7), np.float64(-0.11), np.float64(0.41), np.float64(0.42), np.float64(1.58)]
#
# 📅 2025-07-02 Summary:
#    📈 Trades Taken: 46
#    💰 Day's Return: 20.25%
#    📋 Trades PnL: [np.float64(2.42), np.float64(-1.0), np.float64(0.78), np.float64(0.61), np.float64(5.39), np.float64(-1.0), np.float64(-1.0), np.float64(0.45), np.float64(-1.0), np.float64(0.44), np.float64(0.41), np.float64(3.4), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            #print(f"🔍 Trades found: {len(trades)}")
            all_trades.extend(trades)
        time.sleep(0)  # Adjust if needed to handle rate limit

# === Results ===
trades_df = pd.DataFrame(all_trades)

if trades_df.empty:
    print("\n❌ No trades were generated.")
else:
    trades_df['date'] = pd.to_datetime(trades_df['date']).dt.date
    daily_returns = []
    portfolio_value = 100000

    for date, group in trades_df.groupby('date'):
        pnls = group['pnl_%'].values
        trades_taken = len(pnls)
        day_return = round(np.sum(pnls), 2)
        daily_returns.append(np.float64(day_return))

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {trades_taken}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[np.float64(round(p, 2)) for p in pnls]}")

    for ret in daily_returns:
        portfolio_value *= (1 + float(ret) / 100)

    print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
    print(f"📊 Daily Returns (%): {daily_returns}")

    print("\n🔍 Exit Reason Summary:")
    exit_summary = trades_df['reason'].value_counts().to_dict()
    for reason in exit_summary:
        total = exit_summary[reason]
        wins = sum((trades_df['reason'] == reason) & (trades_df['pnl_%'] > 0))
        losses = total - wins
        win_pct = round((wins / total) * 100, 2)
        print(f"▶️ {reason}: {total} trades → ✅ Wins: {wins} | ❌ Losses: {losses} | 🏆 Win%: {win_pct}%")

    #print("\n📋 Trade Log:")
    #print(trades_df[['date', 'symbol', 'trigger_time', 'entry_time', 'entry_price',
     #                'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
# Out:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-02
# ⚠️ No candles for NSE:ATHERENERG-EQ on 2025-05-02
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-02
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-02
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-02
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-05
# ⚠️ No candles for NSE:ATHERENERG-EQ on 2025-05-05
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-05
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-05
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-05
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-06
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-06
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-06
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-06
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-07
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-07
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-07
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-07
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-08
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-08
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-08
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-08
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-09
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-09
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-09
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-09
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-12
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-12
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-12
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-12
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-13
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-13
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-13
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-13
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-14
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-14
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-14
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-14
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-15
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-15
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-15
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-15
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-16
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-16
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-16
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-16
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-19
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-19
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-19
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-19
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-20
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-20
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-20
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-20
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-21
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-21
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-21
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-21
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-22
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-22
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-22
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-22
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-23
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-23
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-23
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-23
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-26
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-26
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-26
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-26
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-27
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-27
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-27
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-27
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-28
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-28
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-28
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-29
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-29
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-29
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-30
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-30
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-30
#
# 📅 2025-05-02 Summary:
#    📈 Trades Taken: 34
#    💰 Day's Return: -15.32%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.03), np.float64(-1.0), np.float64(-1.0), np.float64(1.16), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.14), np.float64(-1.0), np.float64(2.03), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.41), np.float64(-1.0), np.float64(-1.0), np.float64(0.93), np.float64(1.2), np.float64(0.18), np.float64(1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.79), np.float64(0.09), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📅 2025-05-05 Summary:
#    📈 Trades Taken: 77
#    💰 Day's Return: 12.85%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(1.0), np.float64(0.18), np.float64(1.56), np.float64(-1.0), np.float64(1.71), np.float64(-1.0), np.float64(0.63), np.float64(-1.0), np.float64(2.75), np.float64(-0.03), np.float64(0.78), np.float64(0.37), np.float64(0.8), np.float64(-1.0), np.float64(1.22), np.float64(-1.0), np.float64(0.65), np.float64(0.06), np.float64(-1.0), np.float64(1.64), np.float64(-1.0), np.float64(-0.17), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.54), np.float64(0.78), np.float64(-0.88), np.float64(0.13), np.float64(6.86), np.float64(-0.11), np.float64(-0.14), np.float64(-1.0), np.float64(1.18), np.float64(-0.2), np.float64(-1.0), np.float64(1.02), np.float64(6.06), np.float64(-0.35), np.float64(-1.0), np.float64(-0.73), np.float64(-0.41), np.float64(-1.0), np.float64(-1.0), np.float64(1.96), np.float64(-0.33), np.float64(-1.0), np.float64(-1.0), np.float64(0.01), np.float64(-1.0), np.float64(0.35), np.float64(0.05), np.float64(1.83), np.float64(-1.0), np.float64(-1.0), np.float64(0.22), np.float64(-0.52), np.float64(1.07), np.float64(-0.3), np.float64(-1.0), np.float64(0.36), np.float64(0.39), np.float64(-0.23), np.float64(1.33), np.float64(1.04), np.float64(1.63), np.float64(-1.0), np.float64(-0.08), np.float64(-1.0), np.float64(-1.0), np.float64(1.67), np.float64(1.23), np.float64(-0.36), np.float64(0.33), np.float64(0.3), np.float64(-1.0)]
#
# 📅 2025-05-06 Summary:
#    📈 Trades Taken: 12
#    💰 Day's Return: -6.32%
#    📋 Trades PnL: [np.float64(0.61), np.float64(-0.59), np.float64(-1.0), np.float64(-1.0), np.float64(-0.64), np.float64(0.36), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.94)]
#
# 📅 2025-05-07 Summary:
#    📈 Trades Taken: 45
#    💰 Day's Return: 12.77%
#    📋 Trades PnL: [np.float64(0.66), np.float64(0.39), np.float64(0.87), np.float64(1.93), np.float64(-1.0), np.float64(-0.38), np.float64(1.67), np.float64(-0.08), np.float64(-1.0), np.float64(-1.0), np.float64(0.8), np.float64(-0.02), np.float64(-0.9), np.float64(-1.0), np.float64(-0.42), np.float64(-1.0), np.float64(4.66), np.float64(-1.0), np.float64(-1.0), np.float64(0.75), np.float64(3.22), np.float64(0.89), np.float64(0.05), np.float64(0.37), np.float64(-0.45), np.float64(1.95), np.float64(-1.0), np.float64(-1.0), np.float64(0.73), np.float64(3.0), np.float64(0.93), np.float64(0.33), np.float64(-0.52), np.float64(-1.0), np.float64(1.47), np.float64(1.63), np.float64(0.05), np.float64(-1.0), np.float64(-1.0), np.float64(-0.06), np.float64(-0.03), np.float64(0.89), np.float64(-1.0), np.float64(-0.43), np.float64(1.82)]
#
# 📅 2025-05-08 Summary:
#    📈 Trades Taken: 27
#    💰 Day's Return: -20.9%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.13), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.33), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.8), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.1), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📅 2025-05-09 Summary:
#    📈 Trades Taken: 53
#    💰 Day's Return: 9.87%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(0.74), np.float64(-1.0), np.float64(-1.0), np.float64(-0.37), np.float64(1.12), np.float64(0.28), np.float64(0.3), np.float64(-1.0), np.float64(0.53), np.float64(1.63), np.float64(2.36), np.float64(-1.0), np.float64(3.18), np.float64(-1.0), np.float64(-0.54), np.float64(0.47), np.float64(0.84), np.float64(-0.37), np.float64(-1.0), np.float64(0.44), np.float64(-1.0), np.float64(0.2), np.float64(3.01), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.18), np.float64(0.32), np.float64(-1.0), np.float64(-0.32), np.float64(0.41), np.float64(3.56), np.float64(-1.0), np.float64(1.01), np.float64(2.07), np.float64(2.53), np.float64(-1.0), np.float64(1.12), np.float64(-0.67), np.float64(-1.0), np.float64(-1.0), np.float64(-0.46), np.float64(4.03), np.float64(1.63), np.float64(-1.0), np.float64(-0.19), np.float64(-1.0), np.float64(-0.57), np.float64(0.75), np.float64(0.65)]
#
# 📅 2025-05-12 Summary:
#    📈 Trades Taken: 77
#    💰 Day's Return: 10.74%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(
#
# 📅 2025-05-15 Summary:
#    📈 Trades Taken: 65
#    💰 Day's Return: 16.16%
#    📋 Trades PnL: [np.float64(2.31), np.float64(-1.0), np.float64(2.15), np.float64(3.5), np.float64(1.11), np.float64(1.82), np.float64(1.32), np.float64(1.1), np.float64(-1.0), np.float64(-1.0), np.float64(1.72), np.float64(3.68), np.float64(-0.16), np.float64(-1.0), np.float64(-0.7), np.float64(0.74), np.float64(0.39), np.float64(-0.28), np.float64(-1.0), np.float64(-0.49), np.float64(0.28), np.float64(1.17), np.float64(-1.0), np.float64(-0.02), np.float64(-0.81), np.float64(-1.0), np.float64(0.26), np.float64(4.27), np.float64(-0.01), np.float64(-1.0), np.float64(2.16), np.float64(-0.3), np.float64(-0.41), np.float64(2.9), np.float64(-1.0), np.float64(1.98), np.float64(-1.0), np.float64(-0.53), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.66), np.float64(-1.0), np.float64(2.32), np.float64(-1.0), np.float64(2.34), np.float64(0.11), np.float64(-0.27), np.float64(-0.82), np.float64(-1.0), np.float64(4.11), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.43), np.float64(-1.0), np.float64(-1.0), np.float64(0.27), np.float64(0.29), np.float64(0.25), np.float64(1.32), np.float64(-1.0)]
#
# 📅 2025-05-16 Summary:
#    📈 Trades Taken: 91
#    💰 Day's Return: 45.43%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.94), np.float64(-1.0), np.float64(2.49), np.float64(0.26), np.float64(-0.17), np.float64(-1.0), np.float64(0.58), np.float64(-0.94), np.float64(-1.0), np.float64(1.36), np.float64(0.61), np.float64(1.12), np.float64(-1.0), np.float64(0.38), np.float64(2.41), np.float64(0.64), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(9.26), np.float64(-1.0), np.float64(2.02), np.float64(1.7), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.35), np.float64(0.95), np.float64(-1.0), np.float64(0.17), np.float64(-0.78), np.float64(-1.0), np.float64(1.27), np.float64(-1.0), np.float64(2.56), np.float64(-1.0), np.float64(1.17), np.float64(0.3), np.float64(1.75), np.float64(-0.06), np.float64(0.14), np.float64(-1.0), np.float64(1.83), np.float64(-0.23), np.float64(-1.0), np.float64(2.91), np.float64(-0.67), np.float64(-1.0), np.float64(0.18), np.float64(0.5), np.float64(-1.0), np.float64(-0.55), np.float64(0.28), np.float64(-1.0), np.float64(0.19), np.float64(14.65), np.float64(-1.0), np.float64(-1.0), np.float64(-0.17), np.float64(0.5), np.float64(1.38), np.float64(-0.02), np.float64(6.12), np.float64(2.46), np.float64(-1.0), np.float64(0.36), np.float64(1.13), np.float64(1.03), np.float64(-1.0), np.float64(-0.23), np.float64(1.12), np.float64(0.85), np.float64(-1.0), np.float64(7.16), np.float64(-1.0), np.float64(1.16), np.float64(-1.0), np.float64(0.8), np.float64(0.13), np.float64(0.09), np.float64(0.85), np.float64(2.24), np.float64(-0.33), np.float64(-0.14), np.float64(0.51), np.float64(-0.17), np.float64(0.03)]
#
# 📅 2025-05-19 Summary:
#    📈 Trades Taken: 31
#    💰 Day's Return: -8.24%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(1.49), np.float64(1.56), np.float64(-1.0), np.float64(-0.05), np.float64(-1.0), np.float64(2.13), np.float64(-1.0), np.float64(-1.0), np.float64(0.38), np.float64(2.57), np.float64(-1.0), np.float64(-0.31), np.float64(-0.43), np.float64(-1.0), np.float64(0.37), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.55), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(3.9), np.float64(-0.55), np.float64(-1.0), np.float64(-0.75), np.float64(-1.0)]
#
# 📅 2025-05-20 Summary:
#    📈 Trades Taken: 23
#    💰 Day's Return: -6.77%
#    📋 Trades PnL: [np.float64(-0.13), np.float64(-1.0), np.float64(-1.0), np.float64(-0.65), np.float64(-1.0), np.float64(-0.05), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.88), np.float64(-1.0), np.float64(-1.0), np.float64(0.94), np.float64(-1.0), np.float64(-1.0), np.float64(-0.48), np.float64(-1.0), np.float64(5.55), np.float64(0.65), np.float64(-1.0), np.float64(0.52)]
#
# 📅 2025-05-21 Summary:
#    📈 Trades Taken: 40
#    💰 Day's Return: 15.56%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(0.85), np.float64(0.44), np.float64(-0.05), np.float64(-1.0), np.float64(-0.22), np.float64(0.57), np.float64(0.34), np.float64(1.41), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.56), np.float64(0.17), np.float64(0.61), np.float64(-0.42), np.float64(-1.0), np.float64(-1.0), np.float64(-0.25), np.float64(-1.0), np.float64(0.17), np.float64(-0.56), np.float64(1.86), np.float64(0.62), np.float64(0.39), np.float64(1.0), np.float64(-1.0), np.float64(0.63), np.float64(0.19), np.float64(-1.0), np.float64(-1.0), np.float64(1.98), np.float64(0.94), np.float64(-0.33), np.float64(-1.0), np.float64(3.59), np.float64(-1.0), np.float64(13.2), np.float64(-0.2), np.float64(2.19)]
#
# 📅 2025-05-22 Summary:
#    📈 Trades Taken: 40
#    💰 Day's Return: 11.64%
#    📋 Trades PnL: [np.float64(-0.32), np.float64(0.21), np.float64(-1.0), np.float64(-1.0), np.float64(0.26), np.float64(-1.0), np.float64(1.45), np.float64(-0.76), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(9.0), np.float64(0.43), np.float64(2.37), np.float64(-1.0), np.float64(-1.0), np.float64(3.97), np.float64(0.23), np.float64(-1.0), np.float64(0.53), np.float64(-1.0), np.float64(-0.17), np.float64(-1.0), np.float64(2.94), np.float64(-1.0), np.float64(1.73), np.float64(1.89), np.float64(-0.83), np.float64(-1.0), np.float64(1.58), np.float64(0.76), np.float64(-1.0), np.float64(-1.0), np.float64(2.13), np.float64(-0.85), np.float64(0.26), np.float64(-0.21), np.float64(-0.23), np.float64(1.27), np.float64(-1.0)]
#
# 📅 2025-05-23 Summary:
#    📈 Trades Taken: 66
#    💰 Day's Return: -5.12%
#    📋 Trades PnL: [np.float64(-0.59), np.float64(-0.53), np.float64(0.99), np.float64(0.54), np.float64(-0.83), np.float64(-1.0), np.float64(-0.38), np.float64(2.67), np.float64(-0.57), np.float64(0.25), np.float64(-1.0), np.float64(0.81), np.float64(-0.97), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.11), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.04), np.float64(0.81), np.float64(1.79), np.float64(-0.18), np.float64(0.53), np.float64(0.04), np.float64(-1.0), np.float64(-1.0), np.float64(-0.53), np.float64(-0.21), np.float64(2.32), np.float64(-0.21), np.float64(1.33), np.float64(-1.0), np.float64(-0.38), np.float64(-1.0), np.float64(0.7), np.float64(0.21), np.float64(-1.0), np.float64(1.42), np.float64(-1.0), np.float64(0.97), np.float64(0.97), np.float64(-0.57), np.float64(-1.0), np.float64(-0.66), np.float64(-1.0), np.float64(-1.0), np.float64(-0.53), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(2.9), np.float64(0.19), np.float64(-1.0), np.float64(-1.0), np.float64(0.89), np.float64(-0.35), np.float64(-0.59), np.float64(0.05), np.float64(-1.0), np.float64(-1.0), np.float64(6.5), np.float64(-1.0), np.float64(0.34), np.float64(-0.41)]
#
# 📅 2025-05-26 Summary:
#    📈 Trades Taken: 50
#    💰 Day's Return: 1.39%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.12), np.float64(-1.0), np.float64(-1.0), np.float64(-0.49), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.22), np.float64(4.31), np.float64(-1.0), np.float64(0.23), np.float64(-1.0), np.float64(9.51), np.float64(1.98), np.float64(-1.0), np.float64(-0.65), np.float64(1.08), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.31), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.98), np.float64(2.27), np.float64(-0.05), np.float64(-0.73), np.float64(-1.0), np.float64(2.79), np.float64(0.53), np.float64(0.08), np.float64(-1.0), np.float64(-1.0), np.float64(2.1), np.float64(-1.0), np.float64(-0.68), np.float64(-1.0), np.float64(-1.0), np.float64(-0.68), np.float64(1.22), np.float64(-1.0), np.float64(2.29), np.float64(0.39), np.float64(0.22)]
#
# 📅 2025-05-27 Summary:
#    📈 Trades Taken: 36
#    💰 Day's Return: -9.5%
#    📋 Trades PnL: [np.float64(0.24), np.float64(0.29), np.float64(-0.11), np.float64(1.32), np.float64(-1.0), np.float64(-1.0), np.float64(6.85), np.float64(-1.0), np.float64(-1.0), np.float64(0.33), np.float64(-1.0), np.float64(0.37), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.67), np.float64(-0.82), np.float64(0.55), np.float64(-0.45), np.float64(0.5), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.37), np.float64(-1.0), np.float64(0.27), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.86), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📅 2025-05-28 Summary:
#    📈 Trades Taken: 40
#    💰 Day's Return: 6.07%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(4.47), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.56), np.float64(2.39), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.83), np.float64(-1.0), np.float64(-0.06), np.float64(1.0), np.float64(3.5), np.float64(3.84), np.float64(1.88), np.float64(1.82), np.float64(-1.0), np.float64(-0.14), np.float64(-0.77), np.float64(-1.0), np.float64(-0.21), np.float64(0.87), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(3.12), np.float64(-0.06), np.float64(2.88), np.float64(-1.0), np.float64(-0.23), np.float64(-0.39), np.float64(-1.0), np.float64(0.77), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📅 2025-05-29 Summary:
#    📈 Trades Taken: 44
#    💰 Day's Return: 8.16%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.49), np.float64(-0.31), np.float64(-1.0), np.float64(0.39), np.float64(0.42), np.float64(-1.0), np.float64(0.26), np.float64(0.43), np.float64(-1.0), np.float64(1.6), np.float64(-1.0), np.float64(-0.28), np.float64(-1.0), np.float64(0.41), np.float64(-0.05), np.float64(-1.0), np.float64(0.64), np.float64(1.88), np.float64(0.74), np.float64(0.67), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.71), np.float64(-0.28), np.float64(0.32), np.float64(1.37), np.float64(0.37), np.float64(2.44), np.float64(1.13), np.float64(0.08), np.float64(-1.0), np.float64(1.18), np.float64(0.2), np.float64(0.03), np.float64(1.92), np.float64(0.73), np.float64(0.49), np.float64(0.98), np.float64(0.62), np.float64(-1.0), np.float64(0.83), np.float64(0.73)]
#
# 📅 2025-05-30 Summary:
#    📈 Trades Taken: 70
#    💰 Day's Return: 46.14%
#    📋 Trades PnL: [np.float64(1.54), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(4.21), np.float64(0.08), np.float64(-1.0), np.float64(-1.0), np.float64(1.02), np.float64(-0.6), np.float64(0.14), np.float64(-1.0), np.float64(3.16), np.float64(-1.0), np.float64(1.76), np.float64(-1.0), np.float64(1.1), np.float64(0.81), np.float64(-1.0), np.float64(-1.0), np.float64(-0.25), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.22), np.float64(0.33), np.float64(-0.8), np.float64(-0.27), np.float64(2.82), np.float64(-0.34), np.float64(-0.51), np.float64(-0.29), np.float64(-1.0), np.float64(4.63), np.float64(2.62), np.float64(1.75), np.float64(-1.0), np.float64(-1.0), np.float64(1.67), np.float64(-0.75), np.float64(3.7), np.float64(1.82), np.float64(-1.0), np.float64(-0.81), np.float64(7.16), np.float64(12.69), np.float64(-1.0), np.float64(0.33), np.float64(3.75), np.float64(-0.45), np.float64(3.03), np.float64(-0.2), np.float64(3.0), np.float64(0.46), np.float64(0.0), np.float64(2.06), np.float64(1.05), np.float64(-1.0), np.float64(-1.0), np.float64(0.0), np.float64(-1.0), np.float64(0.87), np.float64(-1.0), np.float64(-1.0), np.float64(-0.02), np.float64(4.67), np.float64(2.52), np.float64(-1.0), np.float64(-1.0), np.float64(0.46)]
#
# 💼 Final Portfolio Value: ₹308030.26
# 📊 Daily Returns (%): [np.float64(-15.32), np.float64(12.85), np.float64(-6.32), np.float64(12.77), np.float64(-20.9), np.float64(9.87), np.float64(10.74), np.float64(-0.54), np.float64(17.13), np.float64(16.16), np.float64(45.43), np.float64(-8.24), np.float64(-6.77), np.float64(15.56), np.float64(11.64), np.float64(-5.12), np.float64(1.39), np.float64(-9.5), np.float64(6.07), np.float64(8.16), np.float64(46.14)]
#
# 🔍 Exit Reason Summary:
# ▶️ End of Day Exit: 608 trades → ✅ Wins: 431 | ❌ Losses: 177 | 🏆 Win%: 70.89%
# ▶️ SL Hit: 428 trades → ✅ Wins: 0 | ❌ Losses: 428 | 🏆 Win%: 0.0%

# %%
#trying ..........................................................................................................
import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....2PAqSpaL4PcIIVlWMjeqeTlyUJgfD4iDZmI0Ve_Mxco"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Inputs ===
dates_to_check = ["2025-06-23", "2025-06-24", "2025-06-25", "2025-06-26",
    "2025-06-27","2025-06-30","2025-07-01","2025-07-02","2025-07-03"]
fyers_symbols = fyers_symbols_filtered  # Make sure this list is defined

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
entry_buffer_pct = 0.01
min_body_pct = 0.0075
confirmation_breakout_pct = 0.015  # 1% breakout

# === Fetch 5-min Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]
            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            # ❌ Skip trade if upper wick is large
            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]
                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99  # ✅ Fixed 1% SL
                        remaining_candles = candles_after.iloc[j + 1:]

                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
all_trades = []

for date in dates_to_check:
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        print(f"✅ Data fetched: {symbol} on {date}, {len(df)} candles")
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            print(f"🔍 Trades found: {len(trades)}")
            all_trades.extend(trades)
        time.sleep(0)  # Adjust if needed to handle rate limit

# === Results ===
trades_df = pd.DataFrame(all_trades)

if trades_df.empty:
    print("\n❌ No trades were generated.")
else:
    trades_df['date'] = pd.to_datetime(trades_df['date']).dt.date
    daily_returns = []
    portfolio_value = 100000

    for date, group in trades_df.groupby('date'):
        pnls = group['pnl_%'].values
        trades_taken = len(pnls)
        day_return = round(np.sum(pnls), 2)
        daily_returns.append(np.float64(day_return))

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {trades_taken}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[np.float64(round(p, 2)) for p in pnls]}")

    for ret in daily_returns:
        portfolio_value *= (1 + float(ret) / 100)

    print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
    print(f"📊 Daily Returns (%): {daily_returns}")

    print("\n🔍 Exit Reason Summary:")
    exit_summary = trades_df['reason'].value_counts().to_dict()
    for reason in exit_summary:
        total = exit_summary[reason]
        wins = sum((trades_df['reason'] == reason) & (trades_df['pnl_%'] > 0))
        losses = total - wins
        win_pct = round((wins / total) * 100, 2)
        print(f"▶️ {reason}: {total} trades → ✅ Wins: {wins} | ❌ Losses: {losses} | 🏆 Win%: {win_pct}%")

    print("\n📋 Trade Log:")
    print(trades_df[['date', 'symbol', 'trigger_time', 'entry_time', 'entry_price',
                     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
# Out:
# ✅ Data fetched: NSE:360ONE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:3MINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:63MOONS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AADHARHFC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIDRUGS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AARTIPHARM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AAVAS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABB-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABBOTINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABCAPITAL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABDL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABFRL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:ABREL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ABSLAMC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACI-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACMESOLAR-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ACUTAAS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIENSOL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIENT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIGREEN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIPORTS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADANIPOWER-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADFFOODS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ADVENZYMES-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AEGISLOG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AEGISVOPAK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AETHER-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AFCONS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AFFLE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AGARWALEYE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AGI-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AHLUCONT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AIAENG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AIIL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJANTPHARM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJAXENGG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AJMERA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AKUMS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AKZOINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALEMBICLTD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALIVUS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALKEM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALKYLAMINE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:ALLCARGO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ALOKINDS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AMBER-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AMBUJACEM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANANDRATHI-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANANTRAJ-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANGELONE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANUP-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ANURAS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APARINDS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APLAPOLLO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APLLTD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLOHOSP-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APOLLOTYRE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:APTUS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARE&M-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARKADE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVINDFASN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ARVSMART-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASAHIINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:ASHAPURMIN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHIANA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHOKA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASHOKLEY-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASIANPAINT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASKAUTOLTD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTERDM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAMICRO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ASTRAZEN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATGL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATHERENERG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ATUL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AUBANK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AURIONPRO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AUROPHARMA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVALON-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVANTEL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVANTIFEED-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AVL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AWFIS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AWL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AXISBANK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:AZAD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJ-AUTO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJELEC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJFINSV-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHFL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJAJHIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BAJAJHLDNG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAJFINANCE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALAMINES-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALKRISIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALMLAWRIE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BALRAMCHIN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANARISUG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANCOINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANDHANBNK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANKBARODA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANKINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BANSALWIRE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BASF-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BATAINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BAYERCROP-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BBL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BBTC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BDL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BECTORFOOD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BEL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BELRISE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BEML-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BERGEPAINT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHAGCHEM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARATFORG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARATRAS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARTIARTL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHARTIHEXA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BHEL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIKAJI-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIOCON-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BIRLACORPN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLACKBUCK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUEDART-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUEJET-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BLUESTARCO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:BOMDYEING-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOROLTD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BORORENEW-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BOSCHLTD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BPCL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BRIGADE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BRITANNIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BSE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:BSOFT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAMPUS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAMS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CANBK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CANFINHOME-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CAPLIPOINT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARBORUNIV-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARERATING-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CARTRADE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CASTROLIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:CCL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 1
# ✅ Data fetched: NSE:CDSL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEATLTD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CEIGALL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CELLO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CENTRALBK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CENTUM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CENTURYPLY-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CERA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CESC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CGCL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CGPOWER-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHALET-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHAMBLFERT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHEMPLASTS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHENNPETRO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHOICEIN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHOLAFIN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CHOLAHLDNG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CIEINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CIGNITITEC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CIPLA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CLEAN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CMSINFO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COALINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COCHINSHIP-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COFORGE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COHANCE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COLPAL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CONCOR-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CONCORDBIO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COROMANDEL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:COSMOFIRST-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CRAFTSMAN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CREDITACC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CRISIL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CROMPTON-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CSBBANK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CUB-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CUMMINSIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CYIENT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:CYIENTDLM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:
-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ULTRACEMCO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:UNICHEMLAB-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:UNIONBANK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:UNITDSPR-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:UNOMINDA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:UPL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:USHAMART-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:UTIAMC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:V2RETAIL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VADILALIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VAIBHAVGBL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VARROC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VBL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VEDL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VENTIVE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VESUVIUS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VGUARD-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VIJAYA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VINATIORGA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VIPIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VISHNU-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VMART-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VMM-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VOLTAMP-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VOLTAS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VRLLOG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VSTIND-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VSTTILLERS-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:VTL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WAAREEENER-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WAAREERTL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WABAG-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WEBELSOLAR-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WELCORP-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WELENT-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WELSPUNLIV-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WESTLIFE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WHIRLPOOL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WINDMACHIN-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WIPRO-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WOCKPHARMA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WONDERLA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:WSTCSTPAPR-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:YATHARTH-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:YESBANK-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZAGGLE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZEEL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZENSARTECH-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZENTEC-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZFCVINDIA-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZYDUSLIFE-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
# ✅ Data fetched: NSE:ZYDUSWELL-EQ on 2025-07-02, 75 candles
# 🔍 Trades found: 0
#
# 📅 2025-07-02 Summary:
#    📈 Trades Taken: 28
#    💰 Day's Return: 11.85%
#    📋 Trades PnL: [np.float64(1.92), np.float64(0.29), np.float64(4.87), np.float64(-1.0), np.float64(-0.06), np.float64(-0.09), np.float64(2.89), np.float64(0.48), np.float64(1.34), np.float64(-1.0), np.float64(1.43), np.float64(-1.0), np.float64(-1.0), np.float64(0.42), np.float64(-1.0), np.float64(-1.0), np.float64(1.97), np.float64(2.29), np.float64(-1.0), np.float64(-0.6), np.float64(0.18), np.float64(-1.0), np.float64(-0.27), np.float64(-1.0), np.float64(5.26), np.float64(0.53), np.float64(-1.0), np.float64(-1.0)]
#
# 💼 Final Portfolio Value: ₹111850.0
# 📊 Daily Returns (%): [np.float64(11.85)]
#
# 🔍 Exit Reason Summary:
# ▶️ End of Day Exit: 17 trades → ✅ Wins: 13 | ❌ Losses: 4 | 🏆 Win%: 76.47%
# ▶️ SL Hit: 11 trades → ✅ Wins: 0 | ❌ Losses: 11 | 🏆 Win%: 0.0%
#
# 📋 Trade Log:
#       date            symbol              trigger_time                entry_time  entry_price                 exit_time  exit_price  pnl_%          reason
# 2025-07-02      NSE:ABFRL-EQ 2025-07-02 13:50:00+05:30 2025-07-02 13:55:00+05:30        76.29 2025-07-02 15:25:00+05:30       77.75   1.92 End of Day Exit
# 2025-07-02 NSE:ALKYLAMINE-EQ 2025-07-02 12:20:00+05:30 2025-07-02 12:25:00+05:30      2333.18 2025-07-02 15:25:00+05:30     2339.90   0.29 End of Day Exit
# 2025-07-02 NSE:ASAHIINDIA-EQ 2025-07-02 12:15:00+05:30 2025-07-02 12:40:00+05:30       798.30 2025-07-02 15:25:00+05:30      837.15   4.87 End of Day Exit
# 2025-07-02  NSE:BAJAJHIND-EQ 2025-07-02 13:30:00+05:30 2025-07-02 13:35:00+05:30        27.30 2025-07-02 13:50:00+05:30       27.03  -1.00          SL Hit
# 2025-07-02 NSE:BLUESTARCO-EQ 2025-07-02 14:25:00+05:30 2025-07-02 14:40:00+05:30      1760.01 2025-07-02 15:25:00+05:30     1759.00  -0.06 End of Day Exit
# 2025-07-02     NSE:PFOCUS-EQ 2025-07-02 12:15:00+05:30 2025-07-02 12:30:00+05:30       156.80 2025-07-02 14:05:00+05:30      155.23  -1.00          SL Hit
# 2025-07-02     NSE:SAGCEM-EQ 2025-07-02 13:40:00+05:30 2025-07-02 14:15:00+05:30       247.50 2025-07-02 15:25:00+05:30      246.83  -0.27 End of Day Exit
# 2025-07-02 NSE:SINDHUTRAD-EQ 2025-07-02 12:55:00+05:30 2025-07-02 14:25:00+05:30        27.90 2025-07-02 15:15:00+05:30       27.62  -1.00          SL Hit
# 2025-07-02     NSE:SUBROS-EQ 2025-07-02 11:35:00+05:30 2025-07-02 13:10:00+05:30       964.25 2025-07-02 15:25:00+05:30     1015.00   5.26 End of Day Exit
# 2025-07-02  NSE:TEAMLEASE-EQ 2025-07-02 11:30:00+05:30 2025-07-02 12:10:00+05:30      2039.64 2025-07-02 15:25:00+05:30     2050.50   0.53 End of Day Exit
# 2025-07-02    NSE:THERMAX-EQ 2025-07-02 11:25:00+05:30 2025-07-02 11:30:00+05:30      3433.64 2025-07-02 12:30:00+05:30     3399.31  -1.00          SL Hit
# 2025-07-02      NSE:TRENT-EQ 2025-07-02 11:40:00+05:30 2025-07-02 11:45:00+05:30      6216.87 2025-07-02 13:45:00+05:30     6154.71  -1.00          SL Hit

# %%
import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....pxfBGTzIVRRK6od1SOpu_9svlO2eklfih1CUWc_8hlI"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Load Market Cap Data ===
market_cap_df = pd.read_csv('/content/stocks_above_1kcr.csv')
market_cap_dict = dict(zip(market_cap_df['SYMBOL'], market_cap_df['MARKET_CAP_CR']))

# === Inputs ===
dates_to_check = ["2025-06-23", "2025-06-24", "2025-06-25", "2025-06-26",
                 "2025-06-27", "2025-06-30", "2025-07-01", "2025-07-02", "2025-07-03"]
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
entry_buffer_pct = 0.01
min_body_pct = 0.005
confirmation_breakout_pct = 0.015

# === Fetch 5-min Candle Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]
            # === Reject breakouts after 2:30 PM ===
            if breakout_candle['timestamp'].time() > pd.to_datetime("14:30").time():
              continue
            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]
                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99
                        remaining_candles = candles_after.iloc[j + 1:]
                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        symbol_key = symbol.split(':')[-1].split('-')[0]
                        market_cap = market_cap_dict.get(symbol_key, np.nan)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'market_cap_cr': round(market_cap, 2) if not pd.isna(market_cap) else np.nan,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
portfolio_value = 100000
all_trades = []

for date in dates_to_check:
    daily_trades = []
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            daily_trades.extend(trades)
        time.sleep(0)

    # Daily logs
    if daily_trades:
        daily_df = pd.DataFrame(daily_trades)
        all_trades.extend(daily_trades)

        pnls = daily_df['pnl_%'].values
        day_return = round(np.sum(pnls), 2)
        portfolio_value *= (1 + float(day_return) / 100)

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {len(pnls)}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")
        print("\n📋 Trade Log with Market Cap:")
        #print(daily_df[['date', 'symbol', 'market_cap_cr', 'trigger_time', 'entry_time', 'entry_price',
                    #    'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
    else:
        print(f"\n📅 {date} — ❌ No trades generated.")

# === Final Portfolio Summary ===
print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
# === Save Entire Trade Log to CSV ===
if all_trades:
    all_trades_df = pd.DataFrame(all_trades)
    all_trades_df.to_csv("all_trade_log.csv", index=False)
    print("✅ Saved all trades to all_trade_log.csv")
else:
    print("⚠️ No trades to save.")
# Out:
# 📅 2025-06-23 Summary:
#    📈 Trades Taken: 49
#    💰 Day's Return: -1.67%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.55), np.float64(-0.22), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.12), np.float64(1.63), np.float64(-1.0), np.float64(-0.29), np.float64(-1.0), np.float64(-0.13), np.float64(1.24), np.float64(0.22), np.float64(-1.0), np.float64(-1.0), np.float64(1.55), np.float64(-1.0), np.float64(0.39), np.float64(-0.71), np.float64(-0.17), np.float64(1.41), np.float64(2.15), np.float64(0.4), np.float64(0.67), np.float64(-1.0), np.float64(-0.56), np.float64(-0.09), np.float64(-0.7), np.float64(0.68), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.87), np.float64(0.4), np.float64(-0.61), np.float64(6.21), np.float64(-1.0), np.float64(-1.0), np.float64(-0.03), np.float64(-0.18), np.float64(-0.15), np.float64(-1.0), np.float64(0.75), np.float64(0.11), np.float64(1.66), np.float64(0.26), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-24 Summary:
#    📈 Trades Taken: 25
#    💰 Day's Return: -10.35%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.42), np.float64(-1.0), np.float64(0.39), np.float64(1.29), np.float64(1.5), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.04), np.float64(0.13), np.float64(-1.0), np.float64(-1.0), np.float64(-0.41), np.float64(2.03), np.float64(0.19), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.09), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-25 Summary:
#    📈 Trades Taken: 55
#    💰 Day's Return: 9.99%
.float64(-0.84), np.float64(-1.0), np.float64(-0.16), np.float64(0.01), np.float64(-0.4), np.float64(0.18), np.float64(-1.0), np.float64(0.31), np.float64(1.62), np.float64(-1.0), np.float64(9.91), np.float64(0.31), np.float64(-0.65), np.float64(1.54), np.float64(7.64), np.float64(1.94), np.float64(-0.48), np.float64(-0.66), np.float64(-0.08), np.float64(1.29), np.float64(0.33), np.float64(-0.39), np.float64(0.1), np.float64(0.08), np.float64(-0.51), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-01 Summary:
#    📈 Trades Taken: 47
#    💰 Day's Return: 10.22%
#    📋 Trades PnL: [np.float64(-0.69), np.float64(0.1), np.float64(2.18), np.float64(-0.32), np.float64(0.83), np.float64(-1.0), np.float64(0.45), np.float64(0.48), np.float64(-0.38), np.float64(-0.46), np.float64(0.69), np.float64(-1.0), np.float64(-1.0), np.float64(0.82), np.float64(0.66), np.float64(0.1), np.float64(-0.28), np.float64(1.15), np.float64(-1.0), np.float64(-1.0), np.float64(0.1), np.float64(4.14), np.float64(0.3), np.float64(0.3), np.float64(-0.31), np.float64(0.39), np.float64(4.21), np.float64(-1.0), np.float64(0.33), np.float64(-1.0), np.float64(-1.0), np.float64(-0.18), np.float64(-1.0), np.float64(-1.0), np.float64(0.16), np.float64(0.04), np.float64(-1.0), np.float64(1.89), np.float64(0.72), np.float64(1.82), np.float64(2.19), np.float64(-0.6), np.float64(-0.08), np.float64(-0.22), np.float64(-0.08), np.float64(-0.31), np.float64(1.08)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-02 Summary:
#    📈 Trades Taken: 44
#    💰 Day's Return: 12.45%
#    📋 Trades PnL: [np.float64(1.92), np.float64(0.29), np.float64(-0.35), np.float64(4.87), np.float64(-1.0), np.float64(-1.0), np.float64(-0.06), np.float64(-0.09), np.float64(2.89), np.float64(-1.0), np.float64(-0.48), np.float64(0.48), np.float64(1.34), np.float64(-0.53), np.float64(0.07), np.float64(-1.0), np.float64(1.43), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.68), np.float64(0.42), np.float64(-1.0), np.float64(-1.0), np.float64(1.97), np.float64(2.29), np.float64(2.91), np.float64(-1.0), np.float64(0.15), np.float64(-0.6), np.float64(0.18), np.float64(-1.0), np.float64(-0.27), np.float64(-0.63), np.float64(-1.0), np.float64(5.26), np.float64(0.58), np.float64(1.12), np.float64(0.53), np.float64(-1.0), np.float64(-1.0), np.float64(1.24), np.float64(-1.0), np.float64(-0.16)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-03 Summary:
#    📈 Trades Taken: 42
#    💰 Day's Return: -12.12%
#    📋 Trades PnL: [np.float64(0.99), np.float64(-1.0), np.float64(-1.0), np.float64(-0.42), np.float64(1.66), np.float64(-1.0), np.float64(-1.0), np.float64(0.5), np.float64(-1.0), np.float64(-1.0), np.float64(0.14), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(2.73), np.float64(-1.0), np.float64(1.08), np.float64(1.3), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.18), np.float64(0.13), np.float64(-1.0), np.float64(0.96), np.float64(-0.57), np.float64(-1.0), np.float64(-1.0), np.float64(0.31), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.74), np.float64(-1.0), np.float64(-1.0), np.float64(1.75), np.float64(0.29), np.float64(0.05), np.float64(-1.0), np.float64(0.2), np.float64(0.34)]
#
# 📋 Trade Log with Market Cap:
#
# 💼 Final Portfolio Value: ₹171649.51
# ✅ Saved all trades to all_trade_log.csv

# %%
## NO TRADE AFTER 2:30PM

import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....V61box-fjvi_UfGekd2WoAuCmAEXz21fd-ow5Un2ukY"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Load Market Cap Data ===
market_cap_df = pd.read_csv('/content/stocks_above_1kcr.csv')
market_cap_dict = dict(zip(market_cap_df['SYMBOL'], market_cap_df['MARKET_CAP_CR']))

# === Inputs ===
dates_to_check = ["2025-06-23", "2025-06-24", "2025-06-25", "2025-06-26",
                 "2025-06-27", "2025-06-30", "2025-07-01", "2025-07-02", "2025-07-03"]
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
entry_buffer_pct = 0.01
min_body_pct = 0.005
confirmation_breakout_pct = 0.015

# === Fetch 5-min Candle Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]
            # === Reject breakouts after 2:30 PM ===
            if breakout_candle['timestamp'].time() > pd.to_datetime("14:30").time():
              continue
            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]
                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99
                        remaining_candles = candles_after.iloc[j + 1:]
                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        symbol_key = symbol.split(':')[-1].split('-')[0]
                        market_cap = market_cap_dict.get(symbol_key, np.nan)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'market_cap_cr': round(market_cap, 2) if not pd.isna(market_cap) else np.nan,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
portfolio_value = 100000
all_trades = []

for date in dates_to_check:
    daily_trades = []
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            daily_trades.extend(trades)
        time.sleep(0)

    # Daily logs
    if daily_trades:
        daily_df = pd.DataFrame(daily_trades)
        all_trades.extend(daily_trades)

        pnls = daily_df['pnl_%'].values
        day_return = round(np.sum(pnls), 2)
        portfolio_value *= (1 + float(day_return) / 100)

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {len(pnls)}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")
        print("\n📋 Trade Log with Market Cap:")
        #print(daily_df[['date', 'symbol', 'market_cap_cr', 'trigger_time', 'entry_time', 'entry_price',
                    #    'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
    else:
        print(f"\n📅 {date} — ❌ No trades generated.")

# === Final Portfolio Summary ===
print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
# === Save Entire Trade Log to CSV ===
if all_trades:
    all_trades_df = pd.DataFrame(all_trades)
    #all_trades_df.to_csv("all_trade_log.csv", index=False)
    print("✅ Saved all trades to all_trade_log.csv")
else:
    print("⚠️ No trades to save.")
# Out:
# 📅 2025-06-23 Summary:
#    📈 Trades Taken: 30
#    💰 Day's Return: 4.95%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.55), np.float64(-0.22), np.float64(-1.0), np.float64(-1.0), np.float64(0.12), np.float64(1.63), np.float64(-1.0), np.float64(-0.29), np.float64(-0.13), np.float64(1.24), np.float64(-1.0), np.float64(-1.0), np.float64(1.55), np.float64(-1.0), np.float64(0.39), np.float64(-0.71), np.float64(-0.17), np.float64(1.41), np.float64(2.15), np.float64(0.68), np.float64(-1.0), np.float64(-1.0), np.float64(6.21), np.float64(-1.0), np.float64(-0.03), np.float64(-1.0), np.float64(0.75), np.float64(1.66), np.float64(0.26)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-24 Summary:
#    📈 Trades Taken: 17
#    💰 Day's Return: -9.37%
#    📋 Trades PnL: [np.float64(-0.42), np.float64(-1.0), np.float64(0.39), np.float64(-1.0), np.float64(-1.0), np.float64(0.13), np.float64(-1.0), np.float64(-1.0), np.float64(-0.41), np.float64(2.03), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.09), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-25 Summary:
#    📈 Trades Taken: 35
#    💰 Day's Return: 12.63%
#    📋 Trades PnL: [np.float64(0.36), np.float64(-1.0), np.float64(-1.0), np.float64(-0.19), np.float64(1.21), np.float64(0.44), np.float64(2.23), np.float64(2.92), np.float64(-0.16), np.float64(-0.84), np.float64(-0.07), np.float64(-0.19), np.float64(0.63), np.float64(0.18), np.float64(-1.0), np.float64(0.46), np.float64(0.5), np.float64(0.99), np.float64(3.18), np.float64(2.53), np.float64(0.88), np.float64(-0.08), np.float64(1.32), np.float64(-1.0), np.float64(2.56), np.float64(0.14), np.float64(0.05), np.float64(-0.31), np.float64(1.44), np.float64(-0.6), np.float64(-0.08), np.float64(-1.0), np.float64(0.13), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-26 Summary:
#    📈 Trades Taken: 24
#    💰 Day's Return: 6.23%
#    📋 Trades PnL: [np.float64(0.24), np.float64(3.52), np.float64(2.83), np.float64(0.38), np.float64(-0.78), np.float64(-1.0), np.float64(1.86), np.float64(-0.25), np.float64(-1.0), np.float64(0.16), np.float64(-0.16), np.float64(-0.71), np.float64(-0.01), np.float64(0.39), np.float64(-1.0), np.float64(0.29), np.float64(0.69), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.17), np.float64(1.35), np.float64(0.4), np.float64(2.2)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-27 Summary:
#    📈 Trades Taken: 34
#    💰 Day's Return: 8.91%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.53), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.3), np.float64(-1.0), np.float64(5.76), np.float64(1.46), np.float64(0.74), np.float64(-1.0), np.float64(-0.52), np.float64(-1.0), np.float64(5.16), np.float64(1.51), np.float64(-0.6), np.float64(3.17), np.float64(-0.78), np.float64(-1.0), np.float64(-1.0), np.float64(6.19), np.float64(-1.0), np.float64(-1.0), np.float64(0.11), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.15), np.float64(0.41), np.float64(1.67), np.float64(0.15), np.float64(0.4)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-30 Summary:
#    📈 Trades Taken: 38
#    💰 Day's Return: 14.12%
#    📋 Trades PnL: [np.float64(0.53), np.float64(0.85), np.float64(-1.0), np.float64(-0.43), np.float64(-1.0), np.float64(-0.75), np.float64(0.03), np.float64(0.08), np.float64(0.51), np.float64(-1.0), np.float64(5.39), np.float64(0.7), np.float64(1.64), np.float64(-1.0), np.float64(-1.0), np.float64(-0.11), np.float64(-0.21), np.float64(0.65), np.float64(-0.09), np.float64(1.06), np.float64(-1.0), np.float64(1.06), np.float64(-0.16), np.float64(0.01), np.float64(-1.0), np.float64(1.62), np.float64(-1.0), np.float64(0.31), np.float64(7.64), np.float64(1.94), np.float64(-0.48), np.float64(-0.08), np.float64(1.29), np.float64(0.33), np.float64(-0.39), np.float64(0.1), np.float64(0.08), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-01 Summary:
#    📈 Trades Taken: 31
#    💰 Day's Return: 11.35%
#    📋 Trades PnL: [np.float64(-0.69), np.float64(0.1), np.float64(2.18), np.float64(-0.32), np.float64(-1.0), np.float64(0.45), np.float64(0.48), np.float64(-0.38), np.float64(-0.46), np.float64(0.69), np.float64(-1.0), np.float64(-1.0), np.float64(0.66), np.float64(-0.28), np.float64(1.15), np.float64(-1.0), np.float64(0.1), np.float64(-0.31), np.float64(0.39), np.float64(4.21), np.float64(0.33), np.float64(0.04), np.float64(1.89), np.float64(0.72), np.float64(1.82), np.float64(2.19), np.float64(-0.08), np.float64(-0.22), np.float64(-0.08), np.float64(-0.31), np.float64(1.08)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-02 Summary:
#    📈 Trades Taken: 33
#    💰 Day's Return: 13.61%
#    📋 Trades PnL: [np.float64(1.92), np.float64(0.29), np.float64(-0.35), np.float64(4.87), np.float64(-1.0), np.float64(-0.06), np.float64(-0.09), np.float64(2.89), np.float64(-1.0), np.float64(-0.48), np.float64(0.48), np.float64(-0.53), np.float64(0.07), np.float64(1.43), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.68), np.float64(-1.0), np.float64(-1.0), np.float64(1.97), np.float64(2.29), np.float64(2.91), np.float64(-1.0), np.float64(0.15), np.float64(-0.63), np.float64(5.26), np.float64(0.58), np.float64(1.12), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.16)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-03 Summary:
#    📈 Trades Taken: 22
#    💰 Day's Return: -3.53%
#    📋 Trades PnL: [np.float64(0.99), np.float64(-1.0), np.float64(-0.42), np.float64(-1.0), np.float64(-1.0), np.float64(0.5), np.float64(-1.0), np.float64(0.14), np.float64(2.73), np.float64(-1.0), np.float64(1.08), np.float64(-1.0), np.float64(-1.0), np.float64(0.18), np.float64(0.13), np.float64(-1.0), np.float64(-0.74), np.float64(-1.0), np.float64(0.29), np.float64(0.05), np.float64(0.2), np.float64(0.34)]
#
# 📋 Trade Log with Market Cap:
#
# 💼 Final Portfolio Value: ₹172617.28
# ✅ Saved all trades to all_trade_log.csv

# %%
import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....XnYfyuH2W1P6TeIn4-0R-8ZCqIdYI0jTrcEDttXSfs8"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Load Market Cap Data ===
market_cap_df = pd.read_csv('/content/stocks_above_1kcr.csv')
market_cap_dict = dict(zip(market_cap_df['SYMBOL'], market_cap_df['MARKET_CAP_CR']))

# === Inputs ===
dates_to_check = [
    "2025-05-02", "2025-05-05", "2025-05-06", "2025-05-07", "2025-05-08",
    "2025-05-09", "2025-05-12", "2025-05-13", "2025-05-14", "2025-05-15",
    "2025-05-16", "2025-05-19", "2025-05-20", "2025-05-21", "2025-05-22",
    "2025-05-23", "2025-05-26", "2025-05-27", "2025-05-28", "2025-05-29",
    "2025-05-30"
]
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined before running

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
entry_buffer_pct = 0.01
min_body_pct = 0.005
confirmation_breakout_pct = 0.015

# === Fetch 5-min Candle Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]

            # Reject breakout after 2:30 PM
            if breakout_candle['timestamp'].time() > pd.to_datetime("14:30").time():
                continue

            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]

                    # Reject if entry happens after 2:30 PM
                    if row['timestamp'].time() > pd.to_datetime("14:30").time():
                        break

                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99
                        remaining_candles = candles_after.iloc[j + 1:]
                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        symbol_key = symbol.split(':')[-1].split('-')[0]
                        market_cap = market_cap_dict.get(symbol_key, np.nan)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'market_cap_cr': round(market_cap, 2) if not pd.isna(market_cap) else np.nan,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
portfolio_value = 100000
all_trades = []

for date in dates_to_check:
    daily_trades = []
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            daily_trades.extend(trades)
        time.sleep(0)

    # Daily logs
    if daily_trades:
        daily_df = pd.DataFrame(daily_trades)
        all_trades.extend(daily_trades)

        pnls = daily_df['pnl_%'].values
        day_return = round(np.sum(pnls), 2)
        portfolio_value *= (1 + float(day_return) / 100)

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {len(pnls)}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")
        print("\n📋 Trade Log with Market Cap:")
        # print(daily_df[['date', 'symbol', 'market_cap_cr', 'trigger_time', 'entry_time', 'entry_price',
        #     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
    else:
        print(f"\n📅 {date} — ❌ No trades generated.")

# === Final Portfolio Summary ===
print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")

# === Save Entire Trade Log to CSV ===
if all_trades:
    all_trades_df = pd.DataFrame(all_trades)
    # all_trades_df.to_csv("all_trade_log.csv", index=False)
    print("✅ Saved all trades to all_trade_log.csv")
else:
    print("⚠️ No trades to save.")
# Out:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-02
# ⚠️ No candles for NSE:ATHERENERG-EQ on 2025-05-02
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-02
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-02
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-02
#
# 📅 2025-05-02 Summary:
#    📈 Trades Taken: 12
#    💰 Day's Return: -3.93%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.09), np.float64(-0.74), np.float64(0.66), np.float64(-1.0), np.float64(-1.0), np.float64(1.52), np.float64(-1.0), np.float64(0.43), np.float64(0.29), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-05
# ⚠️ No candles for NSE:ATHERENERG-EQ on 2025-05-05
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-05
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-05
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-05
#
# 📅 2025-05-05 Summary:
#    📈 Trades Taken: 27
#    💰 Day's Return: 16.45%
#    📋 Trades PnL: [np.float64(-0.31), np.float64(1.06), np.float64(1.07), np.float64(1.21), np.float64(0.13), np.float64(2.09), np.float64(-1.0), np.float64(1.73), np.float64(2.13), np.float64(0.04), np.float64(0.28), np.float64(6.33), np.float64(-0.04), np.float64(0.61), np.float64(0.52), np.float64(-1.0), np.float64(0.91), np.float64(1.46), np.float64(-1.0), np.float64(-1.0), np.float64(0.61), np.float64(-0.11), np.float64(-1.0), np.float64(-0.57), np.float64(1.17), np.float64(1.3), np.float64(-0.17)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-06
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-06
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-06
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-06
#
# 📅 2025-05-06 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: -4.56%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.44)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-07
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-07
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-07
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-07
#
# 📅 2025-05-07 Summary:
#    📈 Trades Taken: 17
#    💰 Day's Return: 3.46%
#    📋 Trades PnL: [np.float64(-0.46), np.float64(2.25), np.float64(0.16), np.float64(0.37), np.float64(0.24), np.float64(-1.0), np.float64(0.3), np.float64(-1.0), np.float64(0.54), np.float64(-1.0), np.float64(2.72), np.float64(1.45), np.float64(-0.64), np.float64(1.13), np.float64(-1.0), np.float64(-1.0), np.float64(0.4)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-08
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-08
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-08
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-08
#
# 📅 2025-05-08 Summary:
#    📈 Trades Taken: 15
#    💰 Day's Return: -13.78%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.62), np.float64(-1.0), np.float64(-1.0), np.float64(-0.16), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-09
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-09
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-09
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-09
#
# 📅 2025-05-09 Summary:
#    📈 Trades Taken: 23
#    💰 Day's Return: 5.59%
#    📋 Trades PnL: [np.float64(0.24), np.float64(0.37), np.float64(0.53), np.float64(-1.0), np.float64(2.67), np.float64(-1.0), np.float64(-0.5), np.float64(1.59), np.float64(-1.0), np.float64(2.51), np.float64(-1.0), np.float64(-1.0), np.float64(0.36), np.float64(-0.18), np.float64(-1.0), np.float64(0.07), np.float64(-1.0), np.float64(3.52), np.float64(1.13), np.float64(-1.0), np.float64(-1.0), np.float64(0.25), np.float64(2.03)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-12
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-12
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-12
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-12
#
# 📅 2025-05-12 Summary:
#    📈 Trades Taken: 32
#    💰 Day's Return: -2.82%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(6.44), np.float64(-0.42), np.float64(0.05), np.float64(-1.0), np.float64(-0.13), np.float64(1.49), np.float64(1.45), np.float64(-1.0), np.float64(0.73), np.float64(-0.04), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.01), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.59), np.float64(-0.73), np.float64(0.01), np.float64(-1.0), np.float64(-1.0), np.float64(0.68), np.float64(0.27), np.float64(-1.0), np.float64(0.49), np.float64(0.63), np.float64(0.66), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-13
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-13
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-13
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-13
#
# 📅 2025-05-13 Summary:
#    📈 Trades Taken: 23
#    💰 Day's Return: -3.8%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(2.28), np.float64(-0.11), np.float64(-0.5), np.float64(1.08), np.float64(0.8), np.float64(0.56), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.32), np.float64(0.46), np.float64(1.08), np.float64(-1.0), np.float64(-1.0), np.float64(0.74), np.float64(0.06), np.float64(-1.0), np.float64(-1.0), np.float64(0.43), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-14
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-14
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-14
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-14
#
# 📅 2025-05-14 Summary:
#    📈 Trades Taken: 23
#    💰 Day's Return: -4.07%
#    📋 Trades PnL: [np.float64(2.98), np.float64(-1.0), np.float64(2.85), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.54), np.float64(0.2), np.float64(-1.0), np.float64(-0.01), np.float64(-1.0), np.float64(3.22), np.float64(-1.0), np.float64(-1.0), np.float64(0.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.51), np.float64(-1.0), np.float64(-0.2), np.float64(-0.08), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-15
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-15
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-15
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-15
#
# 📅 2025-05-15 Summary:
#    📈 Trades Taken: 34
#    💰 Day's Return: 11.01%
#    📋 Trades PnL: [np.float64(1.8), np.float64(-1.0), np.float64(1.64), np.float64(2.99), np.float64(1.32), np.float64(0.82), np.float64(0.6), np.float64(-0.03), np.float64(-0.4), np.float64(3.17), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.52), np.float64(-0.22), np.float64(-0.51), np.float64(-1.0), np.float64(-1.0), np.float64(3.75), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.07), np.float64(2.39), np.float64(0.07), np.float64(0.16), np.float64(0.79), np.float64(1.81), np.float64(1.83), np.float64(-1.0), np.float64(-1.0), np.float64(0.42), np.float64(0.16)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-16
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-16
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-16
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-16
#
# 📅 2025-05-16 Summary:
#    📈 Trades Taken: 45
#    💰 Day's Return: 11.58%
#    📋 Trades PnL: [np.float64(1.04), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.86), np.float64(0.22), np.float64(-0.45), np.float64(0.15), np.float64(1.94), np.float64(-1.0), np.float64(8.72), np.float64(-1.0), np.float64(1.52), np.float64(-0.36), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(2.05), np.float64(0.46), np.float64(-1.0), np.float64(2.23), np.float64(-1.0), np.float64(2.41), np.float64(0.01), np.float64(-1.0), np.float64(-1.0), np.float64(-0.31), np.float64(-1.0), np.float64(-1.0), np.float64(0.88), np.float64(-1.0), np.float64(0.09), np.float64(2.5), np.float64(0.53), np.float64(-1.0), np.float64(6.63), np.float64(0.66), np.float64(-1.0), np.float64(0.3), np.float64(0.15), np.float64(-1.0), np.float64(0.35), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-19
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-19
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-19
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-19
#
# 📅 2025-05-19 Summary:
#    📈 Trades Taken: 15
#    💰 Day's Return: -7.73%
#    📋 Trades PnL: [np.float64(0.99), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.11), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(3.39), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-20
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-20
# ⚠️ No candles for NSE:METROBRAND-EQ on 2025-05-20
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-20
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-20
#
# 📅 2025-05-20 Summary:
#    📈 Trades Taken: 10
#    💰 Day's Return: -1.05%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.38), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(5.03), np.float64(-1.0), np.float64(0.54)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-21
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-21
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-21
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-21
#
# 📅 2025-05-21 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: 4.46%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.72), np.float64(4.66), np.float64(0.44), np.float64(3.08)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-22
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-22
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-22
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-22
#
# 📅 2025-05-22 Summary:
#    📈 Trades Taken: 15
#    💰 Day's Return: 16.07%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(8.46), np.float64(-0.07), np.float64(1.86), np.float64(-1.0), np.float64(-1.0), np.float64(3.45), np.float64(-0.26), np.float64(0.72), np.float64(5.2), np.float64(1.36), np.float64(1.08), np.float64(-1.0), np.float64(-1.0), np.float64(-0.73)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-23
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-23
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-23
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-23
#
# 📅 2025-05-23 Summary:
#    📈 Trades Taken: 35
#    💰 Day's Return: -10.79%
#    📋 Trades PnL: [np.float64(0.1), np.float64(-1.0), np.float64(2.17), np.float64(-0.24), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(3.24), np.float64(0.61), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.32), np.float64(-1.0), np.float64(-1.0), np.float64(0.04), np.float64(-1.0), np.float64(0.99), np.float64(-1.0), np.float64(0.83), np.float64(-0.66), np.float64(0.92), np.float64(-0.6), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.94), np.float64(-1.0), np.float64(1.85), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.58)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-26
# ⚠️ No candles for NSE:BASF-EQ on 2025-05-26
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-26
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-26
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-26
#
# 📅 2025-05-26 Summary:
#    📈 Trades Taken: 23
#    💰 Day's Return: -3.11%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.62), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.73), np.float64(-0.26), np.float64(-0.18), np.float64(1.48), np.float64(-1.0), np.float64(-0.18), np.float64(-1.0), np.float64(-1.0), np.float64(2.29), np.float64(-1.0), np.float64(1.6), np.float64(-1.0), np.float64(1.09), np.float64(1.07), np.float64(-0.1), np.float64(-0.27)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-27
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-27
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-27
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-27
#
# 📅 2025-05-27 Summary:
#    📈 Trades Taken: 12
#    💰 Day's Return: -2.52%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.82), np.float64(1.13), np.float64(-0.16), np.float64(2.31), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.22), np.float64(-1.0), np.float64(-0.4)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-28
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-28
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-28
#
# 📅 2025-05-28 Summary:
#    📈 Trades Taken: 25
#    💰 Day's Return: 15.58%
#    📋 Trades PnL: [np.float64(1.69), np.float64(3.95), np.float64(-1.0), np.float64(0.86), np.float64(-1.0), np.float64(3.43), np.float64(1.88), np.float64(-1.0), np.float64(-1.0), np.float64(2.99), np.float64(3.33), np.float64(0.14), np.float64(1.38), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.37), np.float64(-1.0), np.float64(-1.0), np.float64(2.61), np.float64(-1.0), np.float64(5.83), np.float64(-0.88), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-29
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-29
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-29
#
# 📅 2025-05-29 Summary:
#    📈 Trades Taken: 22
#    💰 Day's Return: -3.54%
#    📋 Trades PnL: [np.float64(-0.08), np.float64(-1.0), np.float64(0.78), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.98), np.float64(1.38), np.float64(-1.0), np.float64(-1.0), np.float64(1.57), np.float64(-1.0), np.float64(-0.46), np.float64(1.42), np.float64(-1.0), np.float64(2.25), np.float64(-1.0), np.float64(-1.0), np.float64(0.24), np.float64(-0.45), np.float64(-1.0), np.float64(-0.17)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-30
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-30
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-30
#
# 📅 2025-05-30 Summary:
#    📈 Trades Taken: 44
#    💰 Day's Return: 20.62%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.23), np.float64(-1.0), np.float64(-1.0), np.float64(0.52), np.float64(0.99), np.float64(2.36), np.float64(2.66), np.float64(-0.17), np.float64(-1.0), np.float64(-1.0), np.float64(2.31), np.float64(-0.84), np.float64(-1.0), np.float64(-0.41), np.float64(4.11), np.float64(2.12), np.float64(1.25), np.float64(-1.0), np.float64(3.59), np.float64(1.32), np.float64(-1.0), np.float64(-1.0), np.float64(3.74), np.float64(1.68), np.float64(2.53), np.float64(-0.26), np.float64(-0.84), np.float64(2.5), np.float64(-0.49), np.float64(-1.0), np.float64(-1.0), np.float64(0.47), np.float64(-1.0), np.float64(2.06), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(4.16), np.float64(2.01), np.float64(-1.0), np.float64(0.05), np.float64(-0.03)]
#
# 📋 Trade Log with Market Cap:
#
# 💼 Final Portfolio Value: ₹140126.24
# ✅ Saved all trades to all_trade_log.csv

# %%
# trying different range
# USED 1.5% range here

import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....oqitGIQAW-OL1S9hcnFqi3AbvJzifvB92WoW3kEkImE"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Load Market Cap Data ===
market_cap_df = pd.read_csv('/content/stocks_above_1kcr.csv')
market_cap_dict = dict(zip(market_cap_df['SYMBOL'], market_cap_df['MARKET_CAP_CR']))

# === Inputs ===
dates_to_check = [
    "2025-05-02", "2025-05-05", "2025-05-06", "2025-05-07", "2025-05-08",
    "2025-05-09", "2025-05-12", "2025-05-13", "2025-05-14", "2025-05-15",
    "2025-05-16", "2025-05-19", "2025-05-20", "2025-05-21", "2025-05-22",
    "2025-05-23", "2025-05-26", "2025-05-27", "2025-05-28", "2025-05-29",
    "2025-05-30"
]
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined before running

# === Parameters ===
window_size = 24
max_range_pct = 0.015
volume_multiplier = 5
entry_buffer_pct = 0.01
min_body_pct = 0.005
confirmation_breakout_pct = 0.015

# === Fetch 5-min Candle Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]

            # Reject breakout after 2:30 PM
            if breakout_candle['timestamp'].time() > pd.to_datetime("14:30").time():
                continue

            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]

                    # Reject if entry happens after 2:30 PM
                    if row['timestamp'].time() > pd.to_datetime("14:30").time():
                        break

                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99
                        remaining_candles = candles_after.iloc[j + 1:]
                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        symbol_key = symbol.split(':')[-1].split('-')[0]
                        market_cap = market_cap_dict.get(symbol_key, np.nan)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'market_cap_cr': round(market_cap, 2) if not pd.isna(market_cap) else np.nan,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
portfolio_value = 100000
all_trades = []

for date in dates_to_check:
    daily_trades = []
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            daily_trades.extend(trades)
        time.sleep(0)

    # Daily logs
    if daily_trades:
        daily_df = pd.DataFrame(daily_trades)
        all_trades.extend(daily_trades)

        pnls = daily_df['pnl_%'].values
        day_return = round(np.sum(pnls), 2)
        portfolio_value *= (1 + float(day_return) / 100)

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {len(pnls)}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")
        print("\n📋 Trade Log with Market Cap:")
        # print(daily_df[['date', 'symbol', 'market_cap_cr', 'trigger_time', 'entry_time', 'entry_price',
        #     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
    else:
        print(f"\n📅 {date} — ❌ No trades generated.")

# === Final Portfolio Summary ===
print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")

# === Save Entire Trade Log to CSV ===
if all_trades:
    all_trades_df = pd.DataFrame(all_trades)
    # all_trades_df.to_csv("all_trade_log.csv", index=False)
    print("✅ Saved all trades to all_trade_log.csv")
else:
    print("⚠️ No trades to save.")
# Out:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-02
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-02
# ⚠️ No candles for NSE:ATHERENERG-EQ on 2025-05-02
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-02
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-02
#
# 📅 2025-05-02 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: -3.02%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(0.29), np.float64(-1.0), np.float64(0.43), np.float64(-1.0), np.float64(-0.74)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-05
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-05
# ⚠️ No candles for NSE:ATHERENERG-EQ on 2025-05-05
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-05
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-05
#
# 📅 2025-05-05 Summary:
#    📈 Trades Taken: 11
#    💰 Day's Return: 7.16%
#    📋 Trades PnL: [np.float64(1.17), np.float64(0.52), np.float64(2.09), np.float64(1.21), np.float64(0.61), np.float64(-0.17), np.float64(-0.04), np.float64(0.13), np.float64(-1.0), np.float64(1.73), np.float64(0.91)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-06
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-06
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-06
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-06
#
# 📅 2025-05-06 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: -1.0%
#    📋 Trades PnL: [np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-07
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-07
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-07
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-07
#
# 📅 2025-05-07 Summary:
#    📈 Trades Taken: 9
#    💰 Day's Return: 2.46%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(1.13), np.float64(0.54), np.float64(-1.0), np.float64(-1.0), np.float64(0.4), np.float64(0.3), np.float64(0.37), np.float64(2.72)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-08
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-08
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-08
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-08
#
# 📅 2025-05-08 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: -6.62%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.62)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-09
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-09
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-09
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-09
#
# 📅 2025-05-09 Summary:
#    📈 Trades Taken: 14
#    💰 Day's Return: 2.84%
#    📋 Trades PnL: [np.float64(1.13), np.float64(-1.0), np.float64(-0.18), np.float64(-1.0), np.float64(-1.0), np.float64(1.59), np.float64(2.51), np.float64(-1.0), np.float64(-1.0), np.float64(-0.5), np.float64(3.52), np.float64(0.53), np.float64(0.24), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-12
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-12
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-12
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-12
#
# 📅 2025-05-12 Summary:
#    📈 Trades Taken: 19
#    💰 Day's Return: 5.59%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(6.44), np.float64(-1.0), np.float64(0.05), np.float64(-0.42), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.49), np.float64(0.63), np.float64(0.59), np.float64(0.68), np.float64(0.01), np.float64(0.73), np.float64(-0.73), np.float64(0.01), np.float64(0.66), np.float64(0.49), np.float64(-0.04)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-13
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-13
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-13
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-13
#
# 📅 2025-05-13 Summary:
#    📈 Trades Taken: 11
#    💰 Day's Return: 2.52%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.08), np.float64(-1.0), np.float64(0.56), np.float64(1.08), np.float64(0.46), np.float64(2.28), np.float64(0.74), np.float64(0.32)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-14
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-14
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-14
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-14
#
# 📅 2025-05-14 Summary:
#    📈 Trades Taken: 13
#    💰 Day's Return: -3.93%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.54), np.float64(0.0), np.float64(0.2), np.float64(2.98), np.float64(-1.0), np.float64(-1.0), np.float64(-0.08), np.float64(0.51), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-15
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-15
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-15
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-15
#
# 📅 2025-05-15 Summary:
#    📈 Trades Taken: 22
#    💰 Day's Return: 5.16%
#    📋 Trades PnL: [np.float64(0.16), np.float64(2.99), np.float64(-1.0), np.float64(-1.0), np.float64(0.6), np.float64(1.83), np.float64(1.64), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(3.75), np.float64(-1.0), np.float64(-0.22), np.float64(-1.0), np.float64(-0.51), np.float64(0.16), np.float64(1.8), np.float64(1.32), np.float64(-0.4), np.float64(-1.0), np.float64(-0.03), np.float64(0.07)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-16
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-16
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-16
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-16
#
# 📅 2025-05-16 Summary:
#    📈 Trades Taken: 23
#    💰 Day's Return: -0.57%
#    📋 Trades PnL: [np.float64(0.53), np.float64(1.52), np.float64(-1.0), np.float64(-1.0), np.float64(2.23), np.float64(0.86), np.float64(-1.0), np.float64(0.22), np.float64(0.3), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(2.05), np.float64(0.66), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.36), np.float64(0.35), np.float64(-0.12), np.float64(0.15), np.float64(1.04), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-19
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-19
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-19
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-19
#
# 📅 2025-05-19 Summary:
#    📈 Trades Taken: 3
#    💰 Day's Return: -3.0%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-20
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-20
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-20
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-20
#
# 📅 2025-05-20 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: 3.41%
#    📋 Trades PnL: [np.float64(5.03), np.float64(0.38), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-21
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-21
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-21
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-21
#
# 📅 2025-05-21 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: 2.36%
#    📋 Trades PnL: [np.float64(3.08), np.float64(-0.72)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-22
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-22
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-22
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-22
#
# 📅 2025-05-22 Summary:
#    📈 Trades Taken: 8
#    💰 Day's Return: 13.59%
#    📋 Trades PnL: [np.float64(0.72), np.float64(1.86), np.float64(-1.0), np.float64(1.36), np.float64(8.46), np.float64(-0.26), np.float64(3.45), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-23
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-23
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-23
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-23
#
# 📅 2025-05-23 Summary:
#    📈 Trades Taken: 14
#    💰 Day's Return: -7.35%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(0.83), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(0.04), np.float64(-1.0), np.float64(-1.0), np.float64(-0.24), np.float64(0.92), np.float64(-1.0), np.float64(0.1), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-26
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-26
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-26
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-26
#
# 📅 2025-05-26 Summary:
#    📈 Trades Taken: 12
#    💰 Day's Return: -1.34%
#    📋 Trades PnL: [np.float64(1.48), np.float64(1.6), np.float64(-1.0), np.float64(0.73), np.float64(-1.0), np.float64(-1.0), np.float64(-0.27), np.float64(-1.0), np.float64(0.4), np.float64(-1.0), np.float64(-0.1), np.float64(-0.18)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-27
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-27
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-27
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-27
#
# 📅 2025-05-27 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: -5.62%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.22), np.float64(-0.4), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-28
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-28
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-28
#
# 📅 2025-05-28 Summary:
#    📈 Trades Taken: 12
#    💰 Day's Return: 0.03%
#    📋 Trades PnL: [np.float64(0.37), np.float64(-1.0), np.float64(-0.88), np.float64(-1.0), np.float64(1.38), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(1.69), np.float64(0.14), np.float64(3.33)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-29
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-29
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-29
#
# 📅 2025-05-29 Summary:
#    📈 Trades Taken: 11
#    💰 Day's Return: -4.14%
#    📋 Trades PnL: [np.float64(-0.46), np.float64(0.24), np.float64(-1.0), np.float64(0.78), np.float64(1.38), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.08), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-30
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-30
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-30
#
# 📅 2025-05-30 Summary:
#    📈 Trades Taken: 30
#    💰 Day's Return: 19.7%
#    📋 Trades PnL: [np.float64(-0.26), np.float64(-1.0), np.float64(0.05), np.float64(-1.0), np.float64(2.06), np.float64(2.5), np.float64(-0.84), np.float64(-1.0), np.float64(-1.0), np.float64(0.23), np.float64(1.25), np.float64(2.12), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.17), np.float64(-0.49), np.float64(-0.84), np.float64(-1.0), np.float64(2.53), np.float64(2.66), np.float64(4.16), np.float64(3.19), np.float64(-1.0), np.float64(-0.03), np.float64(4.11), np.float64(2.31), np.float64(2.01), np.float64(1.68), np.float64(0.47)]
#
# 📋 Trade Log with Market Cap:
#
# 💼 Final Portfolio Value: ₹127127.81
# ✅ Saved all trades to all_trade_log.csv

# %%
all_trades_df.to_csv("all_trade_log_0.15range.csv", index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ==== Sample Data ====
strategy1_data = {
    '2025-05-02': -3.93, '2025-05-05': 16.45, '2025-05-06': -4.56,
    '2025-05-07': 3.46, '2025-05-08': -13.78, '2025-05-09': 5.59,
    '2025-05-12': -2.82, '2025-05-13': -3.8, '2025-05-14': -4.07,
    '2025-05-15': 11.01, '2025-05-16': 11.58, '2025-05-19': -7.73,
    '2025-05-20': -1.05, '2025-05-21': 4.46, '2025-05-22': 16.07,
    '2025-05-23': -10.79, '2025-05-26': -3.11, '2025-05-27': -2.52,
    '2025-05-28': 15.58, '2025-05-29': -3.54, '2025-05-30': 20.62,
}

strategy1_trades = {
    '2025-05-02': 12, '2025-05-05': 27, '2025-05-06': 6,
    '2025-05-07': 17, '2025-05-08': 15, '2025-05-09': 23,
    '2025-05-12': 32, '2025-05-13': 23, '2025-05-14': 23,
    '2025-05-15': 34, '2025-05-16': 45, '2025-05-19': 15,
    '2025-05-20': 10, '2025-05-21': 7, '2025-05-22': 15,
    '2025-05-23': 35, '2025-05-26': 23, '2025-05-27': 12,
    '2025-05-28': 25, '2025-05-29': 22, '2025-05-30': 44,
}

strategy2_data = {
    '2025-05-02': -3.02, '2025-05-05': 7.16, '2025-05-06': -1.0,
    '2025-05-07': 2.46, '2025-05-08': -6.62, '2025-05-09': 2.84,
    '2025-05-12': 5.59, '2025-05-13': 2.52, '2025-05-14': -3.93,
    '2025-05-15': 5.16, '2025-05-16': -0.57, '2025-05-19': -3.0,
    '2025-05-20': 3.41, '2025-05-21': 2.36, '2025-05-22': 13.59,
    '2025-05-23': -7.35, '2025-05-26': -1.34, '2025-05-27': -5.62,
    '2025-05-28': 0.03, '2025-05-29': -4.14, '2025-05-30': 19.7,
}

strategy2_trades = {
    '2025-05-02': 6, '2025-05-05': 11, '2025-05-06': 1,
    '2025-05-07': 9, '2025-05-08': 7, '2025-05-09': 14,
    '2025-05-12': 19, '2025-05-13': 11, '2025-05-14': 13,
    '2025-05-15': 22, '2025-05-16': 23, '2025-05-19': 3,
    '2025-05-20': 4, '2025-05-21': 2, '2025-05-22': 8,
    '2025-05-23': 14, '2025-05-26': 12, '2025-05-27': 7,
    '2025-05-28': 12, '2025-05-29': 11, '2025-05-30': 30,
}

# ==== Capital Curve Function ====
def process_strategy(data_dict, trades_dict, cost_per_trade=40, initial_capital=100000):
    df = pd.DataFrame({
        'Return (%)': data_dict,
        'Trades': trades_dict
    })
    df.index = pd.to_datetime(df.index)
    df.sort_index(inplace=True)

    df['Cost (₹)'] = df['Trades'] * cost_per_trade
    df['Net Return (%)'] = df['Return (%)'] - (df['Cost (₹)'] / initial_capital * 100)

    df['Capital'] = initial_capital
    for i in range(1, len(df)):
        prev_cap = df.iloc[i - 1]['Capital']
        net_ret = df.iloc[i]['Net Return (%)']
        df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)

    df['Peak'] = df['Capital'].cummax()
    df['Drawdown (₹)'] = df['Capital'] - df['Peak']
    df['Drawdown (%)'] = df['Drawdown (₹)'] / df['Peak'] * 100

    return df, df['Drawdown (%)'].min()

# ==== Process Both Strategies ====
df1, max_dd1 = process_strategy(strategy1_data, strategy1_trades)
df2, max_dd2 = process_strategy(strategy2_data, strategy2_trades)

# ==== Print Max Drawdown ====
print(f"\n📉 Strategy 1 Max Drawdown: {max_dd1:.2f}%")
print(f"📉 Strategy 2 Max Drawdown: {max_dd2:.2f}%")

# ==== Capital Curve Plot ====
plt.figure(figsize=(14, 6))
plt.plot(df1.index, df1['Capital'], label='Strategy 1', linewidth=2)
plt.plot(df2.index, df2['Capital'], label='Strategy 2', linewidth=2)
plt.axhline(100000, color='gray', linestyle='--', label='Initial Capital')

# Add labels
for i, date in enumerate(df1.index):
    plt.text(date, df1['Capital'].iloc[i] + 200, f"{df1['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='blue')

for i, date in enumerate(df2.index):
    plt.text(date, df2['Capital'].iloc[i] - 500, f"{df2['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='purple')

plt.title('Capital Curve (Starting ₹1,00,000)')
plt.ylabel('Capital (₹)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ==== Drawdown Plot ====
plt.figure(figsize=(14, 5))
plt.plot(df1.index, df1['Drawdown (%)'], label='Strategy 1 Drawdown', linestyle='--', color='red')
plt.plot(df2.index, df2['Drawdown (%)'], label='Strategy 2 Drawdown', linestyle='--', color='purple')
plt.axhline(0, color='black', linestyle=':')
plt.title('Drawdown Over Time (%)')
plt.ylabel('Drawdown (%)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-19-4057383640.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '109832.23999999999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# /tmp/ipython-input-19-4057383640.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '106719.99999999999' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# 📉 Strategy 1 Max Drawdown: -23.87%
# 📉 Strategy 2 Max Drawdown: -19.18%

# %%
#enter only if the candle next to breakout candle is green and close of that is entry price

# %%
#try more compact range for may 25

# USED 1.0% range here

import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....iBbjbhrbYqHA2BC__1DI9WLG7XXN4Dbj2cLc7FohzF8"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Load Market Cap Data ===
market_cap_df = pd.read_csv('/content/stocks_above_1kcr.csv')
market_cap_dict = dict(zip(market_cap_df['SYMBOL'], market_cap_df['MARKET_CAP_CR']))

# === Inputs ===
dates_to_check = [
   "2025-05-19", "2025-05-20", "2025-05-21", "2025-05-22",
    "2025-05-23", "2025-05-26", "2025-05-27", "2025-05-28", "2025-05-29",
    "2025-05-30"
]
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined before running

# === Parameters ===
window_size = 24
max_range_pct = 0.01
volume_multiplier = 5
entry_buffer_pct = 0.01
min_body_pct = 0.005
confirmation_breakout_pct = 0.015

# === Fetch 5-min Candle Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]

            # Reject breakout after 2:30 PM
            if breakout_candle['timestamp'].time() > pd.to_datetime("14:30").time():
                continue

            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]

                    # Reject if entry happens after 2:30 PM
                    if row['timestamp'].time() > pd.to_datetime("14:30").time():
                        break

                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99
                        remaining_candles = candles_after.iloc[j + 1:]
                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        symbol_key = symbol.split(':')[-1].split('-')[0]
                        market_cap = market_cap_dict.get(symbol_key, np.nan)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'market_cap_cr': round(market_cap, 2) if not pd.isna(market_cap) else np.nan,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
portfolio_value = 100000
all_trades = []

for date in dates_to_check:
    daily_trades = []
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            daily_trades.extend(trades)
        time.sleep(0)

    # Daily logs
    if daily_trades:
        daily_df = pd.DataFrame(daily_trades)
        all_trades.extend(daily_trades)

        pnls = daily_df['pnl_%'].values
        day_return = round(np.sum(pnls), 2)
        portfolio_value *= (1 + float(day_return) / 100)

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {len(pnls)}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")
        print("\n📋 Trade Log with Market Cap:")
        # print(daily_df[['date', 'symbol', 'market_cap_cr', 'trigger_time', 'entry_time', 'entry_price',
        #     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
    else:
        print(f"\n📅 {date} — ❌ No trades generated.")

# === Final Portfolio Summary ===
print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")

# === Save Entire Trade Log to CSV ===
if all_trades:
    all_trades_df = pd.DataFrame(all_trades)
    # all_trades_df.to_csv("all_trade_log.csv", index=False)
    print("✅ Saved all trades to all_trade_log.csv")
else:
    print("⚠️ No trades to save.")
# Out:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-19
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-19
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-19
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-19
#
# 📅 2025-05-19 — ❌ No trades generated.
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-20
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-20
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-20
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-20
#
# 📅 2025-05-20 Summary:
#    📈 Trades Taken: 3
#    💰 Day's Return: 4.41%
#    📋 Trades PnL: [np.float64(5.03), np.float64(0.38), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-21
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-21
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-21
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-21
#
# 📅 2025-05-21 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: 3.08%
#    📋 Trades PnL: [np.float64(3.08)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-22
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-22
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-22
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-22
#
# 📅 2025-05-22 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: 11.63%
#    📋 Trades PnL: [np.float64(0.72), np.float64(8.46), np.float64(3.45), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-23
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-23
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-23
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-23
#
# 📅 2025-05-23 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: -6.24%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.24), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-26
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-26
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-26
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-26
#
# 📅 2025-05-26 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: 1.18%
#    📋 Trades PnL: [np.float64(1.6), np.float64(0.73), np.float64(-0.27), np.float64(-1.0), np.float64(0.4), np.float64(-0.1), np.float64(-0.18)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-27
# ⚠️ No candles for NSE:BELRISE-EQ on 2025-05-27
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-27
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-27
#
# 📅 2025-05-27 Summary:
#    📈 Trades Taken: 3
#    💰 Day's Return: -1.62%
#    📋 Trades PnL: [np.float64(-0.22), np.float64(-0.4), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-28
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-28
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-28
#
# 📅 2025-05-28 Summary:
#    📈 Trades Taken: 5
#    💰 Day's Return: 2.85%
#    📋 Trades PnL: [np.float64(1.38), np.float64(-1.0), np.float64(-1.0), np.float64(0.14), np.float64(3.33)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-29
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-29
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-29
#
# 📅 2025-05-29 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: -3.3%
#    📋 Trades PnL: [np.float64(-0.46), np.float64(0.24), np.float64(-1.0), np.float64(-1.0), np.float64(-0.08), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-05-30
# ⚠️ No candles for NSE:THELEELA-EQ on 2025-05-30
# ⚠️ No candles for NSE:AEGISVOPAK-EQ on 2025-05-30
#
# 📅 2025-05-30 Summary:
#    📈 Trades Taken: 15
#    💰 Day's Return: 19.4%
#    📋 Trades PnL: [np.float64(0.05), np.float64(2.06), np.float64(2.5), np.float64(0.23), np.float64(1.25), np.float64(2.12), np.float64(-1.0), np.float64(-0.49), np.float64(2.66), np.float64(4.16), np.float64(-1.0), np.float64(-0.03), np.float64(4.11), np.float64(2.31), np.float64(0.47)]
#
# 📋 Trade Log with Market Cap:
#
# 💼 Final Portfolio Value: ₹133153.2
# ✅ Saved all trades to all_trade_log.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ==== Sample Data ====
strategy3_data = {
    '2025-05-02': -1.71, '2025-05-05': 8.33, '2025-05-06': 0,
    '2025-05-07': 2.39, '2025-05-08': 1, '2025-05-09':7.12,
    '2025-05-12': 0.85, '2025-05-13': 4.76, '2025-05-14':-4.49,
    '2025-05-15': 4.08, '2025-05-16': 1.26, '2025-05-19': 0,
    '2025-05-20': 4.41, '2025-05-21': 3.08, '2025-05-22': 11.63,
    '2025-05-23': -6.24, '2025-05-26': 1.18, '2025-05-27': -1.62,
    '2025-05-28': 2.85, '2025-05-29': -3.3, '2025-05-30': 19.4
}

strategy3_trades = {
    '2025-05-02': 3, '2025-05-05': 9, '2025-05-06': 0,
    '2025-05-07': 4, '2025-05-08': -1, '2025-05-09':4,
    '2025-05-12': 6, '2025-05-13': 4, '2025-05-14': 7,
    '2025-05-15': 12, '2025-05-16': 12, '2025-05-19': 0,
    '2025-05-20': 3, '2025-05-21': 1, '2025-05-22': 4,
    '2025-05-23': 7, '2025-05-26': 7, '2025-05-27': 3,
    '2025-05-28': 5, '2025-05-29': 6, '2025-05-30': 15
}

strategy2_data = {
    '2025-05-02': -3.02, '2025-05-05': 7.16, '2025-05-06': -1.0,
    '2025-05-07': 2.46, '2025-05-08': -6.62, '2025-05-09': 2.84,
    '2025-05-12': 5.59, '2025-05-13': 2.52, '2025-05-14': -3.93,
    '2025-05-15': 5.16, '2025-05-16': -0.57, '2025-05-19': -3.0,
    '2025-05-20': 3.41, '2025-05-21': 2.36, '2025-05-22': 13.59,
    '2025-05-23': -7.35, '2025-05-26': -1.34, '2025-05-27': -5.62,
    '2025-05-28': 0.03, '2025-05-29': -4.14, '2025-05-30': 19.7,
}

strategy2_trades = {
    '2025-05-02': 6, '2025-05-05': 11, '2025-05-06': 1,
    '2025-05-07': 9, '2025-05-08': 7, '2025-05-09': 14,
    '2025-05-12': 19, '2025-05-13': 11, '2025-05-14': 13,
    '2025-05-15': 22, '2025-05-16': 23, '2025-05-19': 3,
    '2025-05-20': 4, '2025-05-21': 2, '2025-05-22': 8,
    '2025-05-23': 14, '2025-05-26': 12, '2025-05-27': 7,
    '2025-05-28': 12, '2025-05-29': 11, '2025-05-30': 30,
}

# ==== Capital Curve Function ====
def process_strategy(data_dict, trades_dict, cost_per_trade=0, initial_capital=100000):
    df = pd.DataFrame({
        'Return (%)': data_dict,
        'Trades': trades_dict
    })
    df.index = pd.to_datetime(df.index)
    df.sort_index(inplace=True)

    df['Cost (₹)'] = df['Trades'] * cost_per_trade
    df['Net Return (%)'] = df['Return (%)'] - (df['Cost (₹)'] / initial_capital * 100)

    df['Capital'] = initial_capital
    for i in range(1, len(df)):
        prev_cap = df.iloc[i - 1]['Capital']
        net_ret = df.iloc[i]['Net Return (%)']
        df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)

    df['Peak'] = df['Capital'].cummax()
    df['Drawdown (₹)'] = df['Capital'] - df['Peak']
    df['Drawdown (%)'] = df['Drawdown (₹)'] / df['Peak'] * 100

    return df, df['Drawdown (%)'].min()

# ==== Process Both Strategies ====
df1, max_dd1 = process_strategy(strategy3_data, strategy3_trades)
df2, max_dd2 = process_strategy(strategy2_data, strategy2_trades)

# ==== Print Max Drawdown ====
print(f"\n📉 Strategy 1 Max Drawdown: {max_dd1:.2f}%")
print(f"📉 Strategy 2 Max Drawdown: {max_dd2:.2f}%")

# ==== Capital Curve Plot ====
plt.figure(figsize=(14, 6))
plt.plot(df1.index, df1['Capital'], label='Strategy 1', linewidth=2)
plt.plot(df2.index, df2['Capital'], label='Strategy 2', linewidth=2)
plt.axhline(100000, color='gray', linestyle='--', label='Initial Capital')

# Add labels
for i, date in enumerate(df1.index):
    plt.text(date, df1['Capital'].iloc[i] + 200, f"{df1['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='blue')

for i, date in enumerate(df2.index):
    plt.text(date, df2['Capital'].iloc[i] - 500, f"{df2['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='purple')

plt.title('Capital Curve (Starting ₹1,00,000)')
plt.ylabel('Capital (₹)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ==== Drawdown Plot ====
plt.figure(figsize=(14, 5))
plt.plot(df1.index, df1['Drawdown (%)'], label='Strategy 1 Drawdown', linestyle='--', color='red')
plt.plot(df2.index, df2['Drawdown (%)'], label='Strategy 2 Drawdown', linestyle='--', color='purple')
plt.axhline(0, color='black', linestyle=':')
plt.title('Drawdown Over Time (%)')
plt.ylabel('Drawdown (%)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-8-1719480796.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '110919.087' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# /tmp/ipython-input-8-1719480796.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '107160.00000000001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# 📉 Strategy 1 Max Drawdown: -7.18%
# 📉 Strategy 2 Max Drawdown: -17.28%

# %%
# trying compact for june 25


import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....ur3OmGO0qJjSnyydc1ptPxxKabDzyGCZrJvhn6PUeDM"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Load Market Cap Data ===
market_cap_df = pd.read_csv('/content/stocks_above_1kcr.csv')
market_cap_dict = dict(zip(market_cap_df['SYMBOL'], market_cap_df['MARKET_CAP_CR']))

# === Inputs ===
dates_to_check = ["2025-06-02", "2025-06-03", "2025-06-04", "2025-06-05",
                 "2025-06-06", "2025-06-09","2025-06-10", "2025-06-11", "2025-06-12", "2025-06-13",
                 "2025-06-16", "2025-06-17","2025-06-18","2025-06-19","2025-06-20","2025-06-23","2025-06-24","2025-06-25","2025-06-26","2025-06-27","2025-06-30", "2025-07-01", "2025-07-02", "2025-07-03","2025-07-04","2025-07-07","2025-07-08","2025-07-09","2025-07-10"]
fyers_symbols = fyers_symbols_filtered  # Ensure this is defined before running

# === Parameters ===
window_size = 24
max_range_pct = 0.01
volume_multiplier = 5
entry_buffer_pct = 0.01
min_body_pct = 0.005
confirmation_breakout_pct = 0.015

# === Fetch 5-min Candle Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Simulate Exit ===
def simulate_exit(entry_price, sl, candles_after_entry):
    for _, row in candles_after_entry.iterrows():
        if row['low'] <= sl:
            return row['timestamp'], sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'
    final_price = candles_after_entry.iloc[-1]['close']
    return candles_after_entry.iloc[-1]['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]

            # Reject breakout after 2:30 PM
            if breakout_candle['timestamp'].time() > pd.to_datetime("14:30").time():
                continue

            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]

                    # Reject if entry happens after 2:30 PM
                    if row['timestamp'].time() > pd.to_datetime("14:30").time():
                        break

                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        sl = entry_price * 0.99
                        remaining_candles = candles_after.iloc[j + 1:]
                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit(entry_price, sl, remaining_candles)

                        symbol_key = symbol.split(':')[-1].split('-')[0]
                        market_cap = market_cap_dict.get(symbol_key, np.nan)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'market_cap_cr': round(market_cap, 2) if not pd.isna(market_cap) else np.nan,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': row['timestamp'],
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades  # One trade per symbol per day
    return trades

# === Run Strategy ===
portfolio_value = 100000
all_trades = []

for date in dates_to_check:
    daily_trades = []
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            daily_trades.extend(trades)
        time.sleep(0)

    # Daily logs
    if daily_trades:
        daily_df = pd.DataFrame(daily_trades)
        all_trades.extend(daily_trades)

        pnls = daily_df['pnl_%'].values
        day_return = round(np.sum(pnls), 2)
        portfolio_value *= (1 + float(day_return) / 100)

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {len(pnls)}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")
        print("\n📋 Trade Log with Market Cap:")
        # print(daily_df[['date', 'symbol', 'market_cap_cr', 'trigger_time', 'entry_time', 'entry_price',
        #     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))
    else:
        print(f"\n📅 {date} — ❌ No trades generated.")

# === Final Portfolio Summary ===
print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")

# === Save Entire Trade Log to CSV ===
if all_trades:
    all_trades_df = pd.DataFrame(all_trades)
    # all_trades_df.to_csv("all_trade_log.csv", index=False)
    print("✅ Saved all trades to all_trade_log.csv")
else:
    print("⚠️ No trades to save.")
# Out:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-02
#
# 📅 2025-06-02 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: -0.32%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.08), np.float64(-1.0), np.float64(1.75), np.float64(-0.43), np.float64(0.3), np.float64(0.14)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-03
#
# 📅 2025-06-03 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: -1.0%
#    📋 Trades PnL: [np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-04
#
# 📅 2025-06-04 Summary:
#    📈 Trades Taken: 9
#    💰 Day's Return: -3.29%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.18), np.float64(-1.0), np.float64(1.94), np.float64(-1.0), np.float64(-1.0), np.float64(-0.43), np.float64(0.02)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-05
#
# 📅 2025-06-05 Summary:
#    📈 Trades Taken: 11
#    💰 Day's Return: 1.37%
#    📋 Trades PnL: [np.float64(-0.91), np.float64(0.13), np.float64(0.93), np.float64(2.44), np.float64(-0.8), np.float64(2.81), np.float64(-1.0), np.float64(0.77), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-06
#
# 📅 2025-06-06 Summary:
#    📈 Trades Taken: 8
#    💰 Day's Return: -1.78%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(0.87), np.float64(0.17), np.float64(-1.0), np.float64(-0.57), np.float64(0.76), np.float64(-1.0), np.float64(-0.01)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-09
#
# 📅 2025-06-09 Summary:
#    📈 Trades Taken: 10
#    💰 Day's Return: 5.11%
#    📋 Trades PnL: [np.float64(0.23), np.float64(7.34), np.float64(-1.0), np.float64(0.77), np.float64(-1.0), np.float64(-0.22), np.float64(1.99), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-10
#
# 📅 2025-06-10 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: 3.99%
#    📋 Trades PnL: [np.float64(0.05), np.float64(-1.0), np.float64(5.04), np.float64(2.43), np.float64(-1.0), np.float64(-0.53), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-11
#
# 📅 2025-06-11 Summary:
#    📈 Trades Taken: 5
#    💰 Day's Return: -5.0%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-12
#
# 📅 2025-06-12 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: -2.0%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-13
#
# 📅 2025-06-13 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: 1.74%
#    📋 Trades PnL: [np.float64(1.74)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-16
#
# 📅 2025-06-16 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: 3.47%
#    📋 Trades PnL: [np.float64(0.77), np.float64(0.27), np.float64(1.68), np.float64(1.54), np.float64(-1.0), np.float64(0.21)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-17
#
# 📅 2025-06-17 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: 0.23%
#    📋 Trades PnL: [np.float64(0.23)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-18
#
# 📅 2025-06-18 Summary:
#    📈 Trades Taken: 1
#    💰 Day's Return: -0.15%
#    📋 Trades PnL: [np.float64(-0.15)]
#
# 📋 Trade Log with Market Cap:
# ⚠️ No candles for NSE:OSWALPUMPS-EQ on 2025-06-19
#
# 📅 2025-06-19 — ❌ No trades generated.
#
# 📅 2025-06-20 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: 0.36%
#    📋 Trades PnL: [np.float64(1.36), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-23 Summary:
#    📈 Trades Taken: 8
#    💰 Day's Return: 3.78%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.55), np.float64(-1.0), np.float64(-1.0), np.float64(6.21), np.float64(-1.0), np.float64(-0.03), np.float64(2.15)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-24 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: -0.61%
#    📋 Trades PnL: [np.float64(0.39), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-25 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: 10.36%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(2.53), np.float64(3.18), np.float64(2.23), np.float64(2.92), np.float64(0.5)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-26 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: 1.47%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-0.19), np.float64(2.83), np.float64(-0.17)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-27 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: -3.07%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(-1.0), np.float64(0.53), np.float64(-1.0), np.float64(0.4), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-06-30 Summary:
#    📈 Trades Taken: 4
#    💰 Day's Return: 7.4%
#    📋 Trades PnL: [np.float64(0.85), np.float64(1.64), np.float64(5.39), np.float64(-0.48)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-01 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: 6.82%
#    📋 Trades PnL: [np.float64(1.89), np.float64(4.21), np.float64(0.72), np.float64(1.08), np.float64(-1.0), np.float64(-0.08)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-02 Summary:
#    📈 Trades Taken: 7
#    💰 Day's Return: 1.01%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(1.97), np.float64(2.89), np.float64(-1.0), np.float64(-1.0), np.float64(0.15), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-03 Summary:
#    📈 Trades Taken: 3
#    💰 Day's Return: 2.72%
#    📋 Trades PnL: [np.float64(2.73), np.float64(-1.0), np.float64(0.99)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-04 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: -0.56%
#    📋 Trades PnL: [np.float64(-1.0), np.float64(0.44)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-07 Summary:
#    📈 Trades Taken: 3
#    💰 Day's Return: 4.44%
#    📋 Trades PnL: [np.float64(2.57), np.float64(2.5), np.float64(-0.63)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-08 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: -1.41%
#    📋 Trades PnL: [np.float64(-0.41), np.float64(-1.0)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-09 Summary:
#    📈 Trades Taken: 6
#    💰 Day's Return: -2.77%
#    📋 Trades PnL: [np.float64(0.79), np.float64(-1.0), np.float64(-1.0), np.float64(-1.0), np.float64(-0.07), np.float64(-0.49)]
#
# 📋 Trade Log with Market Cap:
#
# 📅 2025-07-10 Summary:
#    📈 Trades Taken: 2
#    💰 Day's Return: 3.67%
#    📋 Trades PnL: [np.float64(3.29), np.float64(0.38)]
#
# 📋 Trade Log with Market Cap:
#
# 💼 Final Portfolio Value: ₹140629.46
# ✅ Saved all trades to all_trade_log.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ==== Sample Data ====
strategy3_data = {
    '2025-05-02': -1.71, '2025-05-05': 8.33, '2025-05-06': 0,
    '2025-05-07': 2.39, '2025-05-08': 1, '2025-05-09':7.12,
    '2025-05-12': 0.85, '2025-05-13': 4.76, '2025-05-14':-4.49,
    '2025-05-15': 4.08, '2025-05-16': 1.26, '2025-05-19': 0,
    '2025-05-20': 4.41, '2025-05-21': 3.08, '2025-05-22': 11.63,
    '2025-05-23': -6.24, '2025-05-26': 1.18, '2025-05-27': -1.62,
    '2025-05-28': 2.85, '2025-05-29': -3.3, '2025-05-30': 19.4,'2025-06-02':-0.32, '2025-06-03':-1, '2025-06-04':-3.29, '2025-06-05':1.37,
                 "2025-06-06":-1.78, "2025-06-09":5.11,"2025-06-10":3.99, "2025-06-11":-5, "2025-06-12":-2, "2025-06-13":1.74,
                 "2025-06-16":3.47, "2025-06-17":0.23,"2025-06-18":-0.15,"2025-06-19":0,"2025-06-20":0.36,"2025-06-23":3.78,"2025-06-24":-0.61,"2025-06-25":10.36,"2025-06-26":1.47,"2025-06-27":-3.07,"2025-06-30":7.4, "2025-07-01":6.82, "2025-07-02":1.01, "2025-07-03":2.72,"2025-07-04":-0.56,"2025-07-07":4.44,"2025-07-08":-1.41,"2025-07-09":-2.77,"2025-07-10":3.67
}

strategy3_trades = {
    '2025-05-02': 3, '2025-05-05': 9, '2025-05-06': 0,
    '2025-05-07': 4, '2025-05-08': -1, '2025-05-09':4,
    '2025-05-12': 6, '2025-05-13': 4, '2025-05-14': 7,
    '2025-05-15': 12, '2025-05-16': 12, '2025-05-19': 0,
    '2025-05-20': 3, '2025-05-21': 1, '2025-05-22': 4,
    '2025-05-23': 7, '2025-05-26': 7, '2025-05-27': 3,
    '2025-05-28': 5, '2025-05-29': 6, '2025-05-30': 15,
    "2025-06-02":7, "2025-06-03":1, "2025-06-04":9, "2025-06-05":11,
                 "2025-06-06":8, "2025-06-09":10,"2025-06-10":7, "2025-06-11":5, "2025-06-12":2, "2025-06-13":1,
                 "2025-06-16":6, "2025-06-17":1,"2025-06-18":1,"2025-06-19":0,"2025-06-20":2,"2025-06-23":8,"2025-06-24":2,"2025-06-25":6,"2025-06-26":4,"2025-06-27":6,"2025-06-30":4, "2025-07-01":6, "2025-07-02":7, "2025-07-03":3,"2025-07-04":2,"2025-07-07":3,"2025-07-08":2,"2025-07-09":6,"2025-07-10":2
}

strategy2_data = {
    '2025-05-02': -3.02, '2025-05-05': 7.16, '2025-05-06': -1.0,
    '2025-05-07': 2.46, '2025-05-08': -6.62, '2025-05-09': 2.84,
    '2025-05-12': 5.59, '2025-05-13': 2.52, '2025-05-14': -3.93,
    '2025-05-15': 5.16, '2025-05-16': -0.57, '2025-05-19': -3.0,
    '2025-05-20': 3.41, '2025-05-21': 2.36, '2025-05-22': 13.59,
    '2025-05-23': -7.35, '2025-05-26': -1.34, '2025-05-27': -5.62,
    '2025-05-28': 0.03, '2025-05-29': -4.14, '2025-05-30': 19.7,
}

strategy2_trades = {
    '2025-05-02': 6, '2025-05-05': 11, '2025-05-06': 1,
    '2025-05-07': 9, '2025-05-08': 7, '2025-05-09': 14,
    '2025-05-12': 19, '2025-05-13': 11, '2025-05-14': 13,
    '2025-05-15': 22, '2025-05-16': 23, '2025-05-19': 3,
    '2025-05-20': 4, '2025-05-21': 2, '2025-05-22': 8,
    '2025-05-23': 14, '2025-05-26': 12, '2025-05-27': 7,
    '2025-05-28': 12, '2025-05-29': 11, '2025-05-30': 30,
}

# ==== Capital Curve Function ====
def process_strategy(data_dict, trades_dict, cost_per_trade=0, initial_capital=100000):
    df = pd.DataFrame({
        'Return (%)': data_dict,
        'Trades': trades_dict
    })
    df.index = pd.to_datetime(df.index)
    df.sort_index(inplace=True)

    df['Cost (₹)'] = df['Trades'] * cost_per_trade
    df['Net Return (%)'] = df['Return (%)'] - (df['Cost (₹)'] / initial_capital * 100)

    df['Capital'] = initial_capital
    for i in range(1, len(df)):
        prev_cap = df.iloc[i - 1]['Capital']
        net_ret = df.iloc[i]['Net Return (%)']
        df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)

    df['Peak'] = df['Capital'].cummax()
    df['Drawdown (₹)'] = df['Capital'] - df['Peak']
    df['Drawdown (%)'] = df['Drawdown (₹)'] / df['Peak'] * 100

    return df, df['Drawdown (%)'].min()

# ==== Process Both Strategies ====
df1, max_dd1 = process_strategy(strategy3_data, strategy3_trades)
df2, max_dd2 = process_strategy(strategy2_data, strategy2_trades)

# ==== Print Max Drawdown ====
print(f"\n📉 Strategy 1 Max Drawdown: {max_dd1:.2f}%")
print(f"📉 Strategy 2 Max Drawdown: {max_dd2:.2f}%")

# ==== Capital Curve Plot ====
plt.figure(figsize=(14, 6))
plt.plot(df1.index, df1['Capital'], label='Strategy 1', linewidth=2)
plt.plot(df2.index, df2['Capital'], label='Strategy 2', linewidth=2)
plt.axhline(100000, color='gray', linestyle='--', label='Initial Capital')

# Add labels
for i, date in enumerate(df1.index):
    plt.text(date, df1['Capital'].iloc[i] + 200, f"{df1['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='blue')

for i, date in enumerate(df2.index):
    plt.text(date, df2['Capital'].iloc[i] - 500, f"{df2['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='purple')

plt.title('Capital Curve (Starting ₹1,00,000)')
plt.ylabel('Capital (₹)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ==== Drawdown Plot ====
plt.figure(figsize=(14, 5))
plt.plot(df1.index, df1['Drawdown (%)'], label='Strategy 1 Drawdown', linestyle='--', color='red')
plt.plot(df2.index, df2['Drawdown (%)'], label='Strategy 2 Drawdown', linestyle='--', color='purple')
plt.axhline(0, color='black', linestyle=':')
plt.title('Drawdown Over Time (%)')
plt.ylabel('Drawdown (%)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-20-602981289.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '110919.087' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# /tmp/ipython-input-20-602981289.py:67: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '107160.00000000001' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# 📉 Strategy 1 Max Drawdown: -7.18%
# 📉 Strategy 2 Max Drawdown: -17.28%

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ==== Sample Data ====
strategy3_data = {
    '2025-05-02': -1.71, '2025-05-05': 8.33, '2025-05-06': 0,
    '2025-05-07': 2.39, '2025-05-08': 1, '2025-05-09':7.12,
    '2025-05-12': 0.85, '2025-05-13': 4.76, '2025-05-14':-4.49,
    '2025-05-15': 4.08, '2025-05-16': 1.26, '2025-05-19': 0,
    '2025-05-20': 4.41, '2025-05-21': 3.08, '2025-05-22': 11.63,
    '2025-05-23': -6.24, '2025-05-26': 1.18, '2025-05-27': -1.62,
    '2025-05-28': 2.85, '2025-05-29': -3.3, '2025-05-30': 19.4,'2025-06-02':-0.32, '2025-06-03':-1, '2025-06-04':-3.29, '2025-06-05':1.37,
                 "2025-06-06":-1.78, "2025-06-09":5.11,"2025-06-10":3.99, "2025-06-11":-5, "2025-06-12":-2, "2025-06-13":1.74,
                 "2025-06-16":3.47, "2025-06-17":0.23,"2025-06-18":-0.15,"2025-06-19":0,"2025-06-20":0.36,"2025-06-23":3.78,"2025-06-24":-0.61,"2025-06-25":10.36,"2025-06-26":1.47,"2025-06-27":-3.07,"2025-06-30":7.4, "2025-07-01":6.82, "2025-07-02":1.01, "2025-07-03":2.72,"2025-07-04":-0.56,"2025-07-07":4.44,"2025-07-08":-1.41,"2025-07-09":-2.77,"2025-07-10":3.67
}

strategy3_trades = {
    '2025-05-02': 3, '2025-05-05': 9, '2025-05-06': 0,
    '2025-05-07': 4, '2025-05-08': -1, '2025-05-09':4,
    '2025-05-12': 6, '2025-05-13': 4, '2025-05-14': 7,
    '2025-05-15': 12, '2025-05-16': 12, '2025-05-19': 0,
    '2025-05-20': 3, '2025-05-21': 1, '2025-05-22': 4,
    '2025-05-23': 7, '2025-05-26': 7, '2025-05-27': 3,
    '2025-05-28': 5, '2025-05-29': 6, '2025-05-30': 15,
    "2025-06-02":7, "2025-06-03":1, "2025-06-04":9, "2025-06-05":11,
                 "2025-06-06":8, "2025-06-09":10,"2025-06-10":7, "2025-06-11":5, "2025-06-12":2, "2025-06-13":1,
                 "2025-06-16":6, "2025-06-17":1,"2025-06-18":1,"2025-06-19":0,"2025-06-20":2,"2025-06-23":8,"2025-06-24":2,"2025-06-25":6,"2025-06-26":4,"2025-06-27":6,"2025-06-30":4, "2025-07-01":6, "2025-07-02":7, "2025-07-03":3,"2025-07-04":2,"2025-07-07":3,"2025-07-08":2,"2025-07-09":6,"2025-07-10":2
}

strategy2_data = {
    '2025-05-02': -3.02, '2025-05-05': 7.16, '2025-05-06': -1.0,
    '2025-05-07': 2.46, '2025-05-08': -6.62, '2025-05-09': 2.84,
    '2025-05-12': 5.59, '2025-05-13': 2.52, '2025-05-14': -3.93,
    '2025-05-15': 5.16, '2025-05-16': -0.57, '2025-05-19': -3.0,
    '2025-05-20': 3.41, '2025-05-21': 2.36, '2025-05-22': 13.59,
    '2025-05-23': -7.35, '2025-05-26': -1.34, '2025-05-27': -5.62,
    '2025-05-28': 0.03, '2025-05-29': -4.14, '2025-05-30': 19.7,
}

strategy2_trades = {
    '2025-05-02': 6, '2025-05-05': 11, '2025-05-06': 1,
    '2025-05-07': 9, '2025-05-08': 7, '2025-05-09': 14,
    '2025-05-12': 19, '2025-05-13': 11, '2025-05-14': 13,
    '2025-05-15': 22, '2025-05-16': 23, '2025-05-19': 3,
    '2025-05-20': 4, '2025-05-21': 2, '2025-05-22': 8,
    '2025-05-23': 14, '2025-05-26': 12, '2025-05-27': 7,
    '2025-05-28': 12, '2025-05-29': 11, '2025-05-30': 30,
}

def process_strategy(data_dict, trades_dict, cost_per_trade=40, initial_capital=100000, leverage=4, trades_per_day=10):
    df = pd.DataFrame({
        'Return (%)': data_dict,
        'Trades': trades_dict
    })
    df.index = pd.to_datetime(df.index)
    df.sort_index(inplace=True)

    # Apply adjustment factor: only 1/10 capital per stock with 2.5x leverage → effective weight = 0.25
    df['Adjusted Return (%)'] = df['Return (%)'] * (1 / trades_per_day) * leverage

    # Cost calculation
    df['Cost (₹)'] = df['Trades'] * cost_per_trade
    df['Net Return (%)'] = df['Adjusted Return (%)'] - (df['Cost (₹)'] / initial_capital * 100)

    # Capital curve calculation
    df['Capital'] = initial_capital
    for i in range(1, len(df)):
        prev_cap = df.iloc[i - 1]['Capital']
        net_ret = df.iloc[i]['Net Return (%)']
        df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)

    # Drawdown
    df['Peak'] = df['Capital'].cummax()
    df['Drawdown (₹)'] = df['Capital'] - df['Peak']
    df['Drawdown (%)'] = df['Drawdown (₹)'] / df['Peak'] * 100

    return df, df['Drawdown (%)'].min()

# ==== Run for both strategies ====
df1, max_dd1 = process_strategy(strategy3_data, strategy3_trades)
df2, max_dd2 = process_strategy(strategy2_data, strategy2_trades)

# ==== Print Max Drawdowns ====
print(f"\n📉 Strategy 1 Max Drawdown: {max_dd1:.2f}%")
print(f"📉 Strategy 2 Max Drawdown: {max_dd2:.2f}%")

# ==== Plot Capital Curves ====
plt.figure(figsize=(14, 6))
plt.plot(df1.index, df1['Capital'], label='Strategy 1', linewidth=2, color='blue')
plt.plot(df2.index, df2['Capital'], label='Strategy 2', linewidth=2, color='purple')
plt.axhline(100000, color='gray', linestyle='--', label='Initial Capital')

# Label capital values
for i, date in enumerate(df1.index):
    plt.text(date, df1['Capital'].iloc[i] + 200, f"{df1['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='blue')

for i, date in enumerate(df2.index):
    plt.text(date, df2['Capital'].iloc[i] - 500, f"{df2['Capital'].iloc[i]:,.0f}", fontsize=8, ha='center', color='purple')

plt.title('Capital Curve (₹10K per Trade, 2.5x Leverage, ₹40/Trade Cost)')
plt.ylabel('Capital (₹)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ==== Plot Drawdowns ====
plt.figure(figsize=(14, 5))
plt.plot(df1.index, df1['Drawdown (%)'], label='Strategy 1 Drawdown', linestyle='--', color='red')
plt.plot(df2.index, df2['Drawdown (%)'], label='Strategy 2 Drawdown', linestyle='--', color='purple')
plt.axhline(0, color='black', linestyle=':')
plt.title('Drawdown Over Time (%)')
plt.ylabel('Drawdown (%)')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-23-1533483832.py:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '103791.65712' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# /tmp/ipython-input-23-1533483832.py:71: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '101973.3344' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[i, df.columns.get_loc('Capital')] = prev_cap * (1 + net_ret / 100)
# 📉 Strategy 1 Max Drawdown: -3.95%
# 📉 Strategy 2 Max Drawdown: -9.27%

# %%
##### TRAILING SL
'''
import pandas as pd
import numpy as np
from fyers_apiv3 import fyersModel
import time

# === Fyers Setup ===
client_id = "6HK249XFBQ-100"
access_token = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....MHl4VmmhwnetEtdMF2nsPcVdiPvWbo5HPYyipJQXfJo"
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token)

# === Inputs ===
dates_to_check = ["2025-07-01", "2025-07-02","2025-07-03"]
#dates_to_check = ["2025-07-03"]
fyers_symbols = fyers_symbols_filtered  # Make sure this list is defined

# === Parameters ===
window_size = 24
max_range_pct = 0.02
volume_multiplier = 3
min_body_pct = 0.0075
confirmation_breakout_pct = 0.015

# === Fetch 5-min Data ===
def fetch_5min_data(symbol, date):
    try:
        res = fyers.history({
            "symbol": symbol,
            "resolution": "5",
            "date_format": "1",
            "range_from": date,
            "range_to": date,
            "cont_flag": "0"
        })
        if 'candles' in res and len(res['candles']) > 0:
            df = pd.DataFrame(res['candles'], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s', utc=True).dt.tz_convert('Asia/Kolkata')
            return df
        else:
            print(f"⚠️ No candles for {symbol} on {date}")
            return pd.DataFrame()
    except Exception as e:
        print(f"❌ Error fetching {symbol} on {date}: {e}")
        return pd.DataFrame()

# === Trailing Stop Loss Logic ===
def simulate_exit_with_trailing_sl(entry_price, candles_after_entry):
    initial_sl = entry_price * 0.99  # Start with 1% SL
    sl = initial_sl
    trail_triggered = False
    max_price = entry_price

    for _, row in candles_after_entry.iterrows():
        high = row['high']
        low = row['low']
        time = row['timestamp']

        if high > max_price:
            max_price = high

        gain_pct = (max_price - entry_price) / entry_price

        if not trail_triggered and gain_pct >= 0.01:
            sl = entry_price
            trail_triggered = True

        if trail_triggered and gain_pct >= 0.02:
            extra_steps = int((gain_pct - 0.01) / 0.01)
            sl = entry_price + (extra_steps * 0.005 * entry_price)

        if low <= sl:
            return time, sl, ((sl - entry_price) / entry_price) * 100, 'SL Hit'

    final_row = candles_after_entry.iloc[-1]
    final_price = final_row['close']
    return final_row['timestamp'], final_price, ((final_price - entry_price) / entry_price) * 100, 'End of Day Exit'

# === Breakout Strategy ===
def dynamic_range_breakout(df, symbol, date):
    trades = []
    if df.empty or len(df) < window_size + 10:
        return trades

    for i in range(len(df) - window_size - 6):
        range_df = df.iloc[i:i + window_size]
        r_high = range_df['high'].max()
        r_low = range_df['low'].min()
        r_width = (r_high - r_low) / r_low
        mean_volume = range_df['volume'].mean()

        if r_width < max_range_pct:
            breakout_candle = df.iloc[i + window_size]
            body = breakout_candle['close'] - breakout_candle['open']
            upper_wick = breakout_candle['high'] - breakout_candle['close']
            body_pct = body / breakout_candle['open']

            if upper_wick > 0.5 * abs(body):
                continue

            if (
                breakout_candle['close'] > breakout_candle['open'] and
                breakout_candle['high'] > r_high and
                body_pct >= min_body_pct and
                breakout_candle['volume'] > volume_multiplier * mean_volume
            ):
                target_entry_price = r_high * (1 + confirmation_breakout_pct)
                candles_after = df.iloc[i + window_size + 1:]

                for j in range(len(candles_after)):
                    row = candles_after.iloc[j]
                    if row['high'] >= target_entry_price:
                        entry_price = target_entry_price
                        entry_time = row['timestamp']
                        remaining_candles = candles_after.iloc[j + 1:]

                        if len(remaining_candles) == 0:
                            break

                        exit_time, exit_price, pnl_pct, reason = simulate_exit_with_trailing_sl(entry_price, remaining_candles)

                        trades.append({
                            'date': date,
                            'symbol': symbol,
                            'trigger_time': breakout_candle['timestamp'],
                            'entry_time': entry_time,
                            'entry_price': round(entry_price, 2),
                            'exit_time': exit_time,
                            'exit_price': round(exit_price, 2),
                            'pnl_%': round(pnl_pct, 2),
                            'reason': reason
                        })
                        return trades
    return trades

# === Run Strategy ===
all_trades = []

for date in dates_to_check:
    for symbol in fyers_symbols:
        df = fetch_5min_data(symbol, date)
        #print(f"✅ Data fetched: {symbol} on {date}, {len(df)} candles")
        if not df.empty:
            trades = dynamic_range_breakout(df, symbol, date)
            #print(f"🔍 Trades found: {len(trades)}")
            all_trades.extend(trades)
        time.sleep(0)

# === Results Summary ===
trades_df = pd.DataFrame(all_trades)

if trades_df.empty:
    print("\n❌ No trades were generated.")
else:
    trades_df['date'] = pd.to_datetime(trades_df['date']).dt.date
    daily_returns = []
    portfolio_value = 100000

    for date, group in trades_df.groupby('date'):
        pnls = group['pnl_%'].values
        trades_taken = len(pnls)
        day_return = round(np.sum(pnls), 2)
        daily_returns.append(np.float64(day_return))

        print(f"\n📅 {date} Summary:")
        print(f"   📈 Trades Taken: {trades_taken}")
        print(f"   💰 Day's Return: {day_return}%")
        print(f"   📋 Trades PnL: {[round(p, 2) for p in pnls]}")

    for ret in daily_returns:
        portfolio_value *= (1 + float(ret) / 100)

    print(f"\n💼 Final Portfolio Value: ₹{round(portfolio_value, 2)}")
    print(f"📊 Daily Returns (%): {daily_returns}")

    print("\n🔍 Exit Reason Summary:")
    exit_summary = trades_df['reason'].value_counts().to_dict()
    for reason in exit_summary:
        total = exit_summary[reason]
        wins = sum((trades_df['reason'] == reason) & (trades_df['pnl_%'] > 0))
        losses = total - wins
        win_pct = round((wins / total) * 100, 2)
        print(f"▶️ {reason}: {total} trades → ✅ Wins: {wins} | ❌ Losses: {losses} | 🏆 Win%: {win_pct}%")

    print("\n📋 Trade Log:")
    print(trades_df[['date', 'symbol', 'trigger_time', 'entry_time', 'entry_price',
                     'exit_time', 'exit_price', 'pnl_%', 'reason']].to_string(index=False))

'''

# %%
#with market cap??
